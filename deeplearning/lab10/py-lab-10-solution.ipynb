# %% [markdown]
# # Lab 10
#
# ## Imports

# %%
from math import ceil
from typing import List, Tuple

import matplotlib.pyplot as plt
import torch
from matplotlib_inline.backend_inline import set_matplotlib_formats
from torch import nn, Tensor
from torch.distributions import Normal
from torch.optim import Adam, Optimizer
from torch.utils.data import DataLoader
from torchvision.datasets import MNIST
from torchvision.transforms import ToTensor
from torchvision.utils import make_grid
from torchsummary import summary

set_matplotlib_formats('png', 'pdf')

# %% [markdown]
# # Exercise 1
#
# In this exercise, we will implement a denoising autoencoder (DAE). We will use the MNIST dataset for this task. The autoencoder will be trained on noisy images and should be able to remove the noise from the images.

# %%
train_x = MNIST(root='.data', download=True, transform=ToTensor())

# %% [markdown]
# Let's first construct a basic fully connected autoencoder.

# %%
class AE(nn.Module):
    def __init__(self):
        super(AE, self).__init__()
        self.encoder = nn.Sequential(
            nn.Linear(28*28, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU()
        )
        
        self.decoder = nn.Sequential(
            nn.Linear(64, 128),
            nn.ReLU(),
            nn.Linear(128, 28*28),
            nn.Sigmoid()
        )

    def forward(self, x):
        x = self.encoder(x)
        x = self.decoder(x)
        return x

# %% [markdown]
# Let's define the denoising autoencoder class which will add Gaussian noise to the input images before passing them through the autoencoder.

# %%
class DAE(nn.Module):
    def __init__(self, autoencoder):
        super(DAE, self).__init__()
        self.autoencoder = autoencoder

    def forward(self, x, noise_factor=0.5):
        x_noisy = x + noise_factor * torch.randn_like(x)
        x_recon = self.autoencoder(x_noisy)
        return x_recon

# %% [markdown]
# First let's look at some original images and their noisy versions with varying noise factors.

# %%
# plot original and noisy images
noise_fcts = [0.0, 0.1, 0.5, 1.0]
fig, axs = plt.subplots(2, len(noise_fcts), figsize=(12, 4))
for i, noise_fct in enumerate(noise_fcts):
    for ax, x in zip(axs[:, i], train_x):
        x = x[0]
        x_noisy = x + noise_fct * torch.randn_like(x)
        ax.imshow(x_noisy.squeeze().numpy(), cmap='gray')
    axs[0, i].set_title(f'Noise factor {noise_fct}')
    axs[0, i].set_xticks([])
    axs[0, i].set_yticks([])
    axs[1, i].set_xticks([])
    axs[1, i].set_yticks([])

# %% [markdown]
# Let's write a simple training loop to train the DAE on the MNIST dataset.

# %%
autoencoder = AE()
dae = DAE(autoencoder)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
dae = dae.to(device)

optimizer = torch.optim.Adam(dae.parameters(), lr=0.001)
criterion = (
    nn.MSELoss()
)
for epoch in range(2):
    for i, (images, _) in enumerate(train_x):
        # flatten the images
        images = images.view(-1, 28*28).to(device)
        images_recon = dae(images, noise_factor=0.5)
        loss = criterion(images_recon, images)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    print(f'Epoch {epoch+1}, Loss: {loss.item():.4f}')
# Out:
# Epoch 1, Loss: 0.0332
# Epoch 2, Loss: 0.0387

# %%
summary(dae, (28*28,))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                  [-1, 128]         100,480
#               ReLU-2                  [-1, 128]               0
#             Linear-3                   [-1, 64]           8,256
#               ReLU-4                   [-1, 64]               0
#             Linear-5                  [-1, 128]           8,320
#               ReLU-6                  [-1, 128]               0
#             Linear-7                  [-1, 784]         101,136
#            Sigmoid-8                  [-1, 784]               0
#                 AE-9                  [-1, 784]               0
# ================================================================
# Total params: 218,192
# Trainable params: 218,192
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.02
# Params size (MB): 0.83
# Estimated Total Size (MB): 0.86
# ----------------------------------------------------------------

# %% [markdown]
# The loss decreased during training, which is a good sign. Let's now visualize the original images, noisy images, and the denoised images.

# %%
# plot original, noisy and reconstructed images

fig, axs = plt.subplots(3, 3, figsize=(6, 6))
for i, (images, _) in enumerate(train_x):
    images = images.view(-1, 28*28).to(device)
    noisy_imges = images + 0.5 * torch.randn_like(images)
    recon_images = dae.autoencoder(images)
    for ax, img in zip(axs[i, :], [images, noisy_imges, recon_images]):
        ax.imshow(img.view(28, 28).cpu().detach().numpy(), cmap='gray')
        ax.set_xticks([])
        ax.set_yticks([])
    if i == 2:
        break

# %% [markdown]
# Let's try to be much more parameter efficient by using a convolutional autoencoder.

# %%
class CAE(nn.Module):
    def __init__(self):
        super(CAE, self).__init__()
        self.encoder = nn.Sequential(
            nn.Conv2d(1,16,3,padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2,2),
            nn.Conv2d(16,32,3,padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2,2),
            nn.Conv2d(32,64,3,padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2,2)
        )
        self.decoder = nn.Sequential(
            nn.ConvTranspose2d(64,32,3,stride=2),
            nn.ReLU(),
            nn.ConvTranspose2d(32,16,2,stride=2),
            nn.ReLU(),
            nn.ConvTranspose2d(16,1,2,stride=2),
            nn.Sigmoid()
        )

    def forward(self, x):
        x = self.encoder(x)
        x = self.decoder(x)
        return x

autoencoder = CAE()
dae = DAE(autoencoder)

dae = dae.to(device)

optimizer = torch.optim.Adam(dae.parameters(), lr=0.001)

# Define the loss function and the training loop

criterion = (
    nn.MSELoss()
)

for epoch in range(2):
    for i, (images, _) in enumerate(train_x):
        # note that we do not flatten the images here
        images_recon = dae(images)
        # flatten the images for the loss calculation
        images = images.view(-1, 28*28).to(device)
        images_recon = images_recon.view(-1, 28*28).to(device)
        loss = criterion(images_recon, images)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    print(f'Epoch {epoch+1}, Loss: {loss.item():.4f}')
# Out:
# Epoch 1, Loss: 0.0172
# Epoch 2, Loss: 0.0156

# %%
summary(dae, (1, 28, 28))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 16, 28, 28]             160
#               ReLU-2           [-1, 16, 28, 28]               0
#          MaxPool2d-3           [-1, 16, 14, 14]               0
#             Conv2d-4           [-1, 32, 14, 14]           4,640
#               ReLU-5           [-1, 32, 14, 14]               0
#          MaxPool2d-6             [-1, 32, 7, 7]               0
#             Conv2d-7             [-1, 64, 7, 7]          18,496
#               ReLU-8             [-1, 64, 7, 7]               0
#          MaxPool2d-9             [-1, 64, 3, 3]               0
#   ConvTranspose2d-10             [-1, 32, 7, 7]          18,464
#              ReLU-11             [-1, 32, 7, 7]               0
#   ConvTranspose2d-12           [-1, 16, 14, 14]           2,064
#              ReLU-13           [-1, 16, 14, 14]               0
#   ConvTranspose2d-14            [-1, 1, 28, 28]              65
#           Sigmoid-15            [-1, 1, 28, 28]               0
#               CAE-16            [-1, 1, 28, 28]               0
# ================================================================
# Total params: 43,889
# Trainable params: 43,889
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.46
# Params size (MB): 0.17
# Estimated Total Size (MB): 0.64
# ----------------------------------------------------------------

# %%
# visualize original, noisy and reconstructed images
fig, axs = plt.subplots(3, 3, figsize=(6, 6))
for i, (images, _) in enumerate(train_x):
    images = images.to(device)
    noisy_imges = images + 0.5 * torch.randn_like(images)
    recon_images = dae.autoencoder(images)
    for ax, img in zip(axs[i, :], [images, noisy_imges, recon_images]):
        ax.imshow(img.view(28, 28).cpu().detach().numpy(), cmap='gray')
        ax.set_xticks([])
        ax.set_yticks([])
    if i == 2:
        break

# %% [markdown]
# The results are competitive with the fully connected autoencoder, but the convolutional autoencoder is much more parameter efficient (about 7 times less parameters).

# %% [markdown]
# ## Exercise 2
#
# In this exercise we will get acquainted with the KL divergence for normal distributions.
#
#
# **(a)** First, let $p(x)=\mathcal{N}(\mu_1,\sigma_1^2)$ and $q(x)=\mathcal{N}(\mu_2,\sigma_2^2)$
# and show that
#
# \begin{equation*}
# \text{KL}(q||p)
# = \mathbb{E}_{x\sim q}\left[\log\frac{q(x)}{p(x)}\right]
# =\log\frac{\sigma_1}{\sigma_2}+\frac{\sigma_2^2+(\mu_1-\mu_2)^2}{2\sigma_1^2} -\frac 1 2
# \end{equation*}
#
# **(b)** Now, consider a variational autoencoder that takes a vector as input $\textbf{x}$ and
# transforms it into a mean vector $\mu(\textbf{x})$ and a variance vector $\sigma(\textbf{x})^2$.
# From these, we derive the latent code $\textbf{z}\sim q(\textbf{z})=\mathcal{N}(\mu(\textbf{x}),\text{diag}(\sigma(\textbf{x})^2))$,
# i.e. a multivariate Gaussian in $d$ dimensions with a given mean vector and diagonal
# covariance matrix. The prior distribution for $\textbf{z}$ is another $d$-dimensional
# multivariate Gaussian $p=\mathcal{N}(\textbf{0},\textbf{1})$.
#
# Now show that:
#
# \begin{equation*}
# \text{KL}(q||p)= -\frac 1 2 \sum_{i=1}^d \left(1+\log\sigma_i(\textbf{x})^2-\sigma_i(\textbf{x})^2 - \mu_i(\textbf{x})^2 \right)
# \end{equation*}
#
# Hint: start by showing that $p$ and $q$ can be factorized into a product of independent
# Gaussian components, one for each dimension, then apply the formula for the KL
# divergence for the univariate case.
#
#
#
# ### Solution
#
# **(a)** We analyze each term separately:
#
# \begin{align}
# \mathbb{E}_{x\sim q}\left[\log q(x)\right]
# &= -\frac 1 2 \log(2\pi\sigma_2^2)+\mathbb{E}\left[-\frac{1}{2\sigma_2^2}\left(x-\mu_2\right)^2\right] \\
# &= -\frac 1 2 \log(2\pi\sigma_2^2) -\frac{1}{2\sigma_2^2}\left(\mathbb{E}[x^2]-2\mu_2\mathbb{E}[x]+\mu_2^2\right) \\
# &= -\frac 1 2 \log(2\pi\sigma_2^2) -\frac{1}{2\sigma_2^2}\left(\sigma_2^2+\mu_2^2-2\mu_2^2+\mu_2^2\right) \\
# &= -\frac 1 2(1+\log(2\pi\sigma_2^2))
# \end{align}
#
# and
#
# \begin{align}
# \mathbb{E}_{x\sim q}\left[\log p(x)\right]
# &= -\frac 1 2 \log(2\pi\sigma_1^2)+\mathbb{E}\left[-\frac{1}{2\sigma_1^2}\left(x-\mu_1\right)^2\right] \\
# &= -\frac 1 2 \log(2\pi\sigma_1^2) -\frac{1}{2\sigma_1^2}\left(\mathbb{E}[x^2]-2\mu_1\mathbb{E}[x]+\mu_1^2\right) \\
# &= -\frac 1 2 \log(2\pi\sigma_1^2) -\frac{1}{2\sigma_1^2}\left(\sigma_2^2+\mu_2^2-2\mu_1\mu_2+\mu_1^2\right) \\
# &= -\frac 1 2 \log(2\pi\sigma_1^2) -\frac{\sigma_2^2+(\mu_1-\mu_2)^2}{2\sigma_1^2}
# \end{align}
#
# Now taking the difference:
#
#
# \begin{align}
# \text{KL}(q||p)
# &=\mathbb{E}_{x\sim q}\left[\log q(x)\right] - \mathbb{E}_{x\sim q}\left[\log p(x)\right] \\
# &=-\frac 1 2(1+\log(2\pi\sigma_2^2))+\frac 1 2 \log(2\pi\sigma_1^2) +\frac{\sigma_2^2+(\mu_1-\mu_2)^2}{2\sigma_1^2} \\
# &=-\frac 1 2\left[1+\log(2\pi\sigma_2^2)-\log(2\pi\sigma_1^2)-\frac{\sigma_2^2+(\mu_1-\mu_2)^2}{\sigma_1^2}\right] \\
# &=-\frac 1 2\left[1+\log\frac{\sigma_2^2}{\sigma_1^2}-\frac{\sigma_2^2+(\mu_1-\mu_2)^2}{\sigma_1^2} \right] \\
# &= \log\frac{\sigma_1}{\sigma_2}+\frac{\sigma_2^2+(\mu_1-\mu_2)^2}{2\sigma_1^2} -\frac 1 2
# \end{align}
#
# **(b)** Moving to the second question, the expression for $p$ can be factorized as follows:
#
# \begin{align}
# q(\textbf{z})
# &=
#   (2\pi)^{-d/2}
#   \det(\text{diag}(\sigma(\textbf{x})^2))^{-1/2}
#   \exp\left(-\frac 1 2
#     (\textbf{z}-\mu(\textbf{x}))^T
#     \text{diag}(\sigma(\textbf{x})^2)^{-1}
#     (\textbf{z}-\mu(\textbf{x}))
#   \right) \\
# &=
#   (2\pi)^{-d/2}
#   \left(\prod_i \sigma_i(\textbf{x})^2\right)^{-1/2}
#   \exp\left(
#     -\frac 1 2 \sum_i \sigma_i(\textbf{x})^{-2}(z_i-\mu_i(\textbf{x}))^2
#   \right) \\
# &=
#   \prod_{i=1}^d
#   (2\pi\sigma_i(\textbf{x})^2)^{-1/2}
#   \exp\left(
#     -\frac{1}{2\sigma_i(\textbf{x})^2} (z_i-\mu_i(\textbf{x}))^2
#   \right) \\
# &=
#   \prod_{i=1}^d
#   \mathcal{N}(z_i|\mu_i(\textbf{x})^2, \sigma_i(\textbf{x})^2)
# \end{align}
#
# Where we made use of some convenient properties of diagonal matrices, namely that their
# determinant is the product of the elements on the diagonal, and that their inverse is
# again diagonal with the elements replaced by their reciprocal.
#
# Now since the mean of $p$ is zero and the covariance is the identity matrix, we have:
#
# \begin{equation}
# p(\textbf{z})=\prod_{i=1}^d\mathcal{N}(z_i|0, 1)
# \end{equation}
#
# We now plug these into the formula for the KL divergence to get:
#
# \begin{align}
# \text{KL}(q||p)
# &= \mathbb{E}_{x\sim q}\left[\log q(x)\right] - \mathbb{E}_{x\sim q}\left[\log p(x)\right] \\
# &= \mathbb{E}\left[\log\prod_{i=1}^d q(x)\right] - \mathbb{E}\left[\log\prod_{i=1}^d p_i(x)\right] \\
# &= \sum_{i=1}^d \mathbb{E}\left[\log q_i(x)\right] - \sum_i \mathbb{E}\left[\log p_i(x)\right] \\
# &= \sum_{i=1}^d \mathbb{E}\left[\log\frac{q_i(x)}{p_i(x)}\right] \\
# &= \sum_{i=1}^d \left(\log\frac{1}{\sigma_i(\textbf{x})}+\frac{\sigma_i(\textbf{x})^2+\mu(\textbf{x})^2}{2} -\frac 1 2\right) \\
# &= -\frac 1 2 \sum_{i=1}^d \left(1+\log\sigma_i(\textbf{x})^2-\sigma_i(\textbf{x})^2 - \mu_i(\textbf{x})^2 \right)
# \end{align}
#
#
# ## Exercise 3 (optional)
#
# In this exercise we are going to implement variational autoencoders (VAEs) on the MNIST
# dataset.

# %%
train_x = MNIST(root='.data', download=True, transform=ToTensor())

# %% [markdown]
# In a VAE, the encoder outputs mean and variance of a multivariate Gaussian distribution
# of the latent codes. Nothing prevents you from using a more complicated distribution in
# the same framework, but this is the usual choice. The expected log likelihood is then
# approximated by decoding a single sample from this distribution. Moreover, since we need
# the model to be differentiable end-to-end, sampling from the latent codes is
# re-formulated via the reparametrization trick.
#
# In the following we define a custom VAE module with a few utility functions that allow
# convenient managing of the VAE functionalities.

# %%
class VAE(nn.Module):

    # We pass the encoder and decoder over the constructor, which gives us more flexibility.
    def __init__(
            self,
            encoder: nn.Module,
            decoder: nn.Module,
            device: torch.device):
        super().__init__()
        self.encoder = encoder.to(device)
        self.decoder = decoder.to(device)
        self.device = device

        # We need a normal distribution for the reparametrization trick
        self.distribution = Normal(0, 1)

    # We define a utility function for sampling the eps with correct shape and device
    def sample_eps(self, sample_shape: Tuple) -> Tensor:
        sampled_eps: Tensor = self.distribution.sample(sample_shape)
        if str(self.device) != 'cpu':
            sampled_eps = sampled_eps.cuda()
        return sampled_eps

    # We output the reconstructed x as well as the latent mu and log variance.
    def forward(self, x: Tensor) -> Tuple[Tensor, Tensor, Tensor]:
        mu, log_var = self.encoder(x)
        std = torch.exp(0.5 * log_var)
        eps = self.sample_eps(std.shape)
        z = mu + eps * std
        x_hat = self.decoder(z)
        return x_hat, mu, log_var

    # We define an inference method for encoding input tensors.
    def encode(self, x: Tensor) -> Tensor:
        with torch.no_grad():
            mu, _ = self.encoder(x)
        return mu

    # We define an inference method for reconstructing z tensors.
    def reconstruct(self, z: Tensor) -> Tensor:
        with torch.no_grad():
            x_hat = self.decoder(z)
        return x_hat

# %% [markdown]
# Next, we create our encoder and decoder.
# The encoder will have two outputs, which is easily done via the `nn.Module` container.

# %%
class Encoder(nn.Module):
    def __init__(self, input_size: int, latent_size: int):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(in_features=input_size, out_features=256),
            nn.LeakyReLU(),
            nn.Linear(in_features=256, out_features=64),
            nn.LeakyReLU()
        )

        self.mu = nn.Sequential(
            nn.Linear(in_features=64, out_features=32),
            nn.LeakyReLU(),
            nn.Linear(in_features=32, out_features=latent_size),
            nn.LeakyReLU()
        )

        self.log_var = nn.Sequential(
            nn.Linear(in_features=64, out_features=32),
            nn.LeakyReLU(),
            nn.Linear(in_features=32, out_features=latent_size),
            nn.LeakyReLU()
        )

    def forward(self, x:Tensor) -> Tuple[Tensor, Tensor]:
        x = self.net(x)
        return self.mu(x), self.log_var(x)


class Decoder(nn.Module):
    def __init__(self, output_size: int, latent_size: int):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(in_features=latent_size, out_features=32),
            nn.LeakyReLU(),
            nn.Linear(in_features=32, out_features=64),
            nn.LeakyReLU(),
            nn.Linear(in_features=64, out_features=256),
            nn.LeakyReLU(),
            nn.Linear(in_features=256, out_features=output_size),
            nn.Sigmoid()
        )

    def forward(self, x:Tensor) -> Tuple[Tensor, Tensor]:
        return self.net(x)

# %% [markdown]
# A missing component is a Kullback-Leibler loss function, which we will define
# now for two Gaussians:

# %%
class KLDivergence:
    def __call__(self, mu: Tensor, log_var: Tensor) -> Tensor:
        return (
            -0.5 * torch.sum(1 + log_var - mu.pow(2) - log_var.exp()) / log_var.shape[0]
        )

# %% [markdown]
# Exactly like in the previous exercise, we again define our training iteration:

# %%
def train_autoencoder(
        vae: VAE,
        optimizer: Optimizer,
        mnist_dataset: MNIST,
        epochs: int,
        batch_size: int,
) -> List[float]:

    rec_loss = nn.MSELoss(reduction='sum')
    kl_loss = KLDivergence()

    train_losses = []

    num_train_batches = ceil(len(mnist_dataset) / batch_size)
    train_loader = DataLoader(mnist_dataset, batch_size, shuffle=True)

    for ep in range(1, epochs + 1):
        total_ep_loss = 0

        for batch_idx, (x, _) in enumerate(train_loader):
            x = x.to(vae.device).view(x.shape[0], -1)

            x_hat, mu, log_var = vae(x)
            batch_rec_loss = rec_loss(x, x_hat) / batch_size
            batch_kl_loss = kl_loss(mu, log_var) / x.shape[1]
            total_loss = batch_rec_loss + batch_kl_loss

            optimizer.zero_grad()
            total_loss.backward()
            optimizer.step()

            if batch_idx % 10 == 0:
                print('TRAINING BATCH:\t({:5} / {:5})\tREC LOSS:\t{:2.3f}\tKL LOSS:\t{:2.3f}'
                      .format(batch_idx, num_train_batches, float(batch_rec_loss), float(batch_kl_loss)), end='\r')

            total_ep_loss += float(total_loss)

        train_losses.append(total_ep_loss / num_train_batches)
        print('EPOCH:\t{:5}\tTRAIN LOSS:\t{:.3f}'.format(ep, train_losses[-1], end='\r'))

    return train_losses

# %% [markdown]
# Finally, we can initialize all our classes and start the training!
# We will choose a latent size of 8.

# %%
latent_size = 8
epochs = 2
batch_size = 128


encoder = (
    Encoder(input_size=784, latent_size=8)
)

decoder = (
    Decoder(output_size=784, latent_size=8)
)

vae = (
    VAE(
        encoder=encoder,
        decoder=decoder,
        device=torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    )
)

optimizer = (
    Adam(vae.parameters())
)

train_autoencoder(vae, optimizer, train_x, epochs, batch_size)
# Out:
# TRAINING BATCH:	(   20 /   469)	REC LOSS:	66.725	KL LOSS:	0.046
# TRAINING BATCH:	(   50 /   469)	REC LOSS:	55.554	KL LOSS:	0.003
# TRAINING BATCH:	(   70 /   469)	REC LOSS:	53.689	KL LOSS:	0.004
# TRAINING BATCH:	(   90 /   469)	REC LOSS:	51.913	KL LOSS:	0.015
# TRAINING BATCH:	(  110 /   469)	REC LOSS:	51.165	KL LOSS:	0.042
# TRAINING BATCH:	(  140 /   469)	REC LOSS:	49.305	KL LOSS:	0.056
# TRAINING BATCH:	(  170 /   469)	REC LOSS:	48.100	KL LOSS:	0.074
# TRAINING BATCH:	(  200 /   469)	REC LOSS:	43.663	KL LOSS:	0.111
# TRAINING BATCH:	(  230 /   469)	REC LOSS:	44.915	KL LOSS:	0.097
# TRAINING BATCH:	(  260 /   469)	REC LOSS:	44.273	KL LOSS:	0.125
# TRAINING BATCH:	(  290 /   469)	REC LOSS:	41.241	KL LOSS:	0.159
# TRAINING BATCH:	(  310 /   469)	REC LOSS:	39.422	KL LOSS:	0.172
# TRAINING BATCH:	(  340 /   469)	REC LOSS:	37.692	KL LOSS:	0.175
# TRAINING BATCH:	(  370 /   469)	REC LOSS:	37.174	KL LOSS:	0.185
# TRAINING BATCH:	(  400 /   469)	REC LOSS:	36.552	KL LOSS:	0.196
# TRAINING BATCH:	(  420 /   469)	REC LOSS:	35.835	KL LOSS:	0.218
# TRAINING BATCH:	(  450 /   469)	REC LOSS:	32.031	KL LOSS:	0.235
# EPOCH:	    1	TRAIN LOSS:	48.693
# TRAINING BATCH:	(    0 /   469)	REC LOSS:	33.988	KL LOSS:	0.202
# TRAINING BATCH:	(   30 /   469)	REC LOSS:	33.085	KL LOSS:	0.257
# TRAINING BATCH:	(   60 /   469)	REC LOSS:	32.221	KL LOSS:	0.266
# TRAINING BATCH:	(   80 /   469)	REC LOSS:	31.613	KL LOSS:	0.293
# TRAINING BATCH:	(  100 /   469)	REC LOSS:	28.302	KL LOSS:	0.293
# TRAINING BATCH:	(  120 /   469)	REC LOSS:	30.145	KL LOSS:	0.290
# TRAINING BATCH:	(  140 /   469)	REC LOSS:	29.859	KL LOSS:	0.257
# TRAINING BATCH:	(  160 /   469)	REC LOSS:	30.950	KL LOSS:	0.289
# TRAINING BATCH:	(  180 /   469)	REC LOSS:	27.914	KL LOSS:	0.315
# TRAINING BATCH:	(  210 /   469)	REC LOSS:	27.954	KL LOSS:	0.259
# TRAINING BATCH:	(  240 /   469)	REC LOSS:	28.092	KL LOSS:	0.289
# TRAINING BATCH:	(  270 /   469)	REC LOSS:	26.703	KL LOSS:	0.276
# TRAINING BATCH:	(  300 /   469)	REC LOSS:	28.391	KL LOSS:	0.272
# TRAINING BATCH:	(  330 /   469)	REC LOSS:	27.572	KL LOSS:	0.287
# TRAINING BATCH:	(  360 /   469)	REC LOSS:	24.990	KL LOSS:	0.278
# TRAINING BATCH:	(  390 /   469)	REC LOSS:	28.006	KL LOSS:	0.272
# TRAINING BATCH:	(  420 /   469)	REC LOSS:	23.897	KL LOSS:	0.302
# TRAINING BATCH:	(  450 /   469)	REC LOSS:	26.724	KL LOSS:	0.280
# EPOCH:	    2	TRAIN LOSS:	28.563
# [48.69300673104553, 28.562764535834795]

# %% [markdown]
# Let us check the reconstruction of a digit:

# %%
def plot_reconstruction_grid(vae: nn.Module, mnist_dataset: MNIST) -> None:
    x_samples = mnist_dataset.data[:100] / 255
    z = vae.encode(x_samples.to(vae.device).view(100, -1))
    x_hat = vae.reconstruct(z).detach().cpu().view(100, 28, 28)

    cur_col = 0
    image_list = []
    for _ in range(4):
        image_list.extend(x_samples[cur_col:cur_col + 25])
        image_list.extend(x_hat[cur_col:cur_col + 25])
        cur_col += 25

    image_batch = torch.stack(image_list).unsqueeze(1)
    image_grid = make_grid(image_batch, nrow=25)
    plt.imshow(image_grid.permute(1, 2, 0))
    plt.axis('off')
    plt.show()

# %%
plot_reconstruction_grid(vae, train_x)

# %% [markdown]
# It is already quite good for only two training epochs!
# Now try to remove the division of the KL by 784, train again and visualize the result.
#
# You should see a gray blob that looks a bit like the average of many digits.
# This phenomenon is named _mode collapse_, i.e. the distribution of the generator
# collapsed to a single mode that covers the entire dataset, instead of (at least)
# one mode for every digit. In VAEs, this is typically caused by a KL term that is
# very strong at the beginning of training, and dominates the reconstruction loss.
# The optimizer will focus most of its efforts to reduce this term, ending up in a poor local minimum.
#
# A popular method to deal with this issue is _KL annealing_.
# It consists in training the network without the KL regularizer for some time, then slowly
# increasing the weight of the KL. This procedure allows the network to first learn how to
# perform good reconstructions, then to adjust the latent code to conform to a Normal
# distribution without erasing progress on the reconstruction.
#
# To implement this behaviour, we define a small object that is able to return the
# desired KL weight in the respective epoch.

# %%
class KLWeightManager:
    """
    Manager to get the desired KL weight.

    Warm up rounds specify the starting epochs until which the KL weight will be zero.
    The annealing rounds describe the duration of the annealing process.
    E.g., warm up is 5 and and there are 10 annealing rounds, then the first 5 epochs
    will have a KL weight of 0 and from epoch 5 to 15 the weight will be annealed to 1.
    """
    def __init__(self, warm_up_rounds: int, annealing_rounds: int):
        self.warm_up = warm_up_rounds
        self.annealing_rounds = annealing_rounds


    def __call__(self, cur_epoch: int) -> float:
        if cur_epoch < self.warm_up:
            return 0.0
        elif cur_epoch >= self.warm_up + self.annealing_rounds:
            return 1.0
        else:
            progress = cur_epoch - self.warm_up
            return progress / self.annealing_rounds

# %% [markdown]
# Let's remove the scaling term in the training loop and integrate the `KLWeightManager`:

# %%
def train_autoencoder(
        vae: VAE,
        optimizer: Optimizer,
        mnist_dataset: MNIST,
        epochs: int,
        batch_size: int,
) -> List[float]:

    rec_loss = nn.MSELoss(reduction='sum')
    kl_loss = KLDivergence()
    kl_weighting = KLWeightManager(warm_up_rounds=0, annealing_rounds=5)

    train_losses = []

    num_train_batches = ceil(len(mnist_dataset) / batch_size)
    train_loader = DataLoader(mnist_dataset, batch_size, shuffle=True)

    for ep in range(1, epochs + 1):
        total_ep_loss = 0

        for batch_idx, (x, _) in enumerate(train_loader):
            x = x.to(vae.device).view(x.shape[0], -1)

            x_hat, mu, log_var = vae(x)
            batch_rec_loss = rec_loss(x, x_hat) / batch_size
            batch_kl_loss = kl_loss(mu, log_var)
            total_loss = batch_rec_loss + kl_weighting(ep) * batch_kl_loss

            optimizer.zero_grad()
            total_loss.backward()
            optimizer.step()

            if batch_idx % 10 == 0:
                print('TRAINING BATCH:\t({:5} / {:5})\tREC LOSS:\t{:2.3f}\tKL LOSS:\t{:2.3f}'
                      .format(batch_idx, num_train_batches, float(batch_rec_loss), float(batch_kl_loss)), end='\r')

            total_ep_loss += float(total_loss)

        train_losses.append(total_ep_loss / num_train_batches)
        print('EPOCH:\t{:5}\tTRAIN LOSS:\t{:.3f}\tKL WEIGHT:\t{:.2f}'
              .format(ep, train_losses[-1], kl_weighting(ep), end='\r'))

    return train_losses

# %%
latent_size = 8
epochs = 15
batch_size = 128


encoder = (
    Encoder(input_size=784, latent_size=8)
)

decoder = (
    Decoder(output_size=784, latent_size=8)
)

vae = (
    VAE(
        encoder=encoder,
        decoder=decoder,
        device=torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    )
)

optimizer = (
    Adam(vae.parameters())
)

losses = train_autoencoder(vae, optimizer, train_x, epochs, batch_size)
# Out:
# TRAINING BATCH:	(    0 /   469)	REC LOSS:	181.792	KL LOSS:	0.013
# TRAINING BATCH:	(   10 /   469)	REC LOSS:	146.947	KL LOSS:	0.244
# TRAINING BATCH:	(   30 /   469)	REC LOSS:	54.902	KL LOSS:	1.726
# TRAINING BATCH:	(   40 /   469)	REC LOSS:	53.918	KL LOSS:	0.225
# TRAINING BATCH:	(   60 /   469)	REC LOSS:	54.554	KL LOSS:	0.028
# TRAINING BATCH:	(   70 /   469)	REC LOSS:	53.668	KL LOSS:	0.146
# TRAINING BATCH:	(   90 /   469)	REC LOSS:	54.221	KL LOSS:	0.731
# TRAINING BATCH:	(  100 /   469)	REC LOSS:	53.313	KL LOSS:	0.916
# TRAINING BATCH:	(  120 /   469)	REC LOSS:	51.827	KL LOSS:	1.491
# TRAINING BATCH:	(  130 /   469)	REC LOSS:	52.406	KL LOSS:	2.265
# TRAINING BATCH:	(  150 /   469)	REC LOSS:	52.226	KL LOSS:	2.215
# TRAINING BATCH:	(  160 /   469)	REC LOSS:	50.985	KL LOSS:	2.697
# TRAINING BATCH:	(  180 /   469)	REC LOSS:	48.950	KL LOSS:	3.375
# TRAINING BATCH:	(  190 /   469)	REC LOSS:	50.802	KL LOSS:	3.020
# TRAINING BATCH:	(  210 /   469)	REC LOSS:	48.509	KL LOSS:	3.337
# TRAINING BATCH:	(  220 /   469)	REC LOSS:	49.121	KL LOSS:	2.375
# TRAINING BATCH:	(  240 /   469)	REC LOSS:	51.349	KL LOSS:	3.603
# TRAINING BATCH:	(  250 /   469)	REC LOSS:	48.116	KL LOSS:	3.619
# TRAINING BATCH:	(  270 /   469)	REC LOSS:	51.176	KL LOSS:	3.685
# TRAINING BATCH:	(  280 /   469)	REC LOSS:	50.409	KL LOSS:	3.331
# TRAINING BATCH:	(  300 /   469)	REC LOSS:	48.146	KL LOSS:	3.876
# TRAINING BATCH:	(  310 /   469)	REC LOSS:	47.297	KL LOSS:	4.059
# TRAINING BATCH:	(  330 /   469)	REC LOSS:	48.072	KL LOSS:	3.998
# TRAINING BATCH:	(  340 /   469)	REC LOSS:	46.711	KL LOSS:	3.765
# TRAINING BATCH:	(  360 /   469)	REC LOSS:	49.353	KL LOSS:	3.942
# TRAINING BATCH:	(  370 /   469)	REC LOSS:	47.966	KL LOSS:	3.777
# TRAINING BATCH:	(  390 /   469)	REC LOSS:	48.896	KL LOSS:	3.784
# TRAINING BATCH:	(  400 /   469)	REC LOSS:	48.319	KL LOSS:	3.883
# TRAINING BATCH:	(  420 /   469)	REC LOSS:	48.629	KL LOSS:	4.193
# TRAINING BATCH:	(  430 /   469)	REC LOSS:	46.070	KL LOSS:	5.104
# TRAINING BATCH:	(  450 /   469)	REC LOSS:	48.401	KL LOSS:	4.954
# TRAINING BATCH:	(  460 /   469)	REC LOSS:	48.547	KL LOSS:	4.578
# EPOCH:	    1	TRAIN LOSS:	54.465	KL WEIGHT:	0.20
# TRAINING BATCH:	(   10 /   469)	REC LOSS:	46.126	KL LOSS:	3.809
# TRAINING BATCH:	(   20 /   469)	REC LOSS:	48.762	KL LOSS:	3.501
# TRAINING BATCH:	(   40 /   469)	REC LOSS:	46.877	KL LOSS:	3.284
# TRAINING BATCH:	(   50 /   469)	REC LOSS:	45.840	KL LOSS:	3.577
# TRAINING BATCH:	(   70 /   469)	REC LOSS:	47.502	KL LOSS:	3.356
# TRAINING BATCH:	(   80 /   469)	REC LOSS:	47.376	KL LOSS:	3.010
# TRAINING BATCH:	(  100 /   469)	REC LOSS:	48.933	KL LOSS:	3.277
# TRAINING BATCH:	(  110 /   469)	REC LOSS:	46.549	KL LOSS:	3.856
# TRAINING BATCH:	(  130 /   469)	REC LOSS:	47.950	KL LOSS:	3.112
# TRAINING BATCH:	(  140 /   469)	REC LOSS:	45.625	KL LOSS:	3.369
# TRAINING BATCH:	(  160 /   469)	REC LOSS:	43.912	KL LOSS:	3.903
# TRAINING BATCH:	(  170 /   469)	REC LOSS:	45.911	KL LOSS:	3.374
# TRAINING BATCH:	(  190 /   469)	REC LOSS:	44.642	KL LOSS:	3.465
# TRAINING BATCH:	(  200 /   469)	REC LOSS:	43.119	KL LOSS:	4.323
# TRAINING BATCH:	(  220 /   469)	REC LOSS:	44.648	KL LOSS:	3.584
# TRAINING BATCH:	(  230 /   469)	REC LOSS:	46.263	KL LOSS:	3.397
# TRAINING BATCH:	(  250 /   469)	REC LOSS:	42.953	KL LOSS:	4.378
# TRAINING BATCH:	(  260 /   469)	REC LOSS:	45.002	KL LOSS:	3.463
# TRAINING BATCH:	(  280 /   469)	REC LOSS:	43.414	KL LOSS:	3.927
# TRAINING BATCH:	(  290 /   469)	REC LOSS:	47.280	KL LOSS:	3.935
# TRAINING BATCH:	(  310 /   469)	REC LOSS:	45.678	KL LOSS:	3.664
# TRAINING BATCH:	(  320 /   469)	REC LOSS:	44.973	KL LOSS:	4.531
# TRAINING BATCH:	(  340 /   469)	REC LOSS:	43.564	KL LOSS:	4.187
# TRAINING BATCH:	(  350 /   469)	REC LOSS:	44.113	KL LOSS:	4.018
# TRAINING BATCH:	(  370 /   469)	REC LOSS:	43.708	KL LOSS:	3.944
# TRAINING BATCH:	(  380 /   469)	REC LOSS:	42.877	KL LOSS:	3.874
# TRAINING BATCH:	(  400 /   469)	REC LOSS:	42.844	KL LOSS:	4.305
# TRAINING BATCH:	(  410 /   469)	REC LOSS:	42.368	KL LOSS:	4.275
# TRAINING BATCH:	(  430 /   469)	REC LOSS:	42.589	KL LOSS:	4.843
# TRAINING BATCH:	(  440 /   469)	REC LOSS:	40.374	KL LOSS:	4.380
# TRAINING BATCH:	(  460 /   469)	REC LOSS:	42.596	KL LOSS:	4.357
# EPOCH:	    2	TRAIN LOSS:	46.314	KL WEIGHT:	0.40
# TRAINING BATCH:	(    0 /   469)	REC LOSS:	42.143	KL LOSS:	4.572
# TRAINING BATCH:	(   10 /   469)	REC LOSS:	42.349	KL LOSS:	4.182
# TRAINING BATCH:	(   20 /   469)	REC LOSS:	42.031	KL LOSS:	4.097
# TRAINING BATCH:	(   30 /   469)	REC LOSS:	43.636	KL LOSS:	3.627
# TRAINING BATCH:	(   40 /   469)	REC LOSS:	39.748	KL LOSS:	3.952
# TRAINING BATCH:	(   60 /   469)	REC LOSS:	39.836	KL LOSS:	4.550
# TRAINING BATCH:	(   70 /   469)	REC LOSS:	44.796	KL LOSS:	3.911
# TRAINING BATCH:	(   90 /   469)	REC LOSS:	41.138	KL LOSS:	3.495
# TRAINING BATCH:	(  100 /   469)	REC LOSS:	41.460	KL LOSS:	3.829
# TRAINING BATCH:	(  110 /   469)	REC LOSS:	41.269	KL LOSS:	4.037
# TRAINING BATCH:	(  130 /   469)	REC LOSS:	42.172	KL LOSS:	3.915
# TRAINING BATCH:	(  140 /   469)	REC LOSS:	41.223	KL LOSS:	4.296
# TRAINING BATCH:	(  160 /   469)	REC LOSS:	41.408	KL LOSS:	3.923
# TRAINING BATCH:	(  170 /   469)	REC LOSS:	40.741	KL LOSS:	4.022
# TRAINING BATCH:	(  190 /   469)	REC LOSS:	40.595	KL LOSS:	4.143
# TRAINING BATCH:	(  200 /   469)	REC LOSS:	42.036	KL LOSS:	4.710
# TRAINING BATCH:	(  220 /   469)	REC LOSS:	40.172	KL LOSS:	4.122
# TRAINING BATCH:	(  230 /   469)	REC LOSS:	37.733	KL LOSS:	4.642
# TRAINING BATCH:	(  240 /   469)	REC LOSS:	39.336	KL LOSS:	4.244
# TRAINING BATCH:	(  250 /   469)	REC LOSS:	39.481	KL LOSS:	4.168
# TRAINING BATCH:	(  260 /   469)	REC LOSS:	39.641	KL LOSS:	4.167
# TRAINING BATCH:	(  270 /   469)	REC LOSS:	39.336	KL LOSS:	4.266
# TRAINING BATCH:	(  280 /   469)	REC LOSS:	40.626	KL LOSS:	4.261
# TRAINING BATCH:	(  290 /   469)	REC LOSS:	39.153	KL LOSS:	4.372
# TRAINING BATCH:	(  300 /   469)	REC LOSS:	40.395	KL LOSS:	4.405
# TRAINING BATCH:	(  310 /   469)	REC LOSS:	39.291	KL LOSS:	4.290
# TRAINING BATCH:	(  320 /   469)	REC LOSS:	39.546	KL LOSS:	4.555
# TRAINING BATCH:	(  330 /   469)	REC LOSS:	40.747	KL LOSS:	4.678
# TRAINING BATCH:	(  350 /   469)	REC LOSS:	40.803	KL LOSS:	4.742
# TRAINING BATCH:	(  360 /   469)	REC LOSS:	38.446	KL LOSS:	4.669
# TRAINING BATCH:	(  370 /   469)	REC LOSS:	38.343	KL LOSS:	4.490
# TRAINING BATCH:	(  380 /   469)	REC LOSS:	39.285	KL LOSS:	4.473
# TRAINING BATCH:	(  390 /   469)	REC LOSS:	41.570	KL LOSS:	4.524
# TRAINING BATCH:	(  400 /   469)	REC LOSS:	40.053	KL LOSS:	4.551
# TRAINING BATCH:	(  410 /   469)	REC LOSS:	39.154	KL LOSS:	4.430
# TRAINING BATCH:	(  420 /   469)	REC LOSS:	38.284	KL LOSS:	4.439
# TRAINING BATCH:	(  430 /   469)	REC LOSS:	38.989	KL LOSS:	4.327
# TRAINING BATCH:	(  450 /   469)	REC LOSS:	39.683	KL LOSS:	4.342
# TRAINING BATCH:	(  460 /   469)	REC LOSS:	36.811	KL LOSS:	4.787
# EPOCH:	    3	TRAIN LOSS:	42.973	KL WEIGHT:	0.60
# TRAINING BATCH:	(   10 /   469)	REC LOSS:	38.291	KL LOSS:	4.219
# TRAINING BATCH:	(   40 /   469)	REC LOSS:	39.433	KL LOSS:	4.029
# TRAINING BATCH:	(   70 /   469)	REC LOSS:	37.774	KL LOSS:	4.379
# TRAINING BATCH:	(  100 /   469)	REC LOSS:	37.638	KL LOSS:	4.288
# TRAINING BATCH:	(  130 /   469)	REC LOSS:	39.086	KL LOSS:	4.051
# TRAINING BATCH:	(  160 /   469)	REC LOSS:	40.998	KL LOSS:	4.253
# TRAINING BATCH:	(  190 /   469)	REC LOSS:	36.725	KL LOSS:	4.495
# TRAINING BATCH:	(  220 /   469)	REC LOSS:	37.778	KL LOSS:	4.351
# TRAINING BATCH:	(  250 /   469)	REC LOSS:	39.187	KL LOSS:	4.344
# TRAINING BATCH:	(  280 /   469)	REC LOSS:	38.206	KL LOSS:	4.329
# TRAINING BATCH:	(  310 /   469)	REC LOSS:	34.743	KL LOSS:	4.567
# TRAINING BATCH:	(  340 /   469)	REC LOSS:	38.053	KL LOSS:	4.259
# TRAINING BATCH:	(  370 /   469)	REC LOSS:	37.477	KL LOSS:	4.936
# TRAINING BATCH:	(  400 /   469)	REC LOSS:	37.381	KL LOSS:	4.536
# TRAINING BATCH:	(  430 /   469)	REC LOSS:	36.145	KL LOSS:	5.025
# TRAINING BATCH:	(  460 /   469)	REC LOSS:	37.665	KL LOSS:	4.346
# EPOCH:	    4	TRAIN LOSS:	41.813	KL WEIGHT:	0.80
# TRAINING BATCH:	(   20 /   469)	REC LOSS:	39.445	KL LOSS:	3.896
# TRAINING BATCH:	(   50 /   469)	REC LOSS:	36.141	KL LOSS:	4.657
# TRAINING BATCH:	(   80 /   469)	REC LOSS:	37.739	KL LOSS:	4.017
# TRAINING BATCH:	(  110 /   469)	REC LOSS:	38.406	KL LOSS:	4.283
# TRAINING BATCH:	(  140 /   469)	REC LOSS:	38.862	KL LOSS:	4.016
# TRAINING BATCH:	(  170 /   469)	REC LOSS:	37.707	KL LOSS:	4.205
# TRAINING BATCH:	(  190 /   469)	REC LOSS:	36.397	KL LOSS:	4.245
# TRAINING BATCH:	(  220 /   469)	REC LOSS:	38.610	KL LOSS:	4.551
# TRAINING BATCH:	(  240 /   469)	REC LOSS:	34.836	KL LOSS:	4.139
# TRAINING BATCH:	(  270 /   469)	REC LOSS:	37.745	KL LOSS:	4.335
# TRAINING BATCH:	(  300 /   469)	REC LOSS:	37.497	KL LOSS:	4.206
# TRAINING BATCH:	(  320 /   469)	REC LOSS:	35.211	KL LOSS:	4.314
# TRAINING BATCH:	(  350 /   469)	REC LOSS:	35.233	KL LOSS:	4.541
# TRAINING BATCH:	(  380 /   469)	REC LOSS:	37.754	KL LOSS:	4.385
# TRAINING BATCH:	(  410 /   469)	REC LOSS:	35.544	KL LOSS:	4.488
# TRAINING BATCH:	(  440 /   469)	REC LOSS:	37.898	KL LOSS:	4.171
# EPOCH:	    5	TRAIN LOSS:	41.555	KL WEIGHT:	1.00
# TRAINING BATCH:	(    0 /   469)	REC LOSS:	38.247	KL LOSS:	4.323
# TRAINING BATCH:	(   30 /   469)	REC LOSS:	35.830	KL LOSS:	4.285
# TRAINING BATCH:	(   60 /   469)	REC LOSS:	36.694	KL LOSS:	4.348
# TRAINING BATCH:	(   90 /   469)	REC LOSS:	35.747	KL LOSS:	4.601
# TRAINING BATCH:	(  120 /   469)	REC LOSS:	35.896	KL LOSS:	4.346
# TRAINING BATCH:	(  150 /   469)	REC LOSS:	36.434	KL LOSS:	4.534
# TRAINING BATCH:	(  180 /   469)	REC LOSS:	34.741	KL LOSS:	4.642
# TRAINING BATCH:	(  210 /   469)	REC LOSS:	38.403	KL LOSS:	4.382
# TRAINING BATCH:	(  240 /   469)	REC LOSS:	34.949	KL LOSS:	4.389
# TRAINING BATCH:	(  260 /   469)	REC LOSS:	35.207	KL LOSS:	4.091
# TRAINING BATCH:	(  290 /   469)	REC LOSS:	33.977	KL LOSS:	4.604
# TRAINING BATCH:	(  310 /   469)	REC LOSS:	36.609	KL LOSS:	4.610
# TRAINING BATCH:	(  330 /   469)	REC LOSS:	35.714	KL LOSS:	4.562
# TRAINING BATCH:	(  360 /   469)	REC LOSS:	34.026	KL LOSS:	4.497
# TRAINING BATCH:	(  380 /   469)	REC LOSS:	38.614	KL LOSS:	4.299
# TRAINING BATCH:	(  400 /   469)	REC LOSS:	37.346	KL LOSS:	4.462
# TRAINING BATCH:	(  430 /   469)	REC LOSS:	36.380	KL LOSS:	4.539
# TRAINING BATCH:	(  460 /   469)	REC LOSS:	37.237	KL LOSS:	4.429
# EPOCH:	    6	TRAIN LOSS:	40.828	KL WEIGHT:	1.00
# TRAINING BATCH:	(   20 /   469)	REC LOSS:	34.893	KL LOSS:	4.435
# TRAINING BATCH:	(   50 /   469)	REC LOSS:	38.010	KL LOSS:	4.450
# TRAINING BATCH:	(   80 /   469)	REC LOSS:	35.928	KL LOSS:	4.704
# TRAINING BATCH:	(  110 /   469)	REC LOSS:	37.523	KL LOSS:	4.635
# TRAINING BATCH:	(  140 /   469)	REC LOSS:	34.499	KL LOSS:	4.363
# TRAINING BATCH:	(  170 /   469)	REC LOSS:	34.577	KL LOSS:	4.668
# TRAINING BATCH:	(  200 /   469)	REC LOSS:	37.997	KL LOSS:	4.362
# TRAINING BATCH:	(  230 /   469)	REC LOSS:	37.167	KL LOSS:	4.259
# TRAINING BATCH:	(  260 /   469)	REC LOSS:	36.494	KL LOSS:	4.474
# TRAINING BATCH:	(  290 /   469)	REC LOSS:	34.540	KL LOSS:	4.515
# TRAINING BATCH:	(  320 /   469)	REC LOSS:	35.002	KL LOSS:	4.657
# TRAINING BATCH:	(  350 /   469)	REC LOSS:	35.421	KL LOSS:	4.300
# TRAINING BATCH:	(  380 /   469)	REC LOSS:	36.239	KL LOSS:	4.318
# TRAINING BATCH:	(  410 /   469)	REC LOSS:	35.625	KL LOSS:	4.515
# TRAINING BATCH:	(  440 /   469)	REC LOSS:	35.274	KL LOSS:	4.549
# EPOCH:	    7	TRAIN LOSS:	40.455	KL WEIGHT:	1.00
# TRAINING BATCH:	(    0 /   469)	REC LOSS:	33.344	KL LOSS:	4.760
# TRAINING BATCH:	(   30 /   469)	REC LOSS:	37.325	KL LOSS:	4.351
# TRAINING BATCH:	(   60 /   469)	REC LOSS:	34.824	KL LOSS:	4.655
# TRAINING BATCH:	(   90 /   469)	REC LOSS:	34.685	KL LOSS:	4.565
# TRAINING BATCH:	(  120 /   469)	REC LOSS:	37.439	KL LOSS:	4.336
# TRAINING BATCH:	(  150 /   469)	REC LOSS:	35.093	KL LOSS:	4.819
# TRAINING BATCH:	(  180 /   469)	REC LOSS:	36.021	KL LOSS:	4.585
# TRAINING BATCH:	(  210 /   469)	REC LOSS:	35.667	KL LOSS:	4.578
# TRAINING BATCH:	(  240 /   469)	REC LOSS:	35.273	KL LOSS:	4.564
# TRAINING BATCH:	(  270 /   469)	REC LOSS:	37.809	KL LOSS:	4.269
# TRAINING BATCH:	(  290 /   469)	REC LOSS:	35.605	KL LOSS:	4.482
# TRAINING BATCH:	(  310 /   469)	REC LOSS:	35.067	KL LOSS:	4.421
# TRAINING BATCH:	(  330 /   469)	REC LOSS:	38.378	KL LOSS:	4.413
# TRAINING BATCH:	(  360 /   469)	REC LOSS:	35.990	KL LOSS:	4.599
# TRAINING BATCH:	(  390 /   469)	REC LOSS:	36.222	KL LOSS:	4.575
# TRAINING BATCH:	(  420 /   469)	REC LOSS:	33.348	KL LOSS:	4.622
# TRAINING BATCH:	(  440 /   469)	REC LOSS:	35.036	KL LOSS:	4.821
# EPOCH:	    8	TRAIN LOSS:	39.986	KL WEIGHT:	1.00
# TRAINING BATCH:	(    0 /   469)	REC LOSS:	33.548	KL LOSS:	4.791
# TRAINING BATCH:	(   30 /   469)	REC LOSS:	36.271	KL LOSS:	4.592
# TRAINING BATCH:	(   60 /   469)	REC LOSS:	35.747	KL LOSS:	4.683
# TRAINING BATCH:	(   90 /   469)	REC LOSS:	35.471	KL LOSS:	4.567
# TRAINING BATCH:	(  120 /   469)	REC LOSS:	36.947	KL LOSS:	4.396
# TRAINING BATCH:	(  140 /   469)	REC LOSS:	34.932	KL LOSS:	4.677
# TRAINING BATCH:	(  170 /   469)	REC LOSS:	35.585	KL LOSS:	4.584
# TRAINING BATCH:	(  200 /   469)	REC LOSS:	35.030	KL LOSS:	4.654
# TRAINING BATCH:	(  220 /   469)	REC LOSS:	35.035	KL LOSS:	4.808
# TRAINING BATCH:	(  250 /   469)	REC LOSS:	33.456	KL LOSS:	4.719
# TRAINING BATCH:	(  280 /   469)	REC LOSS:	36.149	KL LOSS:	4.421
# TRAINING BATCH:	(  310 /   469)	REC LOSS:	35.629	KL LOSS:	4.714
# TRAINING BATCH:	(  330 /   469)	REC LOSS:	36.724	KL LOSS:	4.556
# TRAINING BATCH:	(  360 /   469)	REC LOSS:	36.876	KL LOSS:	4.776
# TRAINING BATCH:	(  380 /   469)	REC LOSS:	35.043	KL LOSS:	4.838
# TRAINING BATCH:	(  410 /   469)	REC LOSS:	33.936	KL LOSS:	4.649
# TRAINING BATCH:	(  440 /   469)	REC LOSS:	36.973	KL LOSS:	4.656
# EPOCH:	    9	TRAIN LOSS:	39.772	KL WEIGHT:	1.00
# TRAINING BATCH:	(    0 /   469)	REC LOSS:	32.980	KL LOSS:	4.844
# TRAINING BATCH:	(   30 /   469)	REC LOSS:	32.206	KL LOSS:	4.875
# TRAINING BATCH:	(   60 /   469)	REC LOSS:	33.373	KL LOSS:	4.822
# TRAINING BATCH:	(   90 /   469)	REC LOSS:	34.507	KL LOSS:	4.704
# TRAINING BATCH:	(  120 /   469)	REC LOSS:	36.247	KL LOSS:	4.516
# TRAINING BATCH:	(  150 /   469)	REC LOSS:	35.330	KL LOSS:	4.751
# TRAINING BATCH:	(  180 /   469)	REC LOSS:	35.048	KL LOSS:	4.645
# TRAINING BATCH:	(  210 /   469)	REC LOSS:	33.368	KL LOSS:	4.777
# TRAINING BATCH:	(  240 /   469)	REC LOSS:	35.332	KL LOSS:	4.688
# TRAINING BATCH:	(  270 /   469)	REC LOSS:	35.783	KL LOSS:	4.743
# TRAINING BATCH:	(  300 /   469)	REC LOSS:	33.634	KL LOSS:	4.744
# TRAINING BATCH:	(  330 /   469)	REC LOSS:	33.736	KL LOSS:	4.876
# TRAINING BATCH:	(  360 /   469)	REC LOSS:	37.022	KL LOSS:	4.481
# TRAINING BATCH:	(  390 /   469)	REC LOSS:	34.647	KL LOSS:	4.712
# TRAINING BATCH:	(  420 /   469)	REC LOSS:	32.741	KL LOSS:	4.815
# TRAINING BATCH:	(  450 /   469)	REC LOSS:	33.943	KL LOSS:	4.871
# EPOCH:	   10	TRAIN LOSS:	39.412	KL WEIGHT:	1.00
# TRAINING BATCH:	(   10 /   469)	REC LOSS:	35.172	KL LOSS:	4.820
# TRAINING BATCH:	(   40 /   469)	REC LOSS:	33.665	KL LOSS:	4.828
# TRAINING BATCH:	(   70 /   469)	REC LOSS:	33.824	KL LOSS:	4.738
# TRAINING BATCH:	(  100 /   469)	REC LOSS:	33.481	KL LOSS:	4.945
# TRAINING BATCH:	(  130 /   469)	REC LOSS:	35.485	KL LOSS:	4.789
# TRAINING BATCH:	(  160 /   469)	REC LOSS:	34.928	KL LOSS:	4.697
# TRAINING BATCH:	(  190 /   469)	REC LOSS:	34.101	KL LOSS:	4.963
# TRAINING BATCH:	(  220 /   469)	REC LOSS:	33.503	KL LOSS:	4.822
# TRAINING BATCH:	(  250 /   469)	REC LOSS:	33.598	KL LOSS:	4.994
# TRAINING BATCH:	(  280 /   469)	REC LOSS:	36.249	KL LOSS:	4.760
# TRAINING BATCH:	(  310 /   469)	REC LOSS:	36.268	KL LOSS:	4.501
# TRAINING BATCH:	(  340 /   469)	REC LOSS:	34.406	KL LOSS:	4.758
# TRAINING BATCH:	(  370 /   469)	REC LOSS:	35.798	KL LOSS:	4.830
# TRAINING BATCH:	(  400 /   469)	REC LOSS:	37.176	KL LOSS:	4.618
# TRAINING BATCH:	(  430 /   469)	REC LOSS:	34.422	KL LOSS:	4.712
# TRAINING BATCH:	(  460 /   469)	REC LOSS:	34.058	KL LOSS:	4.896
# EPOCH:	   11	TRAIN LOSS:	39.148	KL WEIGHT:	1.00
# TRAINING BATCH:	(   20 /   469)	REC LOSS:	33.922	KL LOSS:	5.062
# TRAINING BATCH:	(   40 /   469)	REC LOSS:	32.397	KL LOSS:	5.095
# TRAINING BATCH:	(   60 /   469)	REC LOSS:	34.450	KL LOSS:	4.523
# TRAINING BATCH:	(   90 /   469)	REC LOSS:	33.741	KL LOSS:	5.063
# TRAINING BATCH:	(  120 /   469)	REC LOSS:	33.396	KL LOSS:	4.818
# TRAINING BATCH:	(  150 /   469)	REC LOSS:	36.279	KL LOSS:	4.939
# TRAINING BATCH:	(  180 /   469)	REC LOSS:	32.406	KL LOSS:	4.756
# TRAINING BATCH:	(  210 /   469)	REC LOSS:	35.344	KL LOSS:	4.911
# TRAINING BATCH:	(  240 /   469)	REC LOSS:	33.451	KL LOSS:	5.190
# TRAINING BATCH:	(  270 /   469)	REC LOSS:	33.996	KL LOSS:	4.830
# TRAINING BATCH:	(  290 /   469)	REC LOSS:	33.298	KL LOSS:	5.003
# TRAINING BATCH:	(  310 /   469)	REC LOSS:	34.666	KL LOSS:	5.028
# TRAINING BATCH:	(  330 /   469)	REC LOSS:	33.650	KL LOSS:	4.956
# TRAINING BATCH:	(  350 /   469)	REC LOSS:	32.925	KL LOSS:	5.013
# TRAINING BATCH:	(  370 /   469)	REC LOSS:	34.803	KL LOSS:	4.849
# TRAINING BATCH:	(  390 /   469)	REC LOSS:	34.020	KL LOSS:	4.985
# TRAINING BATCH:	(  410 /   469)	REC LOSS:	33.197	KL LOSS:	5.100
# TRAINING BATCH:	(  430 /   469)	REC LOSS:	34.155	KL LOSS:	4.941
# TRAINING BATCH:	(  460 /   469)	REC LOSS:	33.359	KL LOSS:	4.832
# EPOCH:	   12	TRAIN LOSS:	38.815	KL WEIGHT:	1.00
# TRAINING BATCH:	(   20 /   469)	REC LOSS:	32.900	KL LOSS:	4.718
# TRAINING BATCH:	(   50 /   469)	REC LOSS:	33.362	KL LOSS:	4.884
# TRAINING BATCH:	(   80 /   469)	REC LOSS:	31.740	KL LOSS:	5.082
# TRAINING BATCH:	(  110 /   469)	REC LOSS:	33.960	KL LOSS:	5.094
# TRAINING BATCH:	(  140 /   469)	REC LOSS:	32.857	KL LOSS:	4.875
# TRAINING BATCH:	(  170 /   469)	REC LOSS:	31.118	KL LOSS:	4.973
# TRAINING BATCH:	(  200 /   469)	REC LOSS:	34.681	KL LOSS:	4.825
# TRAINING BATCH:	(  230 /   469)	REC LOSS:	34.516	KL LOSS:	4.861
# TRAINING BATCH:	(  250 /   469)	REC LOSS:	32.298	KL LOSS:	4.942
# TRAINING BATCH:	(  280 /   469)	REC LOSS:	32.992	KL LOSS:	4.920
# TRAINING BATCH:	(  310 /   469)	REC LOSS:	33.083	KL LOSS:	4.949
# TRAINING BATCH:	(  340 /   469)	REC LOSS:	32.913	KL LOSS:	4.929
# TRAINING BATCH:	(  370 /   469)	REC LOSS:	32.109	KL LOSS:	5.056
# TRAINING BATCH:	(  400 /   469)	REC LOSS:	33.792	KL LOSS:	4.744
# TRAINING BATCH:	(  430 /   469)	REC LOSS:	32.035	KL LOSS:	4.894
# TRAINING BATCH:	(  460 /   469)	REC LOSS:	35.582	KL LOSS:	4.813
# EPOCH:	   13	TRAIN LOSS:	38.658	KL WEIGHT:	1.00
# TRAINING BATCH:	(   10 /   469)	REC LOSS:	33.329	KL LOSS:	4.934
# TRAINING BATCH:	(   40 /   469)	REC LOSS:	32.913	KL LOSS:	5.261
# TRAINING BATCH:	(   60 /   469)	REC LOSS:	33.900	KL LOSS:	5.087
# TRAINING BATCH:	(   80 /   469)	REC LOSS:	32.886	KL LOSS:	4.843
# TRAINING BATCH:	(  100 /   469)	REC LOSS:	32.985	KL LOSS:	4.808
# TRAINING BATCH:	(  110 /   469)	REC LOSS:	31.939	KL LOSS:	4.957
# TRAINING BATCH:	(  130 /   469)	REC LOSS:	32.720	KL LOSS:	5.028
# TRAINING BATCH:	(  160 /   469)	REC LOSS:	32.168	KL LOSS:	4.877
# TRAINING BATCH:	(  180 /   469)	REC LOSS:	33.022	KL LOSS:	4.906
# TRAINING BATCH:	(  200 /   469)	REC LOSS:	34.510	KL LOSS:	5.111
# TRAINING BATCH:	(  230 /   469)	REC LOSS:	30.759	KL LOSS:	4.854
# TRAINING BATCH:	(  260 /   469)	REC LOSS:	34.125	KL LOSS:	5.087
# TRAINING BATCH:	(  290 /   469)	REC LOSS:	34.003	KL LOSS:	5.026
# TRAINING BATCH:	(  320 /   469)	REC LOSS:	34.200	KL LOSS:	4.895
# TRAINING BATCH:	(  350 /   469)	REC LOSS:	31.498	KL LOSS:	5.138
# TRAINING BATCH:	(  380 /   469)	REC LOSS:	36.041	KL LOSS:	4.774
# TRAINING BATCH:	(  410 /   469)	REC LOSS:	33.111	KL LOSS:	4.878
# TRAINING BATCH:	(  440 /   469)	REC LOSS:	33.604	KL LOSS:	4.969
# EPOCH:	   14	TRAIN LOSS:	38.325	KL WEIGHT:	1.00
# TRAINING BATCH:	(    0 /   469)	REC LOSS:	32.010	KL LOSS:	4.901
# TRAINING BATCH:	(   30 /   469)	REC LOSS:	36.080	KL LOSS:	4.952
# TRAINING BATCH:	(   60 /   469)	REC LOSS:	34.171	KL LOSS:	4.930
# TRAINING BATCH:	(   90 /   469)	REC LOSS:	32.159	KL LOSS:	4.994
# TRAINING BATCH:	(  120 /   469)	REC LOSS:	30.783	KL LOSS:	5.044
# TRAINING BATCH:	(  150 /   469)	REC LOSS:	34.059	KL LOSS:	4.933
# TRAINING BATCH:	(  180 /   469)	REC LOSS:	34.877	KL LOSS:	4.966
# TRAINING BATCH:	(  210 /   469)	REC LOSS:	32.377	KL LOSS:	5.173
# TRAINING BATCH:	(  240 /   469)	REC LOSS:	32.565	KL LOSS:	5.087
# TRAINING BATCH:	(  270 /   469)	REC LOSS:	30.967	KL LOSS:	5.186
# TRAINING BATCH:	(  300 /   469)	REC LOSS:	34.046	KL LOSS:	5.043
# TRAINING BATCH:	(  330 /   469)	REC LOSS:	33.475	KL LOSS:	4.989
# TRAINING BATCH:	(  360 /   469)	REC LOSS:	34.162	KL LOSS:	5.095
# TRAINING BATCH:	(  390 /   469)	REC LOSS:	31.629	KL LOSS:	5.272
# TRAINING BATCH:	(  420 /   469)	REC LOSS:	34.430	KL LOSS:	4.928
# TRAINING BATCH:	(  450 /   469)	REC LOSS:	32.337	KL LOSS:	5.026
# EPOCH:	   15	TRAIN LOSS:	38.098	KL WEIGHT:	1.00

# %%
plot_reconstruction_grid(vae, train_x)

# %% [markdown]
# It seems like we don't suffer from posterior collaps and our reconstructions look rather
# good. It has been shown, that choosing KL weights larger than one can lead to overall
# better representations with the downside of worse reconstructions. This framework is
# found in literatures as $\beta$-VAE. The correct choice of the KL weight is a difficult
# one and depends on the distribution of your dataset and also its dimensionality.
#
# With a VAE we also have a generative model. We could e.g. sample zs from a uniform range
# and see what the generator will reconstruct:

# %%
rand_z = torch.rand((100, latent_size), device=vae.device)
generated_samples = vae.reconstruct(rand_z).view(100, 1, 28, 28).detach().cpu()

image_grid = make_grid(generated_samples, nrow=25)
plt.imshow(image_grid.permute(1, 2, 0))
plt.axis('off')
plt.show()

# %% [markdown]
# We can also use the generative decoder to smoothly interpolate between random samples:
# (Execute the cell a few times to see the interpolation between other random digits)

# %%
def interpolate_linear(x: Tensor, y: Tensor, steps: int,) -> Tensor:
    cur_weight = 0.0
    weight_incr = 1 / (steps - 1)

    result = torch.zeros((steps, *x.shape))
    if x.is_cuda:
        result = result.cuda()

    for step in range(steps):
        result[step] = torch.lerp(x, y, cur_weight)
        cur_weight += weight_incr

    return result

x_one = train_x.data[torch.randint(0, 60000, (1,))] / 255.
z_one = vae.encode(x_one.view(1, -1).to(vae.device))

x_two = train_x.data[torch.randint(0, 60000, (1,))] / 255.
z_two = vae.encode(x_two.view(1, -1).to(vae.device))

zs = interpolate_linear(z_one, z_two, steps=20)
x_hats = vae.reconstruct(zs).view(20, 1, 28, 28).detach().cpu()

image_grid = make_grid(x_hats, nrow=20)
plt.imshow(image_grid.permute(1, 2, 0))
plt.axis('off')
plt.show()
