# %% [markdown]
# # Lab 9
#
# ## Imports

# %%
import string
from collections import Counter
from math import ceil
from typing import List, Optional, Tuple, Dict
import random

import matplotlib.pyplot as plt
import torch
from matplotlib_inline.backend_inline import set_matplotlib_formats
from torch import nn, Tensor
from torch.nn.utils.rnn import pad_sequence
from torch.optim import Adam, Optimizer
from torch.utils.data import DataLoader, Dataset
from keras.datasets import imdb
from torchvision.datasets import MNIST
from torchvision.utils import make_grid

set_matplotlib_formats('png', 'pdf')
# Out:
# 2025-07-16 11:44:45.191099: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-16 11:44:45.219403: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-07-16 11:44:45.667086: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Exercise 1
#
# In this exercise, we are going to revise the sentiment classifier for IMDB reviews we
# developed in a previous lab. Earlier, we encoded each review as a single "bag-of-words"
# vector which had one element for each word in our dictionary set to one if that word was
# found in the review, zero otherwise. This allowed us to use a simple fully-connected
# neural network but, on the flip side, we lost all information contained in the ordering
# and of the words and possible multiple repetitions. Recurrent neural networks, however,
# are able to process reviews directly. Let's see how!
#
# The first step is to load the data and preprocess it like it in exercise 6, so if you
# still remember what we did there, feel free to skip this part.
# For brevity, we only use the 10000 most common words
# and truncate reviews to 250 words, but if you can use a GPU then feel free to
# use the full length reviews and all words!

# %%
(train_x, train_y), (test_x, test_y) = imdb.load_data(num_words=10000)
train_x = [train_x[i] for i in range(len(train_x))]
train_y = [train_y[i] for i in range(len(train_y))]
test_x = [test_x[i] for i in range(len(test_x))]
test_y = [test_y[i] for i in range(len(test_y))]

word2enc = imdb.get_word_index()
enc2word = {v: k for k, v in word2enc.items()}

# %%
test_id = random.randint(0, len(train_x) - 1)
print(f"Sentiment: {'Positive' if train_y[test_id] == 1 else 'Negative'}")
print("Review:")
print(" ".join([enc2word[enc+3] for enc in train_x[test_id]]))
# Out:
# Sentiment: Positive
# Review:
# of less discovers quick aggressive that it give released overcome can used have far short not br off i br i've in it interesting being not 5 i discovers br truly works that coming special not it used have looking actress one much perhaps but town support to for movie 10 both day it's br several please long br whatsoever rave all die on get on br third masterpiece back he br extreme turns with watch perhaps as br joe major in really lucky as br uniformly mostly but very i br new wall all be young 2nd as than moment his wasn't down movie 10 both day it's br several please i look assure i less discovers br things in filmmakers by remember least would you those shot scenes in on it guy with their matter small movie i've this 5 i br stars asking in fantasy third re

# %%
# Discard words that are not in the top 10000
# Truncate sequences to a length of 250
# Remove Nones

def filter_word_ranks(
        word_list: List[Optional[int]],
        max_rank: int = 10000,
        max_seq_len: int = 250
) -> List[int]:
    output = []
    seq_len = 0
    for word_rank in word_list:
        if seq_len >= max_seq_len:
            return output
        elif word_rank is None:
            continue
        elif word_rank <= max_rank:
            output.append(word_rank)
            seq_len += 1
    return output


train_x = [filter_word_ranks(word_list) for word_list in train_x]
test_x = [filter_word_ranks(word_list) for word_list in test_x]

# %% [markdown]
# Now, each review is a list of numbers, each corresponding to a different word:

# %%
print(train_x[0])
# Out:
# [1, 14, 22, 16, 43, 530, 973, 1622, 1385, 65, 458, 4468, 66, 3941, 4, 173, 36, 256, 5, 25, 100, 43, 838, 112, 50, 670, 2, 9, 35, 480, 284, 5, 150, 4, 172, 112, 167, 2, 336, 385, 39, 4, 172, 4536, 1111, 17, 546, 38, 13, 447, 4, 192, 50, 16, 6, 147, 2025, 19, 14, 22, 4, 1920, 4613, 469, 4, 22, 71, 87, 12, 16, 43, 530, 38, 76, 15, 13, 1247, 4, 22, 17, 515, 17, 12, 16, 626, 18, 2, 5, 62, 386, 12, 8, 316, 8, 106, 5, 4, 2223, 5244, 16, 480, 66, 3785, 33, 4, 130, 12, 16, 38, 619, 5, 25, 124, 51, 36, 135, 48, 25, 1415, 33, 6, 22, 12, 215, 28, 77, 52, 5, 14, 407, 16, 82, 2, 8, 4, 107, 117, 5952, 15, 256, 4, 2, 7, 3766, 5, 723, 36, 71, 43, 530, 476, 26, 400, 317, 46, 7, 4, 2, 1029, 13, 104, 88, 4, 381, 15, 297, 98, 32, 2071, 56, 26, 141, 6, 194, 7486, 18, 4, 226, 22, 21, 134, 476, 26, 480, 5, 144, 30, 5535, 18, 51, 36, 28, 224, 92, 25, 104, 4, 226, 65, 16, 38, 1334, 88, 12, 16, 283, 5, 16, 4472, 113, 103, 32, 15, 16, 5345, 19, 178, 32]

# %% [markdown]
# Even though RNNs can process sequences of arbitrary length, all sequences in the same
# batch must be of the same length, while sequences in different batches can have different
# length. In this case, however, we pad all sequences to the same length as this makes for
# much simpler code.
# PyTorch provides a function to do so for you called `pad_sequence` (read the documentation!).
# Hint: It might be good to set the argument `batch_first` to `True.
# Beforehand, we need to convert the data to tensors. Let's also define our device and push
# the newly created padded tensor to it.

# %%
device = (
    torch.device('cuda' if torch.cuda.is_available() else 'cpu')
)

train_x = [torch.tensor(word_list, dtype=torch.int) for word_list in train_x]
test_x = [torch.tensor(word_list, dtype=torch.int) for word_list in test_x]

train_x = (
    pad_sequence(train_x, batch_first=True).to(device)
)

test_x = (
    pad_sequence(test_x, batch_first=True).to(device)
)

train_y = torch.tensor(train_y, dtype=torch.float, device=device)
test_y = torch.tensor(test_y, dtype=torch.float, device=device)

# %%
print(train_x.shape)
# Out:
# torch.Size([25000, 250])

# %% [markdown]
# The data is now an array of shape `(num_samples x seq_len)`.
# A PyTorch RNN with `batch_first=True` option expects the input to be of shape
# `(num_samples x seq_len x features)`. Although we have a univariate timeseries, we still
# need to add this additional last dimension.

# %%
train_x = (
    train_x.unsqueeze(-1)
)

test_x = (
    test_x.unsqueeze(-1)
)

# %% [markdown]
# Finally let's create our `IMDBDataset` object:

# %%
class IMDBDataset(Dataset):
    def __init__(self, data: Tensor, labels: Tensor):
        self.data = data
        self.labels = labels

    @property
    def shape(self) -> Tuple:
        return self.data.shape

    def __len__(self) -> int:
        return len(self.labels)

    def __getitem__(self, idx: int) -> Tuple[Tensor, Tensor]:
        return self.data[idx], self.labels[idx]

# %% [markdown]
# Next, we define our sequential model. The first layer is an _Embedding_ layer that
# associates a vector of numbers to each word in the vocabulary. These numbers are updated
# during training just like all other weights in the network. Crucially, thanks to this
# embedding layer we do not have to one-hot-encode the reviews but we can use the word
# indices directly, making the process much more efficient.
#
# Note the parameter `padding_idx`: this indicates that zeros in the input sequences are
# used for padding (verify that this is the case!). Internally, this is used by the RNN to
# ignore padding tokens, preventing them from contributing to the gradients (read more in
# the user guide, [link](https://pytorch.org/docs/stable/generated/torch.nn.Embedding.html/)!)
#
# We also make use of a `nn.Module` container, where we will define our model. This
# gives us more flexibility in the flow of the network. Here we add the model blocks
# as class attributes and define a forward pass, which is enough for the autograd engine.
#
# The shapes and dimensions of tensors can now be a bit tricky. It helps if you print
# the resulting shape of each transformation to console and investigate what happened!

# %%
class LSTMModel(nn.Module):
    def __init__(self):
        # A class that inherits from nn.Module needs to call the constructor from the
        # parent class
        super().__init__()

        self.embedding = nn.Embedding(
            num_embeddings=10001,
            embedding_dim=64,
            padding_idx=0
        )
        self.lstm = nn.LSTM(
            input_size=64,
            hidden_size=32,
            num_layers=2,
            batch_first=True
        )

        self.fc = nn.Linear(in_features=32, out_features=1)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x: Tensor) -> Tensor:
        # The output needs to be reshaped or otherwise we have a dimension too much.
        x = self.embedding(x).squeeze(2)

        # The LSTM module gives a variety of outputs. Please refer to the official
        # docs for a detailed description. Here `hidden` contains the final hidden states
        # from the last layer for every sample in the batch.
        _, (hidden, _) = self.lstm(x)

        # We need to extract the last hidden state
        y_score = self.fc(hidden[-1])
        y_hat = self.sigmoid(y_score).squeeze(-1)
        return y_hat

# %% [markdown]
# In the next step, we once again need our beloved training loop.

# %%
def train(
        model: nn.Module,
        loss: nn.Module,
        optimizer: Optimizer,
        train_dataset: Dataset,
        test_dataset: Dataset,
        epochs: int,
        batch_size: int
) -> Dict:
    metrics: Dict = {
        'train_loss': [],
        'train_acc': [],
        'test_loss': [],
        'test_acc': [],
    }

    num_train_batches = ceil(len(train_dataset) / batch_size)
    num_test_batches = ceil(len(test_dataset) / batch_size)

    train_loader = DataLoader(train_dataset, batch_size, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size)

    for ep in range(1, epochs + 1):
        total_loss = 0
        num_correct = 0

        ################################################################################
        # TRAINING LOOP
        ################################################################################

        for batch_idx, (x, y) in enumerate(train_loader):

            y_hat = model(x)
            batch_loss = loss(y_hat, y)

            optimizer.zero_grad()
            batch_loss.backward()
            optimizer.step()

            # if batch_idx % 10 == 0:
            #     print('TRAINING BATCH:\t({:5} / {:5})\tLOSS:\t{:.3f}'
            #           .format(batch_idx, num_train_batches, float(batch_loss)),
            #           end='\r')

            total_loss += float(batch_loss)
            num_correct += int(torch.sum(torch.where(y_hat > 0.5, 1, 0) == y))

        ep_train_loss = total_loss / len(train_dataset)
        ep_train_acc = num_correct / len(train_dataset)

        total_loss = 0
        num_correct = 0

        ################################################################################
        # TEST LOOP
        ################################################################################

        for batch_idx, (x, y) in enumerate(test_loader):
            with torch.no_grad(): 
                y_hat = model(x)
                batch_loss = loss(y_hat, y)

            # if batch_idx % 50 == 0:
            #     print('TEST BATCH:\t({:5} / {:5})\tLOSS:\t{:.3f}'
            #           .format(batch_idx, num_test_batches, float(batch_loss)), end='\r')

            total_loss += float(batch_loss)
            num_correct += int(torch.sum(torch.where(y_hat > 0.5, 1, 0) == y))

        ep_test_loss = total_loss / len(test_dataset)
        ep_test_acc = num_correct / len(test_dataset)

        metrics['train_loss'].append(ep_train_loss)
        metrics['train_acc'].append(ep_train_acc)
        metrics['test_loss'].append(ep_test_loss)
        metrics['test_acc'].append(ep_test_acc)

        print('EPOCH:\t{:5}\tTRAIN LOSS:\t{:.3f}\tTRAIN ACCURACY:\t{:.3f}\tTEST LOSS:\t'
              '{:.3f}\tTEST ACCURACY:\t{:.3f}'
              .format(ep, ep_train_loss, ep_train_acc, ep_test_loss, ep_test_acc))
    return metrics

# %% [markdown]
# We declare model, optimizer, datasets, loss, epochs, batch size and then start training!

# %%
epochs = 10
batch_size = 32

model = (
    LSTMModel().to(device)
)

optimizer = (
    Adam(model.parameters(), lr=5e-3)
)

loss = (
    nn.BCELoss()
)

train_dataset = (
    IMDBDataset(train_x, train_y)
)

test_dataset = (
    IMDBDataset(test_x, test_y)
)

metrics = train(model, loss, optimizer, train_dataset, test_dataset, epochs, batch_size)
# Out:
# EPOCH:	    1	TRAIN LOSS:	0.022	TRAIN ACCURACY:	0.511	TEST LOSS:	0.022	TEST ACCURACY:	0.503
# EPOCH:	    2	TRAIN LOSS:	0.019	TRAIN ACCURACY:	0.670	TEST LOSS:	0.017	TEST ACCURACY:	0.745
# EPOCH:	    3	TRAIN LOSS:	0.014	TRAIN ACCURACY:	0.797	TEST LOSS:	0.015	TEST ACCURACY:	0.782
# EPOCH:	    4	TRAIN LOSS:	0.011	TRAIN ACCURACY:	0.854	TEST LOSS:	0.012	TEST ACCURACY:	0.828
# EPOCH:	    5	TRAIN LOSS:	0.008	TRAIN ACCURACY:	0.900	TEST LOSS:	0.012	TEST ACCURACY:	0.837
# EPOCH:	    6	TRAIN LOSS:	0.006	TRAIN ACCURACY:	0.929	TEST LOSS:	0.013	TEST ACCURACY:	0.845
# EPOCH:	    7	TRAIN LOSS:	0.004	TRAIN ACCURACY:	0.956	TEST LOSS:	0.015	TEST ACCURACY:	0.844
# EPOCH:	    8	TRAIN LOSS:	0.003	TRAIN ACCURACY:	0.970	TEST LOSS:	0.015	TEST ACCURACY:	0.845
# EPOCH:	    9	TRAIN LOSS:	0.002	TRAIN ACCURACY:	0.978	TEST LOSS:	0.017	TEST ACCURACY:	0.843
# EPOCH:	   10	TRAIN LOSS:	0.002	TRAIN ACCURACY:	0.980	TEST LOSS:	0.017	TEST ACCURACY:	0.838

# %%
def get_training_progress_plot(
        train_losses: List[float],
        train_accs: List[float],
        val_losses: List[float],
        val_accs: List[float],
) -> None:
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(7, 2))

    ax1.set_title('Loss')
    ax1.plot(train_losses, label='Train Loss')
    ax1.plot(val_losses, label='Test Loss')
    ax1.legend()

    ax2.set_title('Accuracy')
    ax2.plot(train_accs, label='Train Accuracy')
    ax2.plot(val_accs, label='Test Accuracy')
    ax2.set_ylim(0, 1)
    ax2.legend()


get_training_progress_plot(
    metrics['train_loss'],
    metrics['train_acc'],
    metrics['test_loss'],
    metrics['test_acc'],
)

# %% [markdown]
# The model seems to be learning more easily than the simple baseline we created time ago,
# which had an accuracy of 85-88% on the test data.
# Let it train for longer and tune the
# architecture above to reach as high accuracy as possible! (note that evaluating on the
# same data that you used for early stopping is cheating). Can you detect other problems we discussed in the previous labs?
#
#
# ## Exercise 2
#
# In this exercise, we are going to build a model that is able to sum two numbers, each given as a sequence
# of images of handwritten digits. The network will first use a convolutional encoder to transform each
# digit into a feature vector. These feature vectors will then be processed by a LSTM that will produce as
# output each digit of the sum.
#
# ### Dataset
# We are now going to create a synthetic dataset using images from MNIST.
#
# First, we define some auxiliary functions.
# We need a function that converts an integer to a padded tensor.

# %%
def convert_int_to_vector(num: int, length: int) -> Tensor:
    """
    Take an integer and convert it to a vector.

    Example: 123 with a length of 3 returns a tensor with [1, 2, 3].
    5 with a length of 3 returns [0, 0, 5]
    """
    num_str = str(num).zfill(length)
    return torch.tensor([int(n) for n in num_str])

# %% [markdown]
# Then, we need a function that generates our training labels.
# The result of the function should be a dictionary that contains 3 tensors (first numbers, second numbers, sum of first + second) of shape `(num_samples, max_length)`.
# We need the summands for drawing matching images later, while the latter is our actual label.

# %%
def generate_labels(num_samples: int, max_length: int) -> Dict:
    """
    Generate random numbers, whose sum does not exceed maximum length.

    We will pad numbers that are less than max_length with zeros.
    """

    num_1s = []
    num_2s = []
    sums = []

    for _ in range(num_samples):

        # Ensure the sum always has at most max_len digits
        num_1 = torch.randint(10**max_length // 2 - 1, (1,))
        num_2 = torch.randint(10**max_length // 2 - 1, (1,))

        num_1s.append(convert_int_to_vector(int(num_1), max_length))
        num_2s.append(convert_int_to_vector(int(num_2), max_length))

        sums.append(convert_int_to_vector(int(num_1 + num_2), max_length))

    return {
        'num_1': torch.stack(num_1s),
        'num_2': torch.stack(num_2s),
        'sum': torch.stack(sums)
    }

# %% [markdown]
# For our training, we need our `Dataset` object. Here, we will also draw the images to create our input tensors. One image is of shape `(1 x 28 x 28)`.
# Thus, a constructed input tensor is of shape `(max_length x 1 x 28 x 28)`

# %%
class NumberMNIST(Dataset):
    def __init__(
            self,
            max_length: int = 3,
            train: bool = True
    ) -> None:
        mnist_base = MNIST('.data', train=train, download=True)
        mnist_base.data = mnist_base.data.float() / 255

        self.max_length = max_length
        # We choose 20k samples for training and 5k for testing.
        self.num_samples = 20000 if train else 5000
        self.digit_idxs = NumberMNIST._generate_digit_groups(mnist_base.targets)

        self.labels = generate_labels(self.num_samples, self.max_length)

        self.num_1s = torch.zeros(self.num_samples, self.max_length, 1, 28, 28)
        self.num_2s = torch.zeros(self.num_samples, self.max_length, 1, 28, 28)

        for i in range(self.num_samples):

            imgs = []
            for num_1_digit in self.labels['num_1'][i]:
                # Get corresponding index group
                digit_idxs = self.digit_idxs[int(num_1_digit)]
                # Sample a random index from the digit class
                rand_idx = digit_idxs[torch.randint(len(digit_idxs), (1, ))]
                # Obtain image for the sampled index
                imgs.append(mnist_base.data[rand_idx])
            # Add images to main tensor.
            self.num_1s[i] = torch.stack(imgs)

            imgs = []
            for num_2_digit in self.labels['num_2'][i]:
                digit_idxs = self.digit_idxs[int(num_2_digit)]
                rand_idx = digit_idxs[torch.randint(len(digit_idxs), (1, ))]
                imgs.append(mnist_base.data[rand_idx])
            self.num_2s[i] = torch.stack(imgs)



    @staticmethod
    def _generate_digit_groups(targets: Tensor) -> Dict:
        """Separates the dataset in groups based on the label. Returns a Dict with indices."""
        res = {}
        for i in range(10):
            idxs = (targets == i).nonzero().squeeze(-1)
            res.update({i: idxs})
        return res

    @property
    def shape(self) -> Tuple:
        return self.data.shape

    def __len__(self) -> int:
        return len(self.num_1s)

    def __getitem__(self, idx: int) -> Dict:
        return {
            'num_1': self.num_1s[idx],
            'num_2': self.num_2s[idx],
            'label': self.labels['sum'][idx],
        }

# %% [markdown]
# Let's initialize our datasets and see if everything works as expected.

# %%
train_dataset = NumberMNIST(train=True, max_length=3)
test_dataset = NumberMNIST(train=False, max_length=3)

# %%
def plot_digits(num_1: Tensor, num_2: Tensor) -> None:
    grid_img = make_grid(torch.cat([num_1, num_2]), nrow=3)
    plt.imshow(grid_img.permute(1, 2, 0))
    plt.show()

idx = int(torch.randint(len(test_dataset), (1,)))
sample = test_dataset[idx]

print('Sum:', [int(i) for i in sample['label']])
plot_digits(sample['num_1'], sample['num_2'])
# Out:
# Sum: [5, 8, 3]

# %% [markdown]
# ### The model
#
# Let's now see how to create the model.
#
# This network will have two inputs, one for each number. The numbers have three digits, each of which is an image of size 1 x 28 x 28.

# %%
class AdditionModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.latent_dim = 128

        # The network will use the same convolutional encoder for all digits in both numbers.
        # Let us first define this encoder as its own submodule, a normal CNN:

        self.digit_encoder = nn.Sequential(
            nn.Conv2d(1, 32, (3, 3)),
            nn.ReLU(),
            nn.MaxPool2d((2, 2)),
            nn.Conv2d(32, 64, (3, 3)),
            nn.ReLU(),
            nn.MaxPool2d((2, 2)),
            nn.Conv2d(64, self.latent_dim, (3, 3)),
            nn.ReLU(),
            nn.MaxPool2d((2, 2)),
            nn.AdaptiveAvgPool2d((1, 1))
        )

        # Our second model in this szenario will be a bidrectional LSTM.
        # The input for this model are the concatenated latent vectors that we obtained from
        # the digit encoder.
        # For flexibility, we do not use a sequential but have the final layers as single attributes in this module class.

        # Let's also apply a bit of dropout to prevent overfitting too much.
        self.dropout = (
            nn.Dropout(0.3)
        )

        self.lstm = (
            nn.LSTM(
                input_size=self.latent_dim * 2,
                hidden_size=64,
                batch_first=True,
                bidirectional=True
            )
        )

        # Finally, we add a fully connected layer as output.
        # Note that the input size of the linear layer should be twice the hidden size
        # of the LSTM (bidirectional).
        self.fc = (
            nn.Linear(128, 10)
        )


    def forward(self, num_1: Tensor, num_2: Tensor) -> Tensor:
        # Note: num_1 and num_2 are of shape (batch_size x max_length x 1 x 28 x 28)
        batch_size = num_1.shape[0]
        max_length = num_1.shape[1]

        enc_1 = torch.zeros(batch_size, max_length, self.latent_dim, device=num_1.device)
        enc_2 = torch.zeros(batch_size, max_length, self.latent_dim, device=num_1.device)
        for i in range(max_length):
            enc_1[:, i] = self.digit_encoder(num_1[:, i]).view(batch_size, -1)
            enc_2[:, i] = self.digit_encoder(num_2[:, i]).view(batch_size, -1)

        # After we apply the CNN to both numbers, we need to "merge" the two sequence of vectors.
        # There are several options here, here we choose to concatenate the two tensor in each time-step
        # to produce a single tensor of shape (batch_size, max_len, latent_dim * 2).
        enc_total = (
            torch.cat([enc_1, enc_2], dim=2)
        )

        # Now, we pass the total encoded tensor through the dropout, lstm and output layer.
        enc_total = self.dropout(enc_total)

        # We obtain all hidden states from each timestep resulting in a tensor of shape (batch_size, max_length, lstm_hidden_dim)
        out, _ = self.lstm(enc_total)
        # Due to broadcasting, we can feed this tensor directly to the fully connected layer.
        out = self.fc(out)
        # Our loss function does accept a tensor of shape (batch_size, num_classes, max_length)
        # So we reshape before returning the network output.
        return out.permute(0, 2, 1)

# %% [markdown]
# We can mainly reuse the training loop from the exercise before, but we need to change the computation of the accuracy and dataloading.
# Let's initialize our modules and start training!

# %%
device = (
    torch.device('cuda' if torch.cuda.is_available() else 'cpu')
)

def train(
        model: AdditionModel,
        loss: nn.Module,
        optimizer: Optimizer,
        train_dataset: Dataset,
        test_dataset: Dataset,
        epochs: int,
        batch_size: int
) -> Dict:
    metrics: Dict = {
        'train_loss': [],
        'train_acc': [],
        'test_loss': [],
        'test_acc': [],
    }

    num_train_batches = ceil(len(train_dataset) / batch_size)
    num_test_batches = ceil(len(test_dataset) / batch_size)

    train_loader = DataLoader(train_dataset, batch_size, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size)

    for ep in range(1, epochs + 1):
        total_loss = 0
        num_correct = 0

        ################################################################################
        # TRAINING LOOP
        ################################################################################

        for batch_idx, sample in enumerate(train_loader):

            num_1 = sample['num_1'].to(device)
            num_2 = sample['num_2'].to(device)
            y = sample['label'].to(device)


            y_hat = model(num_1, num_2)
            batch_loss = loss(y_hat, y)

            optimizer.zero_grad()
            batch_loss.backward()
            optimizer.step()

            if batch_idx % 10 == 0:
                print('TRAINING BATCH:\t({:5} / {:5})\tLOSS:\t{:.3f}'
                      .format(batch_idx, num_train_batches, float(batch_loss)),
                      end='\r')

            total_loss += float(batch_loss)

            num_correct += int(torch.sum(torch.all(torch.eq(torch.argmax(y_hat, dim=1), y), dim=1)))

        ep_train_loss = total_loss / len(train_dataset)
        ep_train_acc = num_correct / len(train_dataset)

        total_loss = 0
        num_correct = 0

        ################################################################################
        # TEST LOOP
        ################################################################################

        for batch_idx, sample in enumerate(test_loader):
            num_1 = sample['num_1'].to(device)
            num_2 = sample['num_2'].to(device)
            y = sample['label'].to(device)

            with torch.no_grad():
                y_hat = model(num_1, num_2)
                batch_loss = loss(y_hat, y)

            if batch_idx % 50 == 0:
                print('TEST BATCH:\t({:5} / {:5})\tLOSS:\t{:.3f}'
                      .format(batch_idx, num_test_batches, float(batch_loss)), end='\r')

            total_loss += float(batch_loss)

            num_correct += int(torch.sum(torch.all(torch.eq(torch.argmax(y_hat, dim=1), y), dim=1)))

        ep_test_loss = total_loss / len(test_dataset)
        ep_test_acc = num_correct / len(test_dataset)

        metrics['train_loss'].append(ep_train_loss)
        metrics['train_acc'].append(ep_train_acc)
        metrics['test_loss'].append(ep_test_loss)
        metrics['test_acc'].append(ep_test_acc)

        print('EPOCH:\t{:5}\tTRAIN LOSS:\t{:.3f}\tTRAIN ACCURACY:\t{:.3f}\tTEST LOSS:\t'
              '{:.3f}\tTEST ACCURACY:\t{:.3f}'
              .format(ep, ep_train_loss, ep_train_acc, ep_test_loss, ep_test_acc))
    return metrics

# %% [markdown]
# Let's initialize our modules and start training!

# %%
epochs = 20
batch_size = 32

model = (
    AdditionModel().to(device)
)

optimizer = (
    Adam(model.parameters())
)

loss = (
    nn.CrossEntropyLoss()
)

metrics = train(model, loss, optimizer, train_dataset, test_dataset, epochs, batch_size)
# Out:
# TRAINING BATCH:	(    0 /   625)	LOSS:	2.289
# TRAINING BATCH:	(   10 /   625)	LOSS:	2.283
# TRAINING BATCH:	(   20 /   625)	LOSS:	2.320
# TRAINING BATCH:	(   30 /   625)	LOSS:	2.268
# TRAINING BATCH:	(   40 /   625)	LOSS:	2.306
# TRAINING BATCH:	(   50 /   625)	LOSS:	2.257
# TRAINING BATCH:	(   60 /   625)	LOSS:	2.238
# TRAINING BATCH:	(   70 /   625)	LOSS:	2.284
# TRAINING BATCH:	(   80 /   625)	LOSS:	2.295
# TRAINING BATCH:	(   90 /   625)	LOSS:	2.275
# TRAINING BATCH:	(  100 /   625)	LOSS:	2.248
# TRAINING BATCH:	(  110 /   625)	LOSS:	2.299
# TRAINING BATCH:	(  120 /   625)	LOSS:	2.238
# TRAINING BATCH:	(  130 /   625)	LOSS:	2.226
# TRAINING BATCH:	(  140 /   625)	LOSS:	2.244
# TRAINING BATCH:	(  150 /   625)	LOSS:	2.274
# TRAINING BATCH:	(  160 /   625)	LOSS:	2.255
# TRAINING BATCH:	(  170 /   625)	LOSS:	2.258
# TRAINING BATCH:	(  180 /   625)	LOSS:	2.240
# TRAINING BATCH:	(  190 /   625)	LOSS:	2.250
# TRAINING BATCH:	(  200 /   625)	LOSS:	2.197
# TRAINING BATCH:	(  210 /   625)	LOSS:	2.179
# TRAINING BATCH:	(  220 /   625)	LOSS:	2.144
# TRAINING BATCH:	(  230 /   625)	LOSS:	2.178
# TRAINING BATCH:	(  240 /   625)	LOSS:	2.159
# TRAINING BATCH:	(  250 /   625)	LOSS:	2.137
# TRAINING BATCH:	(  260 /   625)	LOSS:	2.062
# TRAINING BATCH:	(  270 /   625)	LOSS:	2.048
# TRAINING BATCH:	(  280 /   625)	LOSS:	2.050
# TRAINING BATCH:	(  290 /   625)	LOSS:	2.002
# TRAINING BATCH:	(  300 /   625)	LOSS:	1.991
# TRAINING BATCH:	(  310 /   625)	LOSS:	1.936
# TRAINING BATCH:	(  320 /   625)	LOSS:	1.910
# TRAINING BATCH:	(  330 /   625)	LOSS:	1.856
# TRAINING BATCH:	(  340 /   625)	LOSS:	1.825
# TRAINING BATCH:	(  350 /   625)	LOSS:	1.896
# TRAINING BATCH:	(  360 /   625)	LOSS:	1.898
# TRAINING BATCH:	(  370 /   625)	LOSS:	1.700
# TRAINING BATCH:	(  380 /   625)	LOSS:	1.782
# TRAINING BATCH:	(  390 /   625)	LOSS:	1.817
# TRAINING BATCH:	(  400 /   625)	LOSS:	1.735
# TRAINING BATCH:	(  410 /   625)	LOSS:	1.689
# TRAINING BATCH:	(  420 /   625)	LOSS:	1.667
# TRAINING BATCH:	(  430 /   625)	LOSS:	1.811
# TRAINING BATCH:	(  440 /   625)	LOSS:	1.814
# TRAINING BATCH:	(  450 /   625)	LOSS:	1.584
# TRAINING BATCH:	(  460 /   625)	LOSS:	1.721
# TRAINING BATCH:	(  470 /   625)	LOSS:	1.526
# TRAINING BATCH:	(  480 /   625)	LOSS:	1.631
# TRAINING BATCH:	(  490 /   625)	LOSS:	1.490
# TRAINING BATCH:	(  500 /   625)	LOSS:	1.501
# TRAINING BATCH:	(  510 /   625)	LOSS:	1.573
# TRAINING BATCH:	(  520 /   625)	LOSS:	1.565
# TRAINING BATCH:	(  530 /   625)	LOSS:	1.426
# TRAINING BATCH:	(  540 /   625)	LOSS:	1.525
# TRAINING BATCH:	(  550 /   625)	LOSS:	1.450
# TRAINING BATCH:	(  560 /   625)	LOSS:	1.327
# TRAINING BATCH:	(  570 /   625)	LOSS:	1.467
# TRAINING BATCH:	(  580 /   625)	LOSS:	1.576
# TRAINING BATCH:	(  590 /   625)	LOSS:	1.432
# TRAINING BATCH:	(  600 /   625)	LOSS:	1.557
# TRAINING BATCH:	(  610 /   625)	LOSS:	1.277
# TRAINING BATCH:	(  620 /   625)	LOSS:	1.280
# TEST BATCH:	(    0 /   157)	LOSS:	1.178
# TEST BATCH:	(   50 /   157)	LOSS:	1.369
# TEST BATCH:	(  100 /   157)	LOSS:	1.272
# EPOCH:	    1	TRAIN LOSS:	0.060	TRAIN ACCURACY:	0.029	TEST LOSS:	0.042	TEST ACCURACY:	0.123
# TRAINING BATCH:	(    0 /   625)	LOSS:	1.406
# TRAINING BATCH:	(   10 /   625)	LOSS:	1.397
# TRAINING BATCH:	(   20 /   625)	LOSS:	1.231
# TRAINING BATCH:	(   30 /   625)	LOSS:	1.231
# TRAINING BATCH:	(   40 /   625)	LOSS:	1.252
# TRAINING BATCH:	(   50 /   625)	LOSS:	1.281
# TRAINING BATCH:	(   60 /   625)	LOSS:	1.189
# TRAINING BATCH:	(   70 /   625)	LOSS:	1.339
# TRAINING BATCH:	(   80 /   625)	LOSS:	1.263
# TRAINING BATCH:	(   90 /   625)	LOSS:	1.205
# TRAINING BATCH:	(  100 /   625)	LOSS:	1.228
# TRAINING BATCH:	(  110 /   625)	LOSS:	1.232
# TRAINING BATCH:	(  120 /   625)	LOSS:	1.128
# TRAINING BATCH:	(  130 /   625)	LOSS:	1.033
# TRAINING BATCH:	(  140 /   625)	LOSS:	1.120
# TRAINING BATCH:	(  150 /   625)	LOSS:	1.166
# TRAINING BATCH:	(  160 /   625)	LOSS:	1.191
# TRAINING BATCH:	(  170 /   625)	LOSS:	1.029
# TRAINING BATCH:	(  180 /   625)	LOSS:	1.170
# TRAINING BATCH:	(  190 /   625)	LOSS:	1.182
# TRAINING BATCH:	(  200 /   625)	LOSS:	1.120
# TRAINING BATCH:	(  210 /   625)	LOSS:	0.986
# TRAINING BATCH:	(  220 /   625)	LOSS:	1.079
# TRAINING BATCH:	(  230 /   625)	LOSS:	1.323
# TRAINING BATCH:	(  240 /   625)	LOSS:	1.041
# TRAINING BATCH:	(  250 /   625)	LOSS:	0.967
# TRAINING BATCH:	(  260 /   625)	LOSS:	1.020
# TRAINING BATCH:	(  270 /   625)	LOSS:	0.987
# TRAINING BATCH:	(  280 /   625)	LOSS:	1.176
# TRAINING BATCH:	(  290 /   625)	LOSS:	0.919
# TRAINING BATCH:	(  300 /   625)	LOSS:	1.071
# TRAINING BATCH:	(  310 /   625)	LOSS:	1.057
# TRAINING BATCH:	(  320 /   625)	LOSS:	1.097
# TRAINING BATCH:	(  330 /   625)	LOSS:	1.002
# TRAINING BATCH:	(  340 /   625)	LOSS:	1.045
# TRAINING BATCH:	(  350 /   625)	LOSS:	0.927
# TRAINING BATCH:	(  360 /   625)	LOSS:	0.957
# TRAINING BATCH:	(  370 /   625)	LOSS:	0.859
# TRAINING BATCH:	(  380 /   625)	LOSS:	0.820
# TRAINING BATCH:	(  390 /   625)	LOSS:	0.934
# TRAINING BATCH:	(  400 /   625)	LOSS:	1.025
# TRAINING BATCH:	(  410 /   625)	LOSS:	0.823
# TRAINING BATCH:	(  420 /   625)	LOSS:	1.047
# TRAINING BATCH:	(  430 /   625)	LOSS:	0.992
# TRAINING BATCH:	(  440 /   625)	LOSS:	0.960
# TRAINING BATCH:	(  450 /   625)	LOSS:	1.000
# TRAINING BATCH:	(  460 /   625)	LOSS:	0.856
# TRAINING BATCH:	(  470 /   625)	LOSS:	0.921
# TRAINING BATCH:	(  480 /   625)	LOSS:	0.918
# TRAINING BATCH:	(  490 /   625)	LOSS:	0.819
# TRAINING BATCH:	(  500 /   625)	LOSS:	0.858
# TRAINING BATCH:	(  510 /   625)	LOSS:	0.881
# TRAINING BATCH:	(  520 /   625)	LOSS:	0.719
# TRAINING BATCH:	(  530 /   625)	LOSS:	0.786
# TRAINING BATCH:	(  540 /   625)	LOSS:	0.880
# TRAINING BATCH:	(  550 /   625)	LOSS:	0.860
# TRAINING BATCH:	(  560 /   625)	LOSS:	0.937
# TRAINING BATCH:	(  570 /   625)	LOSS:	0.736
# TRAINING BATCH:	(  580 /   625)	LOSS:	0.807
# TRAINING BATCH:	(  590 /   625)	LOSS:	0.845
# TRAINING BATCH:	(  600 /   625)	LOSS:	0.759
# TRAINING BATCH:	(  610 /   625)	LOSS:	0.849
# TRAINING BATCH:	(  620 /   625)	LOSS:	0.787
# TEST BATCH:	(    0 /   157)	LOSS:	0.569
# TEST BATCH:	(   50 /   157)	LOSS:	0.833
# TEST BATCH:	(  100 /   157)	LOSS:	0.579
# EPOCH:	    2	TRAIN LOSS:	0.032	TRAIN ACCURACY:	0.257	TEST LOSS:	0.024	TEST ACCURACY:	0.420
# TRAINING BATCH:	(    0 /   625)	LOSS:	0.785
# TRAINING BATCH:	(   10 /   625)	LOSS:	0.707
# TRAINING BATCH:	(   20 /   625)	LOSS:	0.821
# TRAINING BATCH:	(   30 /   625)	LOSS:	0.827
# TRAINING BATCH:	(   40 /   625)	LOSS:	0.738
# TRAINING BATCH:	(   50 /   625)	LOSS:	0.902
# TRAINING BATCH:	(   60 /   625)	LOSS:	0.654
# TRAINING BATCH:	(   70 /   625)	LOSS:	0.748
# TRAINING BATCH:	(   80 /   625)	LOSS:	0.726
# TRAINING BATCH:	(   90 /   625)	LOSS:	0.609
# TRAINING BATCH:	(  100 /   625)	LOSS:	0.832
# TRAINING BATCH:	(  110 /   625)	LOSS:	0.702
# TRAINING BATCH:	(  120 /   625)	LOSS:	0.748
# TRAINING BATCH:	(  130 /   625)	LOSS:	0.689
# TRAINING BATCH:	(  140 /   625)	LOSS:	0.758
# TRAINING BATCH:	(  150 /   625)	LOSS:	0.804
# TRAINING BATCH:	(  160 /   625)	LOSS:	0.606
# TRAINING BATCH:	(  170 /   625)	LOSS:	0.571
# TRAINING BATCH:	(  180 /   625)	LOSS:	0.905
# TRAINING BATCH:	(  190 /   625)	LOSS:	0.839
# TRAINING BATCH:	(  200 /   625)	LOSS:	0.726
# TRAINING BATCH:	(  210 /   625)	LOSS:	0.608
# TRAINING BATCH:	(  220 /   625)	LOSS:	0.775
# TRAINING BATCH:	(  230 /   625)	LOSS:	0.804
# TRAINING BATCH:	(  240 /   625)	LOSS:	0.640
# TRAINING BATCH:	(  250 /   625)	LOSS:	0.796
# TRAINING BATCH:	(  260 /   625)	LOSS:	0.634
# TRAINING BATCH:	(  270 /   625)	LOSS:	0.578
# TRAINING BATCH:	(  280 /   625)	LOSS:	0.548
# TRAINING BATCH:	(  290 /   625)	LOSS:	0.771
# TRAINING BATCH:	(  300 /   625)	LOSS:	0.597
# TRAINING BATCH:	(  310 /   625)	LOSS:	0.711
# TRAINING BATCH:	(  320 /   625)	LOSS:	0.766
# TRAINING BATCH:	(  330 /   625)	LOSS:	0.680
# TRAINING BATCH:	(  340 /   625)	LOSS:	0.552
# TRAINING BATCH:	(  350 /   625)	LOSS:	0.569
# TRAINING BATCH:	(  360 /   625)	LOSS:	0.706
# TRAINING BATCH:	(  370 /   625)	LOSS:	0.555
# TRAINING BATCH:	(  380 /   625)	LOSS:	0.559
# TRAINING BATCH:	(  390 /   625)	LOSS:	0.694
# TRAINING BATCH:	(  400 /   625)	LOSS:	0.597
# TRAINING BATCH:	(  410 /   625)	LOSS:	0.557
# TRAINING BATCH:	(  420 /   625)	LOSS:	0.498
# TRAINING BATCH:	(  430 /   625)	LOSS:	0.493
# TRAINING BATCH:	(  440 /   625)	LOSS:	0.515
# TRAINING BATCH:	(  450 /   625)	LOSS:	0.608
# TRAINING BATCH:	(  460 /   625)	LOSS:	0.610
# TRAINING BATCH:	(  470 /   625)	LOSS:	0.521
# TRAINING BATCH:	(  480 /   625)	LOSS:	0.416
# TRAINING BATCH:	(  490 /   625)	LOSS:	0.483
# TRAINING BATCH:	(  500 /   625)	LOSS:	0.591
# TRAINING BATCH:	(  510 /   625)	LOSS:	0.584
# TRAINING BATCH:	(  520 /   625)	LOSS:	0.523
# TRAINING BATCH:	(  530 /   625)	LOSS:	0.687
# TRAINING BATCH:	(  540 /   625)	LOSS:	0.574
# TRAINING BATCH:	(  550 /   625)	LOSS:	0.474
# TRAINING BATCH:	(  560 /   625)	LOSS:	0.432
# TRAINING BATCH:	(  570 /   625)	LOSS:	0.652
# TRAINING BATCH:	(  580 /   625)	LOSS:	0.540
# TRAINING BATCH:	(  590 /   625)	LOSS:	0.521
# TRAINING BATCH:	(  600 /   625)	LOSS:	0.602
# TRAINING BATCH:	(  610 /   625)	LOSS:	0.637
# TRAINING BATCH:	(  620 /   625)	LOSS:	0.414
# TEST BATCH:	(    0 /   157)	LOSS:	0.422
# TEST BATCH:	(   50 /   157)	LOSS:	0.516
# TEST BATCH:	(  100 /   157)	LOSS:	0.322
# EPOCH:	    3	TRAIN LOSS:	0.019	TRAIN ACCURACY:	0.524	TEST LOSS:	0.015	TEST ACCURACY:	0.636
# TRAINING BATCH:	(    0 /   625)	LOSS:	0.377
# TRAINING BATCH:	(   10 /   625)	LOSS:	0.455
# TRAINING BATCH:	(   20 /   625)	LOSS:	0.357
# TRAINING BATCH:	(   30 /   625)	LOSS:	0.402
# TRAINING BATCH:	(   40 /   625)	LOSS:	0.519
# TRAINING BATCH:	(   50 /   625)	LOSS:	0.413
# TRAINING BATCH:	(   60 /   625)	LOSS:	0.545
# TRAINING BATCH:	(   70 /   625)	LOSS:	0.401
# TRAINING BATCH:	(   80 /   625)	LOSS:	0.510
# TRAINING BATCH:	(   90 /   625)	LOSS:	0.444
# TRAINING BATCH:	(  100 /   625)	LOSS:	0.455
# TRAINING BATCH:	(  110 /   625)	LOSS:	0.395
# TRAINING BATCH:	(  120 /   625)	LOSS:	0.461
# TRAINING BATCH:	(  130 /   625)	LOSS:	0.498
# TRAINING BATCH:	(  140 /   625)	LOSS:	0.487
# TRAINING BATCH:	(  150 /   625)	LOSS:	0.460
# TRAINING BATCH:	(  160 /   625)	LOSS:	0.457
# TRAINING BATCH:	(  170 /   625)	LOSS:	0.353
# TRAINING BATCH:	(  180 /   625)	LOSS:	0.511
# TRAINING BATCH:	(  190 /   625)	LOSS:	0.458
# TRAINING BATCH:	(  200 /   625)	LOSS:	0.424
# TRAINING BATCH:	(  210 /   625)	LOSS:	0.542
# TRAINING BATCH:	(  220 /   625)	LOSS:	0.408
# TRAINING BATCH:	(  230 /   625)	LOSS:	0.388
# TRAINING BATCH:	(  240 /   625)	LOSS:	0.351
# TRAINING BATCH:	(  250 /   625)	LOSS:	0.458
# TRAINING BATCH:	(  260 /   625)	LOSS:	0.349
# TRAINING BATCH:	(  270 /   625)	LOSS:	0.509
# TRAINING BATCH:	(  280 /   625)	LOSS:	0.477
# TRAINING BATCH:	(  290 /   625)	LOSS:	0.519
# TRAINING BATCH:	(  300 /   625)	LOSS:	0.392
# TRAINING BATCH:	(  310 /   625)	LOSS:	0.404
# TRAINING BATCH:	(  320 /   625)	LOSS:	0.435
# TRAINING BATCH:	(  330 /   625)	LOSS:	0.408
# TRAINING BATCH:	(  340 /   625)	LOSS:	0.260
# TRAINING BATCH:	(  350 /   625)	LOSS:	0.472
# TRAINING BATCH:	(  360 /   625)	LOSS:	0.322
# TRAINING BATCH:	(  370 /   625)	LOSS:	0.384
# TRAINING BATCH:	(  380 /   625)	LOSS:	0.253
# TRAINING BATCH:	(  390 /   625)	LOSS:	0.306
# TRAINING BATCH:	(  400 /   625)	LOSS:	0.418
# TRAINING BATCH:	(  410 /   625)	LOSS:	0.395
# TRAINING BATCH:	(  420 /   625)	LOSS:	0.446
# TRAINING BATCH:	(  430 /   625)	LOSS:	0.425
# TRAINING BATCH:	(  440 /   625)	LOSS:	0.305
# TRAINING BATCH:	(  450 /   625)	LOSS:	0.403
# TRAINING BATCH:	(  460 /   625)	LOSS:	0.423
# TRAINING BATCH:	(  470 /   625)	LOSS:	0.381
# TRAINING BATCH:	(  480 /   625)	LOSS:	0.299
# TRAINING BATCH:	(  490 /   625)	LOSS:	0.367
# TRAINING BATCH:	(  500 /   625)	LOSS:	0.406
# TRAINING BATCH:	(  510 /   625)	LOSS:	0.445
# TRAINING BATCH:	(  520 /   625)	LOSS:	0.525
# TRAINING BATCH:	(  530 /   625)	LOSS:	0.332
# TRAINING BATCH:	(  540 /   625)	LOSS:	0.339
# TRAINING BATCH:	(  550 /   625)	LOSS:	0.408
# TRAINING BATCH:	(  560 /   625)	LOSS:	0.314
# TRAINING BATCH:	(  570 /   625)	LOSS:	0.457
# TRAINING BATCH:	(  580 /   625)	LOSS:	0.395
# TRAINING BATCH:	(  590 /   625)	LOSS:	0.336
# TRAINING BATCH:	(  600 /   625)	LOSS:	0.265
# TRAINING BATCH:	(  610 /   625)	LOSS:	0.393
# TRAINING BATCH:	(  620 /   625)	LOSS:	0.348
# TEST BATCH:	(    0 /   157)	LOSS:	0.307
# TEST BATCH:	(   50 /   157)	LOSS:	0.461
# TEST BATCH:	(  100 /   157)	LOSS:	0.290
# TEST BATCH:	(  150 /   157)	LOSS:	0.380
# EPOCH:	    4	TRAIN LOSS:	0.013	TRAIN ACCURACY:	0.697	TEST LOSS:	0.012	TEST ACCURACY:	0.739
# TRAINING BATCH:	(    0 /   625)	LOSS:	0.380
# TRAINING BATCH:	(   10 /   625)	LOSS:	0.255
# TRAINING BATCH:	(   20 /   625)	LOSS:	0.335
# TRAINING BATCH:	(   30 /   625)	LOSS:	0.396
# TRAINING BATCH:	(   40 /   625)	LOSS:	0.466
# TRAINING BATCH:	(   50 /   625)	LOSS:	0.270
# TRAINING BATCH:	(   60 /   625)	LOSS:	0.356
# TRAINING BATCH:	(   70 /   625)	LOSS:	0.330
# TRAINING BATCH:	(   80 /   625)	LOSS:	0.332
# TRAINING BATCH:	(   90 /   625)	LOSS:	0.427
# TRAINING BATCH:	(  100 /   625)	LOSS:	0.308
# TRAINING BATCH:	(  110 /   625)	LOSS:	0.567
# TRAINING BATCH:	(  120 /   625)	LOSS:	0.395
# TRAINING BATCH:	(  130 /   625)	LOSS:	0.280
# TRAINING BATCH:	(  140 /   625)	LOSS:	0.349
# TRAINING BATCH:	(  150 /   625)	LOSS:	0.372
# TRAINING BATCH:	(  160 /   625)	LOSS:	0.263
# TRAINING BATCH:	(  170 /   625)	LOSS:	0.408
# TRAINING BATCH:	(  180 /   625)	LOSS:	0.471
# TRAINING BATCH:	(  190 /   625)	LOSS:	0.344
# TRAINING BATCH:	(  200 /   625)	LOSS:	0.323
# TRAINING BATCH:	(  210 /   625)	LOSS:	0.341
# TRAINING BATCH:	(  220 /   625)	LOSS:	0.254
# TRAINING BATCH:	(  230 /   625)	LOSS:	0.371
# TRAINING BATCH:	(  240 /   625)	LOSS:	0.283
# TRAINING BATCH:	(  250 /   625)	LOSS:	0.303
# TRAINING BATCH:	(  260 /   625)	LOSS:	0.336
# TRAINING BATCH:	(  270 /   625)	LOSS:	0.250
# TRAINING BATCH:	(  280 /   625)	LOSS:	0.326
# TRAINING BATCH:	(  290 /   625)	LOSS:	0.205
# TRAINING BATCH:	(  300 /   625)	LOSS:	0.281
# TRAINING BATCH:	(  310 /   625)	LOSS:	0.411
# TRAINING BATCH:	(  320 /   625)	LOSS:	0.367
# TRAINING BATCH:	(  330 /   625)	LOSS:	0.332
# TRAINING BATCH:	(  340 /   625)	LOSS:	0.384
# TRAINING BATCH:	(  350 /   625)	LOSS:	0.449
# TRAINING BATCH:	(  360 /   625)	LOSS:	0.338
# TRAINING BATCH:	(  370 /   625)	LOSS:	0.299
# TRAINING BATCH:	(  380 /   625)	LOSS:	0.302
# TRAINING BATCH:	(  390 /   625)	LOSS:	0.318
# TRAINING BATCH:	(  400 /   625)	LOSS:	0.261
# TRAINING BATCH:	(  410 /   625)	LOSS:	0.372
# TRAINING BATCH:	(  420 /   625)	LOSS:	0.469
# TRAINING BATCH:	(  430 /   625)	LOSS:	0.503
# TRAINING BATCH:	(  440 /   625)	LOSS:	0.346
# TRAINING BATCH:	(  450 /   625)	LOSS:	0.349
# TRAINING BATCH:	(  460 /   625)	LOSS:	0.217
# TRAINING BATCH:	(  470 /   625)	LOSS:	0.343
# TRAINING BATCH:	(  480 /   625)	LOSS:	0.366
# TRAINING BATCH:	(  490 /   625)	LOSS:	0.355
# TRAINING BATCH:	(  500 /   625)	LOSS:	0.429
# TRAINING BATCH:	(  510 /   625)	LOSS:	0.324
# TRAINING BATCH:	(  520 /   625)	LOSS:	0.286
# TRAINING BATCH:	(  530 /   625)	LOSS:	0.354
# TRAINING BATCH:	(  540 /   625)	LOSS:	0.238
# TRAINING BATCH:	(  550 /   625)	LOSS:	0.206
# TRAINING BATCH:	(  560 /   625)	LOSS:	0.277
# TRAINING BATCH:	(  570 /   625)	LOSS:	0.319
# TRAINING BATCH:	(  580 /   625)	LOSS:	0.596
# TRAINING BATCH:	(  590 /   625)	LOSS:	0.193
# TRAINING BATCH:	(  600 /   625)	LOSS:	0.178
# TRAINING BATCH:	(  610 /   625)	LOSS:	0.326
# TRAINING BATCH:	(  620 /   625)	LOSS:	0.312
# TEST BATCH:	(    0 /   157)	LOSS:	0.175
# TEST BATCH:	(   50 /   157)	LOSS:	0.481
# TEST BATCH:	(  100 /   157)	LOSS:	0.299
# EPOCH:	    5	TRAIN LOSS:	0.010	TRAIN ACCURACY:	0.781	TEST LOSS:	0.010	TEST ACCURACY:	0.787
# TRAINING BATCH:	(    0 /   625)	LOSS:	0.238
# TRAINING BATCH:	(   10 /   625)	LOSS:	0.247
# TRAINING BATCH:	(   20 /   625)	LOSS:	0.187
# TRAINING BATCH:	(   30 /   625)	LOSS:	0.190
# TRAINING BATCH:	(   40 /   625)	LOSS:	0.175
# TRAINING BATCH:	(   50 /   625)	LOSS:	0.337
# TRAINING BATCH:	(   60 /   625)	LOSS:	0.483
# TRAINING BATCH:	(   70 /   625)	LOSS:	0.256
# TRAINING BATCH:	(   80 /   625)	LOSS:	0.348
# TRAINING BATCH:	(   90 /   625)	LOSS:	0.139
# TRAINING BATCH:	(  100 /   625)	LOSS:	0.187
# TRAINING BATCH:	(  110 /   625)	LOSS:	0.189
# TRAINING BATCH:	(  120 /   625)	LOSS:	0.303
# TRAINING BATCH:	(  130 /   625)	LOSS:	0.321
# TRAINING BATCH:	(  140 /   625)	LOSS:	0.284
# TRAINING BATCH:	(  150 /   625)	LOSS:	0.298
# TRAINING BATCH:	(  160 /   625)	LOSS:	0.229
# TRAINING BATCH:	(  170 /   625)	LOSS:	0.209
# TRAINING BATCH:	(  180 /   625)	LOSS:	0.277
# TRAINING BATCH:	(  190 /   625)	LOSS:	0.146
# TRAINING BATCH:	(  200 /   625)	LOSS:	0.203
# TRAINING BATCH:	(  210 /   625)	LOSS:	0.281
# TRAINING BATCH:	(  220 /   625)	LOSS:	0.278
# TRAINING BATCH:	(  230 /   625)	LOSS:	0.234
# TRAINING BATCH:	(  240 /   625)	LOSS:	0.188
# TRAINING BATCH:	(  250 /   625)	LOSS:	0.282
# TRAINING BATCH:	(  260 /   625)	LOSS:	0.267
# TRAINING BATCH:	(  270 /   625)	LOSS:	0.152
# TRAINING BATCH:	(  280 /   625)	LOSS:	0.485
# TRAINING BATCH:	(  290 /   625)	LOSS:	0.194
# TRAINING BATCH:	(  300 /   625)	LOSS:	0.329
# TRAINING BATCH:	(  310 /   625)	LOSS:	0.207
# TRAINING BATCH:	(  320 /   625)	LOSS:	0.182
# TRAINING BATCH:	(  330 /   625)	LOSS:	0.199
# TRAINING BATCH:	(  340 /   625)	LOSS:	0.271
# TRAINING BATCH:	(  350 /   625)	LOSS:	0.187
# TRAINING BATCH:	(  360 /   625)	LOSS:	0.204
# TRAINING BATCH:	(  370 /   625)	LOSS:	0.384
# TRAINING BATCH:	(  380 /   625)	LOSS:	0.241
# TRAINING BATCH:	(  390 /   625)	LOSS:	0.231
# TRAINING BATCH:	(  400 /   625)	LOSS:	0.238
# TRAINING BATCH:	(  410 /   625)	LOSS:	0.142
# TRAINING BATCH:	(  420 /   625)	LOSS:	0.172
# TRAINING BATCH:	(  430 /   625)	LOSS:	0.188
# TRAINING BATCH:	(  440 /   625)	LOSS:	0.173
# TRAINING BATCH:	(  450 /   625)	LOSS:	0.267
# TRAINING BATCH:	(  460 /   625)	LOSS:	0.255
# TRAINING BATCH:	(  470 /   625)	LOSS:	0.296
# TRAINING BATCH:	(  480 /   625)	LOSS:	0.166
# TRAINING BATCH:	(  490 /   625)	LOSS:	0.243
# TRAINING BATCH:	(  500 /   625)	LOSS:	0.299
# TRAINING BATCH:	(  510 /   625)	LOSS:	0.251
# TRAINING BATCH:	(  520 /   625)	LOSS:	0.173
# TRAINING BATCH:	(  530 /   625)	LOSS:	0.296
# TRAINING BATCH:	(  540 /   625)	LOSS:	0.202
# TRAINING BATCH:	(  550 /   625)	LOSS:	0.299
# TRAINING BATCH:	(  560 /   625)	LOSS:	0.201
# TRAINING BATCH:	(  570 /   625)	LOSS:	0.175
# TRAINING BATCH:	(  580 /   625)	LOSS:	0.277
# TRAINING BATCH:	(  590 /   625)	LOSS:	0.202
# TRAINING BATCH:	(  600 /   625)	LOSS:	0.179
# TRAINING BATCH:	(  610 /   625)	LOSS:	0.194
# TRAINING BATCH:	(  620 /   625)	LOSS:	0.195
# TEST BATCH:	(    0 /   157)	LOSS:	0.266
# TEST BATCH:	(   50 /   157)	LOSS:	0.346
# TEST BATCH:	(  100 /   157)	LOSS:	0.224
# EPOCH:	    6	TRAIN LOSS:	0.008	TRAIN ACCURACY:	0.830	TEST LOSS:	0.008	TEST ACCURACY:	0.823
# TRAINING BATCH:	(    0 /   625)	LOSS:	0.216
# TRAINING BATCH:	(   10 /   625)	LOSS:	0.175
# TRAINING BATCH:	(   20 /   625)	LOSS:	0.112
# TRAINING BATCH:	(   30 /   625)	LOSS:	0.237
# TRAINING BATCH:	(   40 /   625)	LOSS:	0.267
# TRAINING BATCH:	(   50 /   625)	LOSS:	0.278
# TRAINING BATCH:	(   60 /   625)	LOSS:	0.214
# TRAINING BATCH:	(   70 /   625)	LOSS:	0.179
# TRAINING BATCH:	(   80 /   625)	LOSS:	0.162
# TRAINING BATCH:	(   90 /   625)	LOSS:	0.191
# TRAINING BATCH:	(  100 /   625)	LOSS:	0.152
# TRAINING BATCH:	(  110 /   625)	LOSS:	0.261
# TRAINING BATCH:	(  120 /   625)	LOSS:	0.223
# TRAINING BATCH:	(  130 /   625)	LOSS:	0.180
# TRAINING BATCH:	(  140 /   625)	LOSS:	0.165
# TRAINING BATCH:	(  150 /   625)	LOSS:	0.134
# TRAINING BATCH:	(  160 /   625)	LOSS:	0.419
# TRAINING BATCH:	(  170 /   625)	LOSS:	0.117
# TRAINING BATCH:	(  180 /   625)	LOSS:	0.133
# TRAINING BATCH:	(  190 /   625)	LOSS:	0.220
# TRAINING BATCH:	(  200 /   625)	LOSS:	0.147
# TRAINING BATCH:	(  210 /   625)	LOSS:	0.262
# TRAINING BATCH:	(  220 /   625)	LOSS:	0.146
# TRAINING BATCH:	(  230 /   625)	LOSS:	0.328
# TRAINING BATCH:	(  240 /   625)	LOSS:	0.351
# TRAINING BATCH:	(  250 /   625)	LOSS:	0.220
# TRAINING BATCH:	(  260 /   625)	LOSS:	0.143
# TRAINING BATCH:	(  270 /   625)	LOSS:	0.208
# TRAINING BATCH:	(  280 /   625)	LOSS:	0.226
# TRAINING BATCH:	(  290 /   625)	LOSS:	0.127
# TRAINING BATCH:	(  300 /   625)	LOSS:	0.321
# TRAINING BATCH:	(  310 /   625)	LOSS:	0.107
# TRAINING BATCH:	(  320 /   625)	LOSS:	0.230
# TRAINING BATCH:	(  330 /   625)	LOSS:	0.165
# TRAINING BATCH:	(  340 /   625)	LOSS:	0.216
# TRAINING BATCH:	(  350 /   625)	LOSS:	0.522
# TRAINING BATCH:	(  360 /   625)	LOSS:	0.170
# TRAINING BATCH:	(  370 /   625)	LOSS:	0.135
# TRAINING BATCH:	(  380 /   625)	LOSS:	0.136
# TRAINING BATCH:	(  390 /   625)	LOSS:	0.169
# TRAINING BATCH:	(  400 /   625)	LOSS:	0.306
# TRAINING BATCH:	(  410 /   625)	LOSS:	0.153
# TRAINING BATCH:	(  420 /   625)	LOSS:	0.145
# TRAINING BATCH:	(  430 /   625)	LOSS:	0.362
# TRAINING BATCH:	(  440 /   625)	LOSS:	0.134
# TRAINING BATCH:	(  450 /   625)	LOSS:	0.134
# TRAINING BATCH:	(  460 /   625)	LOSS:	0.332
# TRAINING BATCH:	(  470 /   625)	LOSS:	0.211
# TRAINING BATCH:	(  480 /   625)	LOSS:	0.120
# TRAINING BATCH:	(  490 /   625)	LOSS:	0.160
# TRAINING BATCH:	(  500 /   625)	LOSS:	0.130
# TRAINING BATCH:	(  510 /   625)	LOSS:	0.138
# TRAINING BATCH:	(  520 /   625)	LOSS:	0.285
# TRAINING BATCH:	(  530 /   625)	LOSS:	0.137
# TRAINING BATCH:	(  540 /   625)	LOSS:	0.178
# TRAINING BATCH:	(  550 /   625)	LOSS:	0.137
# TRAINING BATCH:	(  560 /   625)	LOSS:	0.270
# TRAINING BATCH:	(  570 /   625)	LOSS:	0.201
# TRAINING BATCH:	(  580 /   625)	LOSS:	0.232
# TRAINING BATCH:	(  590 /   625)	LOSS:	0.139
# TRAINING BATCH:	(  600 /   625)	LOSS:	0.168
# TRAINING BATCH:	(  610 /   625)	LOSS:	0.250
# TRAINING BATCH:	(  620 /   625)	LOSS:	0.203
# TEST BATCH:	(    0 /   157)	LOSS:	0.294
# TEST BATCH:	(   50 /   157)	LOSS:	0.342
# TEST BATCH:	(  100 /   157)	LOSS:	0.191
# EPOCH:	    7	TRAIN LOSS:	0.006	TRAIN ACCURACY:	0.863	TEST LOSS:	0.008	TEST ACCURACY:	0.833
# TRAINING BATCH:	(    0 /   625)	LOSS:	0.178
# TRAINING BATCH:	(   10 /   625)	LOSS:	0.205
# TRAINING BATCH:	(   20 /   625)	LOSS:	0.146
# TRAINING BATCH:	(   30 /   625)	LOSS:	0.215
# TRAINING BATCH:	(   40 /   625)	LOSS:	0.128
# TRAINING BATCH:	(   50 /   625)	LOSS:	0.145
# TRAINING BATCH:	(   60 /   625)	LOSS:	0.120
# TRAINING BATCH:	(   70 /   625)	LOSS:	0.170
# TRAINING BATCH:	(   80 /   625)	LOSS:	0.187
# TRAINING BATCH:	(   90 /   625)	LOSS:	0.162
# TRAINING BATCH:	(  100 /   625)	LOSS:	0.164
# TRAINING BATCH:	(  110 /   625)	LOSS:	0.293
# TRAINING BATCH:	(  120 /   625)	LOSS:	0.095
# TRAINING BATCH:	(  130 /   625)	LOSS:	0.163
# TRAINING BATCH:	(  140 /   625)	LOSS:	0.163
# TRAINING BATCH:	(  150 /   625)	LOSS:	0.131
# TRAINING BATCH:	(  160 /   625)	LOSS:	0.081
# TRAINING BATCH:	(  170 /   625)	LOSS:	0.157
# TRAINING BATCH:	(  180 /   625)	LOSS:	0.199
# TRAINING BATCH:	(  190 /   625)	LOSS:	0.144
# TRAINING BATCH:	(  200 /   625)	LOSS:	0.171
# TRAINING BATCH:	(  210 /   625)	LOSS:	0.261
# TRAINING BATCH:	(  220 /   625)	LOSS:	0.120
# TRAINING BATCH:	(  230 /   625)	LOSS:	0.161
# TRAINING BATCH:	(  240 /   625)	LOSS:	0.200
# TRAINING BATCH:	(  250 /   625)	LOSS:	0.206
# TRAINING BATCH:	(  260 /   625)	LOSS:	0.266
# TRAINING BATCH:	(  270 /   625)	LOSS:	0.192
# TRAINING BATCH:	(  280 /   625)	LOSS:	0.143
# TRAINING BATCH:	(  290 /   625)	LOSS:	0.146
# TRAINING BATCH:	(  300 /   625)	LOSS:	0.112
# TRAINING BATCH:	(  310 /   625)	LOSS:	0.182
# TRAINING BATCH:	(  320 /   625)	LOSS:	0.147
# TRAINING BATCH:	(  330 /   625)	LOSS:	0.126
# TRAINING BATCH:	(  340 /   625)	LOSS:	0.141
# TRAINING BATCH:	(  350 /   625)	LOSS:	0.140
# TRAINING BATCH:	(  360 /   625)	LOSS:	0.256
# TRAINING BATCH:	(  370 /   625)	LOSS:	0.103
# TRAINING BATCH:	(  380 /   625)	LOSS:	0.086
# TRAINING BATCH:	(  390 /   625)	LOSS:	0.143
# TRAINING BATCH:	(  400 /   625)	LOSS:	0.349
# TRAINING BATCH:	(  410 /   625)	LOSS:	0.122
# TRAINING BATCH:	(  420 /   625)	LOSS:	0.226
# TRAINING BATCH:	(  430 /   625)	LOSS:	0.262
# TRAINING BATCH:	(  440 /   625)	LOSS:	0.165
# TRAINING BATCH:	(  450 /   625)	LOSS:	0.182
# TRAINING BATCH:	(  460 /   625)	LOSS:	0.152
# TRAINING BATCH:	(  470 /   625)	LOSS:	0.244
# TRAINING BATCH:	(  480 /   625)	LOSS:	0.206
# TRAINING BATCH:	(  490 /   625)	LOSS:	0.097
# TRAINING BATCH:	(  500 /   625)	LOSS:	0.085
# TRAINING BATCH:	(  510 /   625)	LOSS:	0.248
# TRAINING BATCH:	(  520 /   625)	LOSS:	0.161
# TRAINING BATCH:	(  530 /   625)	LOSS:	0.165
# TRAINING BATCH:	(  540 /   625)	LOSS:	0.217
# TRAINING BATCH:	(  550 /   625)	LOSS:	0.154
# TRAINING BATCH:	(  560 /   625)	LOSS:	0.207
# TRAINING BATCH:	(  570 /   625)	LOSS:	0.392
# TRAINING BATCH:	(  580 /   625)	LOSS:	0.233
# TRAINING BATCH:	(  590 /   625)	LOSS:	0.111
# TRAINING BATCH:	(  600 /   625)	LOSS:	0.124
# TRAINING BATCH:	(  610 /   625)	LOSS:	0.076
# TRAINING BATCH:	(  620 /   625)	LOSS:	0.149
# TEST BATCH:	(    0 /   157)	LOSS:	0.161
# TEST BATCH:	(   50 /   157)	LOSS:	0.285
# TEST BATCH:	(  100 /   157)	LOSS:	0.110
# EPOCH:	    8	TRAIN LOSS:	0.005	TRAIN ACCURACY:	0.880	TEST LOSS:	0.007	TEST ACCURACY:	0.850
# TRAINING BATCH:	(    0 /   625)	LOSS:	0.148
# TRAINING BATCH:	(   10 /   625)	LOSS:	0.114
# TRAINING BATCH:	(   20 /   625)	LOSS:	0.196
# TRAINING BATCH:	(   30 /   625)	LOSS:	0.069
# TRAINING BATCH:	(   40 /   625)	LOSS:	0.116
# TRAINING BATCH:	(   50 /   625)	LOSS:	0.108
# TRAINING BATCH:	(   60 /   625)	LOSS:	0.083
# TRAINING BATCH:	(   70 /   625)	LOSS:	0.174
# TRAINING BATCH:	(   80 /   625)	LOSS:	0.188
# TRAINING BATCH:	(   90 /   625)	LOSS:	0.137
# TRAINING BATCH:	(  100 /   625)	LOSS:	0.140
# TRAINING BATCH:	(  110 /   625)	LOSS:	0.159
# TRAINING BATCH:	(  120 /   625)	LOSS:	0.208
# TRAINING BATCH:	(  130 /   625)	LOSS:	0.094
# TRAINING BATCH:	(  140 /   625)	LOSS:	0.125
# TRAINING BATCH:	(  150 /   625)	LOSS:	0.178
# TRAINING BATCH:	(  160 /   625)	LOSS:	0.178
# TRAINING BATCH:	(  170 /   625)	LOSS:	0.169
# TRAINING BATCH:	(  180 /   625)	LOSS:	0.109
# TRAINING BATCH:	(  190 /   625)	LOSS:	0.065
# TRAINING BATCH:	(  200 /   625)	LOSS:	0.130
# TRAINING BATCH:	(  210 /   625)	LOSS:	0.303
# TRAINING BATCH:	(  220 /   625)	LOSS:	0.096
# TRAINING BATCH:	(  230 /   625)	LOSS:	0.110
# TRAINING BATCH:	(  240 /   625)	LOSS:	0.199
# TRAINING BATCH:	(  250 /   625)	LOSS:	0.212
# TRAINING BATCH:	(  260 /   625)	LOSS:	0.251
# TRAINING BATCH:	(  270 /   625)	LOSS:	0.072
# TRAINING BATCH:	(  280 /   625)	LOSS:	0.172
# TRAINING BATCH:	(  290 /   625)	LOSS:	0.170
# TRAINING BATCH:	(  300 /   625)	LOSS:	0.182
# TRAINING BATCH:	(  310 /   625)	LOSS:	0.171
# TRAINING BATCH:	(  320 /   625)	LOSS:	0.208
# TRAINING BATCH:	(  330 /   625)	LOSS:	0.209
# TRAINING BATCH:	(  340 /   625)	LOSS:	0.090
# TRAINING BATCH:	(  350 /   625)	LOSS:	0.204
# TRAINING BATCH:	(  360 /   625)	LOSS:	0.077
# TRAINING BATCH:	(  370 /   625)	LOSS:	0.124
# TRAINING BATCH:	(  380 /   625)	LOSS:	0.106
# TRAINING BATCH:	(  390 /   625)	LOSS:	0.243
# TRAINING BATCH:	(  400 /   625)	LOSS:	0.123
# TRAINING BATCH:	(  410 /   625)	LOSS:	0.081
# TRAINING BATCH:	(  420 /   625)	LOSS:	0.121
# TRAINING BATCH:	(  430 /   625)	LOSS:	0.114
# TRAINING BATCH:	(  440 /   625)	LOSS:	0.200
# TRAINING BATCH:	(  450 /   625)	LOSS:	0.137
# TRAINING BATCH:	(  460 /   625)	LOSS:	0.089
# TRAINING BATCH:	(  470 /   625)	LOSS:	0.133
# TRAINING BATCH:	(  480 /   625)	LOSS:	0.108
# TRAINING BATCH:	(  490 /   625)	LOSS:	0.196
# TRAINING BATCH:	(  500 /   625)	LOSS:	0.270
# TRAINING BATCH:	(  510 /   625)	LOSS:	0.100
# TRAINING BATCH:	(  520 /   625)	LOSS:	0.076
# TRAINING BATCH:	(  530 /   625)	LOSS:	0.102
# TRAINING BATCH:	(  540 /   625)	LOSS:	0.305
# TRAINING BATCH:	(  550 /   625)	LOSS:	0.155
# TRAINING BATCH:	(  560 /   625)	LOSS:	0.079
# TRAINING BATCH:	(  570 /   625)	LOSS:	0.150
# TRAINING BATCH:	(  580 /   625)	LOSS:	0.225
# TRAINING BATCH:	(  590 /   625)	LOSS:	0.126
# TRAINING BATCH:	(  600 /   625)	LOSS:	0.128
# TRAINING BATCH:	(  610 /   625)	LOSS:	0.080
# TRAINING BATCH:	(  620 /   625)	LOSS:	0.134
# TEST BATCH:	(    0 /   157)	LOSS:	0.227
# TEST BATCH:	(   50 /   157)	LOSS:	0.288
# TEST BATCH:	(  100 /   157)	LOSS:	0.124
# EPOCH:	    9	TRAIN LOSS:	0.005	TRAIN ACCURACY:	0.897	TEST LOSS:	0.007	TEST ACCURACY:	0.855
# TRAINING BATCH:	(    0 /   625)	LOSS:	0.130
# TRAINING BATCH:	(   10 /   625)	LOSS:	0.112
# TRAINING BATCH:	(   20 /   625)	LOSS:	0.218
# TRAINING BATCH:	(   30 /   625)	LOSS:	0.123
# TRAINING BATCH:	(   40 /   625)	LOSS:	0.138
# TRAINING BATCH:	(   50 /   625)	LOSS:	0.110
# TRAINING BATCH:	(   60 /   625)	LOSS:	0.142
# TRAINING BATCH:	(   70 /   625)	LOSS:	0.252
# TRAINING BATCH:	(   80 /   625)	LOSS:	0.056
# TRAINING BATCH:	(   90 /   625)	LOSS:	0.149
# TRAINING BATCH:	(  100 /   625)	LOSS:	0.224
# TRAINING BATCH:	(  110 /   625)	LOSS:	0.098
# TRAINING BATCH:	(  120 /   625)	LOSS:	0.133
# TRAINING BATCH:	(  130 /   625)	LOSS:	0.087
# TRAINING BATCH:	(  140 /   625)	LOSS:	0.070
# TRAINING BATCH:	(  150 /   625)	LOSS:	0.086
# TRAINING BATCH:	(  160 /   625)	LOSS:	0.107
# TRAINING BATCH:	(  170 /   625)	LOSS:	0.145
# TRAINING BATCH:	(  180 /   625)	LOSS:	0.047
# TRAINING BATCH:	(  190 /   625)	LOSS:	0.073
# TRAINING BATCH:	(  200 /   625)	LOSS:	0.174
# TRAINING BATCH:	(  210 /   625)	LOSS:	0.087
# TRAINING BATCH:	(  220 /   625)	LOSS:	0.103
# TRAINING BATCH:	(  230 /   625)	LOSS:	0.071
# TRAINING BATCH:	(  240 /   625)	LOSS:	0.130
# TRAINING BATCH:	(  250 /   625)	LOSS:	0.112
# TRAINING BATCH:	(  260 /   625)	LOSS:	0.108
# TRAINING BATCH:	(  270 /   625)	LOSS:	0.153
# TRAINING BATCH:	(  280 /   625)	LOSS:	0.085
# TRAINING BATCH:	(  290 /   625)	LOSS:	0.092
# TRAINING BATCH:	(  300 /   625)	LOSS:	0.189
# TRAINING BATCH:	(  310 /   625)	LOSS:	0.139
# TRAINING BATCH:	(  320 /   625)	LOSS:	0.165
# TRAINING BATCH:	(  330 /   625)	LOSS:	0.086
# TRAINING BATCH:	(  340 /   625)	LOSS:	0.172
# TRAINING BATCH:	(  350 /   625)	LOSS:	0.072
# TRAINING BATCH:	(  360 /   625)	LOSS:	0.064
# TRAINING BATCH:	(  370 /   625)	LOSS:	0.148
# TRAINING BATCH:	(  380 /   625)	LOSS:	0.074
# TRAINING BATCH:	(  390 /   625)	LOSS:	0.070
# TRAINING BATCH:	(  400 /   625)	LOSS:	0.102
# TRAINING BATCH:	(  410 /   625)	LOSS:	0.260
# TRAINING BATCH:	(  420 /   625)	LOSS:	0.084
# TRAINING BATCH:	(  430 /   625)	LOSS:	0.105
# TRAINING BATCH:	(  440 /   625)	LOSS:	0.222
# TRAINING BATCH:	(  450 /   625)	LOSS:	0.135
# TRAINING BATCH:	(  460 /   625)	LOSS:	0.117
# TRAINING BATCH:	(  470 /   625)	LOSS:	0.157
# TRAINING BATCH:	(  480 /   625)	LOSS:	0.106
# TRAINING BATCH:	(  490 /   625)	LOSS:	0.150
# TRAINING BATCH:	(  500 /   625)	LOSS:	0.120
# TRAINING BATCH:	(  510 /   625)	LOSS:	0.080
# TRAINING BATCH:	(  520 /   625)	LOSS:	0.184
# TRAINING BATCH:	(  530 /   625)	LOSS:	0.149
# TRAINING BATCH:	(  540 /   625)	LOSS:	0.101
# TRAINING BATCH:	(  550 /   625)	LOSS:	0.121
# TRAINING BATCH:	(  560 /   625)	LOSS:	0.103
# TRAINING BATCH:	(  570 /   625)	LOSS:	0.077
# TRAINING BATCH:	(  580 /   625)	LOSS:	0.079
# TRAINING BATCH:	(  590 /   625)	LOSS:	0.210
# TRAINING BATCH:	(  600 /   625)	LOSS:	0.080
# TRAINING BATCH:	(  610 /   625)	LOSS:	0.194
# TRAINING BATCH:	(  620 /   625)	LOSS:	0.094
# TEST BATCH:	(    0 /   157)	LOSS:	0.158
# TEST BATCH:	(   50 /   157)	LOSS:	0.296
# TEST BATCH:	(  100 /   157)	LOSS:	0.095
# EPOCH:	   10	TRAIN LOSS:	0.004	TRAIN ACCURACY:	0.907	TEST LOSS:	0.006	TEST ACCURACY:	0.863
# TRAINING BATCH:	(    0 /   625)	LOSS:	0.147
# TRAINING BATCH:	(   10 /   625)	LOSS:	0.138
# TRAINING BATCH:	(   20 /   625)	LOSS:	0.176
# TRAINING BATCH:	(   30 /   625)	LOSS:	0.154
# TRAINING BATCH:	(   40 /   625)	LOSS:	0.081
# TRAINING BATCH:	(   50 /   625)	LOSS:	0.144
# TRAINING BATCH:	(   60 /   625)	LOSS:	0.044
# TRAINING BATCH:	(   70 /   625)	LOSS:	0.057
# TRAINING BATCH:	(   80 /   625)	LOSS:	0.083
# TRAINING BATCH:	(   90 /   625)	LOSS:	0.117
# TRAINING BATCH:	(  100 /   625)	LOSS:	0.071
# TRAINING BATCH:	(  110 /   625)	LOSS:	0.076
# TRAINING BATCH:	(  120 /   625)	LOSS:	0.306
# TRAINING BATCH:	(  130 /   625)	LOSS:	0.085
# TRAINING BATCH:	(  140 /   625)	LOSS:	0.040
# TRAINING BATCH:	(  150 /   625)	LOSS:	0.086
# TRAINING BATCH:	(  160 /   625)	LOSS:	0.207
# TRAINING BATCH:	(  170 /   625)	LOSS:	0.105
# TRAINING BATCH:	(  180 /   625)	LOSS:	0.084
# TRAINING BATCH:	(  190 /   625)	LOSS:	0.170
# TRAINING BATCH:	(  200 /   625)	LOSS:	0.176
# TRAINING BATCH:	(  210 /   625)	LOSS:	0.139
# TRAINING BATCH:	(  220 /   625)	LOSS:	0.109
# TRAINING BATCH:	(  230 /   625)	LOSS:	0.091
# TRAINING BATCH:	(  240 /   625)	LOSS:	0.082
# TRAINING BATCH:	(  250 /   625)	LOSS:	0.042
# TRAINING BATCH:	(  260 /   625)	LOSS:	0.101
# TRAINING BATCH:	(  270 /   625)	LOSS:	0.114
# TRAINING BATCH:	(  280 /   625)	LOSS:	0.125
# TRAINING BATCH:	(  290 /   625)	LOSS:	0.215
# TRAINING BATCH:	(  300 /   625)	LOSS:	0.103
# TRAINING BATCH:	(  310 /   625)	LOSS:	0.078
# TRAINING BATCH:	(  320 /   625)	LOSS:	0.070
# TRAINING BATCH:	(  330 /   625)	LOSS:	0.055
# TRAINING BATCH:	(  340 /   625)	LOSS:	0.068
# TRAINING BATCH:	(  350 /   625)	LOSS:	0.135
# TRAINING BATCH:	(  360 /   625)	LOSS:	0.083
# TRAINING BATCH:	(  370 /   625)	LOSS:	0.156
# TRAINING BATCH:	(  380 /   625)	LOSS:	0.076
# TRAINING BATCH:	(  390 /   625)	LOSS:	0.132
# TRAINING BATCH:	(  400 /   625)	LOSS:	0.118
# TRAINING BATCH:	(  410 /   625)	LOSS:	0.119
# TRAINING BATCH:	(  420 /   625)	LOSS:	0.100
# TRAINING BATCH:	(  430 /   625)	LOSS:	0.080
# TRAINING BATCH:	(  440 /   625)	LOSS:	0.111
# TRAINING BATCH:	(  450 /   625)	LOSS:	0.105
# TRAINING BATCH:	(  460 /   625)	LOSS:	0.140
# TRAINING BATCH:	(  470 /   625)	LOSS:	0.138
# TRAINING BATCH:	(  480 /   625)	LOSS:	0.146
# TRAINING BATCH:	(  490 /   625)	LOSS:	0.229
# TRAINING BATCH:	(  500 /   625)	LOSS:	0.085
# TRAINING BATCH:	(  510 /   625)	LOSS:	0.078
# TRAINING BATCH:	(  520 /   625)	LOSS:	0.072
# TRAINING BATCH:	(  530 /   625)	LOSS:	0.066
# TRAINING BATCH:	(  540 /   625)	LOSS:	0.211
# TRAINING BATCH:	(  550 /   625)	LOSS:	0.233
# TRAINING BATCH:	(  560 /   625)	LOSS:	0.077
# TRAINING BATCH:	(  570 /   625)	LOSS:	0.073
# TRAINING BATCH:	(  580 /   625)	LOSS:	0.080
# TRAINING BATCH:	(  590 /   625)	LOSS:	0.068
# TRAINING BATCH:	(  600 /   625)	LOSS:	0.120
# TRAINING BATCH:	(  610 /   625)	LOSS:	0.067
# TRAINING BATCH:	(  620 /   625)	LOSS:	0.057
# TEST BATCH:	(    0 /   157)	LOSS:	0.212
# TEST BATCH:	(   50 /   157)	LOSS:	0.268
# TEST BATCH:	(  100 /   157)	LOSS:	0.084
# EPOCH:	   11	TRAIN LOSS:	0.004	TRAIN ACCURACY:	0.919	TEST LOSS:	0.006	TEST ACCURACY:	0.865
# TRAINING BATCH:	(    0 /   625)	LOSS:	0.061
# TRAINING BATCH:	(   10 /   625)	LOSS:	0.105
# TRAINING BATCH:	(   20 /   625)	LOSS:	0.046
# TRAINING BATCH:	(   30 /   625)	LOSS:	0.112
# TRAINING BATCH:	(   40 /   625)	LOSS:	0.043
# TRAINING BATCH:	(   50 /   625)	LOSS:	0.057
# TRAINING BATCH:	(   60 /   625)	LOSS:	0.114
# TRAINING BATCH:	(   70 /   625)	LOSS:	0.143
# TRAINING BATCH:	(   80 /   625)	LOSS:	0.075
# TRAINING BATCH:	(   90 /   625)	LOSS:	0.073
# TRAINING BATCH:	(  100 /   625)	LOSS:	0.101
# TRAINING BATCH:	(  110 /   625)	LOSS:	0.083
# TRAINING BATCH:	(  120 /   625)	LOSS:	0.165
# TRAINING BATCH:	(  130 /   625)	LOSS:	0.193
# TRAINING BATCH:	(  140 /   625)	LOSS:	0.079
# TRAINING BATCH:	(  150 /   625)	LOSS:	0.099
# TRAINING BATCH:	(  160 /   625)	LOSS:	0.048
# TRAINING BATCH:	(  170 /   625)	LOSS:	0.173
# TRAINING BATCH:	(  180 /   625)	LOSS:	0.063
# TRAINING BATCH:	(  190 /   625)	LOSS:	0.134
# TRAINING BATCH:	(  200 /   625)	LOSS:	0.192
# TRAINING BATCH:	(  210 /   625)	LOSS:	0.079
# TRAINING BATCH:	(  220 /   625)	LOSS:	0.122
# TRAINING BATCH:	(  230 /   625)	LOSS:	0.075
# TRAINING BATCH:	(  240 /   625)	LOSS:	0.057
# TRAINING BATCH:	(  250 /   625)	LOSS:	0.114
# TRAINING BATCH:	(  260 /   625)	LOSS:	0.113
# TRAINING BATCH:	(  270 /   625)	LOSS:	0.058
# TRAINING BATCH:	(  280 /   625)	LOSS:	0.091
# TRAINING BATCH:	(  290 /   625)	LOSS:	0.117
# TRAINING BATCH:	(  300 /   625)	LOSS:	0.077
# TRAINING BATCH:	(  310 /   625)	LOSS:	0.166
# TRAINING BATCH:	(  320 /   625)	LOSS:	0.119
# TRAINING BATCH:	(  330 /   625)	LOSS:	0.047
# TRAINING BATCH:	(  340 /   625)	LOSS:	0.086
# TRAINING BATCH:	(  350 /   625)	LOSS:	0.146
# TRAINING BATCH:	(  360 /   625)	LOSS:	0.083
# TRAINING BATCH:	(  370 /   625)	LOSS:	0.067
# TRAINING BATCH:	(  380 /   625)	LOSS:	0.110
# TRAINING BATCH:	(  390 /   625)	LOSS:	0.044
# TRAINING BATCH:	(  400 /   625)	LOSS:	0.060
# TRAINING BATCH:	(  410 /   625)	LOSS:	0.085
# TRAINING BATCH:	(  420 /   625)	LOSS:	0.030
# TRAINING BATCH:	(  430 /   625)	LOSS:	0.067
# TRAINING BATCH:	(  440 /   625)	LOSS:	0.091
# TRAINING BATCH:	(  450 /   625)	LOSS:	0.025
# TRAINING BATCH:	(  460 /   625)	LOSS:	0.067
# TRAINING BATCH:	(  470 /   625)	LOSS:	0.164
# TRAINING BATCH:	(  480 /   625)	LOSS:	0.065
# TRAINING BATCH:	(  490 /   625)	LOSS:	0.113
# TRAINING BATCH:	(  500 /   625)	LOSS:	0.145
# TRAINING BATCH:	(  510 /   625)	LOSS:	0.081
# TRAINING BATCH:	(  520 /   625)	LOSS:	0.096
# TRAINING BATCH:	(  530 /   625)	LOSS:	0.075
# TRAINING BATCH:	(  540 /   625)	LOSS:	0.192
# TRAINING BATCH:	(  550 /   625)	LOSS:	0.100
# TRAINING BATCH:	(  560 /   625)	LOSS:	0.130
# TRAINING BATCH:	(  570 /   625)	LOSS:	0.049
# TRAINING BATCH:	(  580 /   625)	LOSS:	0.051
# TRAINING BATCH:	(  590 /   625)	LOSS:	0.072
# TRAINING BATCH:	(  600 /   625)	LOSS:	0.099
# TRAINING BATCH:	(  610 /   625)	LOSS:	0.086
# TRAINING BATCH:	(  620 /   625)	LOSS:	0.096
# TEST BATCH:	(    0 /   157)	LOSS:	0.243
# TEST BATCH:	(   50 /   157)	LOSS:	0.181
# TEST BATCH:	(  100 /   157)	LOSS:	0.050
# EPOCH:	   12	TRAIN LOSS:	0.003	TRAIN ACCURACY:	0.925	TEST LOSS:	0.006	TEST ACCURACY:	0.878
# TRAINING BATCH:	(    0 /   625)	LOSS:	0.275
# TRAINING BATCH:	(   10 /   625)	LOSS:	0.047
# TRAINING BATCH:	(   20 /   625)	LOSS:	0.074
# TRAINING BATCH:	(   30 /   625)	LOSS:	0.056
# TRAINING BATCH:	(   40 /   625)	LOSS:	0.057
# TRAINING BATCH:	(   50 /   625)	LOSS:	0.087
# TRAINING BATCH:	(   60 /   625)	LOSS:	0.116
# TRAINING BATCH:	(   70 /   625)	LOSS:	0.051
# TRAINING BATCH:	(   80 /   625)	LOSS:	0.076
# TRAINING BATCH:	(   90 /   625)	LOSS:	0.124
# TRAINING BATCH:	(  100 /   625)	LOSS:	0.068
# TRAINING BATCH:	(  110 /   625)	LOSS:	0.064
# TRAINING BATCH:	(  120 /   625)	LOSS:	0.092
# TRAINING BATCH:	(  130 /   625)	LOSS:	0.173
# TRAINING BATCH:	(  140 /   625)	LOSS:	0.049
# TRAINING BATCH:	(  150 /   625)	LOSS:	0.161
# TRAINING BATCH:	(  160 /   625)	LOSS:	0.103
# TRAINING BATCH:	(  170 /   625)	LOSS:	0.079
# TRAINING BATCH:	(  180 /   625)	LOSS:	0.279
# TRAINING BATCH:	(  190 /   625)	LOSS:	0.092
# TRAINING BATCH:	(  200 /   625)	LOSS:	0.071
# TRAINING BATCH:	(  210 /   625)	LOSS:	0.117
# TRAINING BATCH:	(  220 /   625)	LOSS:	0.148
# TRAINING BATCH:	(  230 /   625)	LOSS:	0.200
# TRAINING BATCH:	(  240 /   625)	LOSS:	0.057
# TRAINING BATCH:	(  250 /   625)	LOSS:	0.084
# TRAINING BATCH:	(  260 /   625)	LOSS:	0.206
# TRAINING BATCH:	(  270 /   625)	LOSS:	0.082
# TRAINING BATCH:	(  280 /   625)	LOSS:	0.101
# TRAINING BATCH:	(  290 /   625)	LOSS:	0.072
# TRAINING BATCH:	(  300 /   625)	LOSS:	0.128
# TRAINING BATCH:	(  310 /   625)	LOSS:	0.179
# TRAINING BATCH:	(  320 /   625)	LOSS:	0.065
# TRAINING BATCH:	(  330 /   625)	LOSS:	0.146
# TRAINING BATCH:	(  340 /   625)	LOSS:	0.137
# TRAINING BATCH:	(  350 /   625)	LOSS:	0.035
# TRAINING BATCH:	(  360 /   625)	LOSS:	0.157
# TRAINING BATCH:	(  370 /   625)	LOSS:	0.137
# TRAINING BATCH:	(  380 /   625)	LOSS:	0.053
# TRAINING BATCH:	(  390 /   625)	LOSS:	0.071
# TRAINING BATCH:	(  400 /   625)	LOSS:	0.119
# TRAINING BATCH:	(  410 /   625)	LOSS:	0.070
# TRAINING BATCH:	(  420 /   625)	LOSS:	0.071
# TRAINING BATCH:	(  430 /   625)	LOSS:	0.172
# TRAINING BATCH:	(  440 /   625)	LOSS:	0.086
# TRAINING BATCH:	(  450 /   625)	LOSS:	0.054
# TRAINING BATCH:	(  460 /   625)	LOSS:	0.126
# TRAINING BATCH:	(  470 /   625)	LOSS:	0.182
# TRAINING BATCH:	(  480 /   625)	LOSS:	0.144
# TRAINING BATCH:	(  490 /   625)	LOSS:	0.060
# TRAINING BATCH:	(  500 /   625)	LOSS:	0.064
# TRAINING BATCH:	(  510 /   625)	LOSS:	0.106
# TRAINING BATCH:	(  520 /   625)	LOSS:	0.045
# TRAINING BATCH:	(  530 /   625)	LOSS:	0.152
# TRAINING BATCH:	(  540 /   625)	LOSS:	0.141
# TRAINING BATCH:	(  550 /   625)	LOSS:	0.072
# TRAINING BATCH:	(  560 /   625)	LOSS:	0.050
# TRAINING BATCH:	(  570 /   625)	LOSS:	0.028
# TRAINING BATCH:	(  580 /   625)	LOSS:	0.122
# TRAINING BATCH:	(  590 /   625)	LOSS:	0.144
# TRAINING BATCH:	(  600 /   625)	LOSS:	0.124
# TRAINING BATCH:	(  610 /   625)	LOSS:	0.177
# TRAINING BATCH:	(  620 /   625)	LOSS:	0.129
# TEST BATCH:	(    0 /   157)	LOSS:	0.163
# TEST BATCH:	(   50 /   157)	LOSS:	0.270
# TEST BATCH:	(  100 /   157)	LOSS:	0.096
# EPOCH:	   13	TRAIN LOSS:	0.003	TRAIN ACCURACY:	0.930	TEST LOSS:	0.006	TEST ACCURACY:	0.869
# TRAINING BATCH:	(    0 /   625)	LOSS:	0.067
# TRAINING BATCH:	(   10 /   625)	LOSS:	0.154
# TRAINING BATCH:	(   20 /   625)	LOSS:	0.087
# TRAINING BATCH:	(   30 /   625)	LOSS:	0.067
# TRAINING BATCH:	(   40 /   625)	LOSS:	0.034
# TRAINING BATCH:	(   50 /   625)	LOSS:	0.101
# TRAINING BATCH:	(   60 /   625)	LOSS:	0.132
# TRAINING BATCH:	(   70 /   625)	LOSS:	0.107
# TRAINING BATCH:	(   80 /   625)	LOSS:	0.098
# TRAINING BATCH:	(   90 /   625)	LOSS:	0.046
# TRAINING BATCH:	(  100 /   625)	LOSS:	0.124
# TRAINING BATCH:	(  110 /   625)	LOSS:	0.082
# TRAINING BATCH:	(  120 /   625)	LOSS:	0.065
# TRAINING BATCH:	(  130 /   625)	LOSS:	0.060
# TRAINING BATCH:	(  140 /   625)	LOSS:	0.052
# TRAINING BATCH:	(  150 /   625)	LOSS:	0.036
# TRAINING BATCH:	(  160 /   625)	LOSS:	0.169
# TRAINING BATCH:	(  170 /   625)	LOSS:	0.061
# TRAINING BATCH:	(  180 /   625)	LOSS:	0.144
# TRAINING BATCH:	(  190 /   625)	LOSS:	0.061
# TRAINING BATCH:	(  200 /   625)	LOSS:	0.053
# TRAINING BATCH:	(  210 /   625)	LOSS:	0.077
# TRAINING BATCH:	(  220 /   625)	LOSS:	0.124
# TRAINING BATCH:	(  230 /   625)	LOSS:	0.107
# TRAINING BATCH:	(  240 /   625)	LOSS:	0.149
# TRAINING BATCH:	(  250 /   625)	LOSS:	0.093
# TRAINING BATCH:	(  260 /   625)	LOSS:	0.036
# TRAINING BATCH:	(  270 /   625)	LOSS:	0.164
# TRAINING BATCH:	(  280 /   625)	LOSS:	0.150
# TRAINING BATCH:	(  290 /   625)	LOSS:	0.080
# TRAINING BATCH:	(  300 /   625)	LOSS:	0.096
# TRAINING BATCH:	(  310 /   625)	LOSS:	0.102
# TRAINING BATCH:	(  320 /   625)	LOSS:	0.028
# TRAINING BATCH:	(  330 /   625)	LOSS:	0.125
# TRAINING BATCH:	(  340 /   625)	LOSS:	0.123
# TRAINING BATCH:	(  350 /   625)	LOSS:	0.099
# TRAINING BATCH:	(  360 /   625)	LOSS:	0.057
# TRAINING BATCH:	(  370 /   625)	LOSS:	0.096
# TRAINING BATCH:	(  380 /   625)	LOSS:	0.105
# TRAINING BATCH:	(  390 /   625)	LOSS:	0.051
# TRAINING BATCH:	(  400 /   625)	LOSS:	0.052
# TRAINING BATCH:	(  410 /   625)	LOSS:	0.057
# TRAINING BATCH:	(  420 /   625)	LOSS:	0.032
# TRAINING BATCH:	(  430 /   625)	LOSS:	0.055
# TRAINING BATCH:	(  440 /   625)	LOSS:	0.139
# TRAINING BATCH:	(  450 /   625)	LOSS:	0.062
# TRAINING BATCH:	(  460 /   625)	LOSS:	0.085
# TRAINING BATCH:	(  470 /   625)	LOSS:	0.068
# TRAINING BATCH:	(  480 /   625)	LOSS:	0.062
# TRAINING BATCH:	(  490 /   625)	LOSS:	0.030
# TRAINING BATCH:	(  500 /   625)	LOSS:	0.039
# TRAINING BATCH:	(  510 /   625)	LOSS:	0.155
# TRAINING BATCH:	(  520 /   625)	LOSS:	0.236
# TRAINING BATCH:	(  530 /   625)	LOSS:	0.064
# TRAINING BATCH:	(  540 /   625)	LOSS:	0.162
# TRAINING BATCH:	(  550 /   625)	LOSS:	0.040
# TRAINING BATCH:	(  560 /   625)	LOSS:	0.082
# TRAINING BATCH:	(  570 /   625)	LOSS:	0.054
# TRAINING BATCH:	(  580 /   625)	LOSS:	0.146
# TRAINING BATCH:	(  590 /   625)	LOSS:	0.061
# TRAINING BATCH:	(  600 /   625)	LOSS:	0.104
# TRAINING BATCH:	(  610 /   625)	LOSS:	0.073
# TRAINING BATCH:	(  620 /   625)	LOSS:	0.077
# TEST BATCH:	(    0 /   157)	LOSS:	0.212
# TEST BATCH:	(   50 /   157)	LOSS:	0.326
# TEST BATCH:	(  100 /   157)	LOSS:	0.176
# EPOCH:	   14	TRAIN LOSS:	0.003	TRAIN ACCURACY:	0.933	TEST LOSS:	0.006	TEST ACCURACY:	0.871
# TRAINING BATCH:	(    0 /   625)	LOSS:	0.064
# TRAINING BATCH:	(   10 /   625)	LOSS:	0.059
# TRAINING BATCH:	(   20 /   625)	LOSS:	0.077
# TRAINING BATCH:	(   30 /   625)	LOSS:	0.093
# TRAINING BATCH:	(   40 /   625)	LOSS:	0.125
# TRAINING BATCH:	(   50 /   625)	LOSS:	0.090
# TRAINING BATCH:	(   60 /   625)	LOSS:	0.048
# TRAINING BATCH:	(   70 /   625)	LOSS:	0.094
# TRAINING BATCH:	(   80 /   625)	LOSS:	0.055
# TRAINING BATCH:	(   90 /   625)	LOSS:	0.046
# TRAINING BATCH:	(  100 /   625)	LOSS:	0.070
# TRAINING BATCH:	(  110 /   625)	LOSS:	0.252
# TRAINING BATCH:	(  120 /   625)	LOSS:	0.118
# TRAINING BATCH:	(  130 /   625)	LOSS:	0.035
# TRAINING BATCH:	(  140 /   625)	LOSS:	0.132
# TRAINING BATCH:	(  150 /   625)	LOSS:	0.049
# TRAINING BATCH:	(  160 /   625)	LOSS:	0.105
# TRAINING BATCH:	(  170 /   625)	LOSS:	0.057
# TRAINING BATCH:	(  180 /   625)	LOSS:	0.050
# TRAINING BATCH:	(  190 /   625)	LOSS:	0.032
# TRAINING BATCH:	(  200 /   625)	LOSS:	0.059
# TRAINING BATCH:	(  210 /   625)	LOSS:	0.161
# TRAINING BATCH:	(  220 /   625)	LOSS:	0.141
# TRAINING BATCH:	(  230 /   625)	LOSS:	0.081
# TRAINING BATCH:	(  240 /   625)	LOSS:	0.093
# TRAINING BATCH:	(  250 /   625)	LOSS:	0.100
# TRAINING BATCH:	(  260 /   625)	LOSS:	0.133
# TRAINING BATCH:	(  270 /   625)	LOSS:	0.098
# TRAINING BATCH:	(  280 /   625)	LOSS:	0.132
# TRAINING BATCH:	(  290 /   625)	LOSS:	0.080
# TRAINING BATCH:	(  300 /   625)	LOSS:	0.128
# TRAINING BATCH:	(  310 /   625)	LOSS:	0.048
# TRAINING BATCH:	(  320 /   625)	LOSS:	0.119
# TRAINING BATCH:	(  330 /   625)	LOSS:	0.041
# TRAINING BATCH:	(  340 /   625)	LOSS:	0.044
# TRAINING BATCH:	(  350 /   625)	LOSS:	0.043
# TRAINING BATCH:	(  360 /   625)	LOSS:	0.052
# TRAINING BATCH:	(  370 /   625)	LOSS:	0.035
# TRAINING BATCH:	(  380 /   625)	LOSS:	0.125
# TRAINING BATCH:	(  390 /   625)	LOSS:	0.041
# TRAINING BATCH:	(  400 /   625)	LOSS:	0.079
# TRAINING BATCH:	(  410 /   625)	LOSS:	0.078
# TRAINING BATCH:	(  420 /   625)	LOSS:	0.068
# TRAINING BATCH:	(  430 /   625)	LOSS:	0.078
# TRAINING BATCH:	(  440 /   625)	LOSS:	0.076
# TRAINING BATCH:	(  450 /   625)	LOSS:	0.086
# TRAINING BATCH:	(  460 /   625)	LOSS:	0.085
# TRAINING BATCH:	(  470 /   625)	LOSS:	0.017
# TRAINING BATCH:	(  480 /   625)	LOSS:	0.025
# TRAINING BATCH:	(  490 /   625)	LOSS:	0.146
# TRAINING BATCH:	(  500 /   625)	LOSS:	0.063
# TRAINING BATCH:	(  510 /   625)	LOSS:	0.040
# TRAINING BATCH:	(  520 /   625)	LOSS:	0.028
# TRAINING BATCH:	(  530 /   625)	LOSS:	0.067
# TRAINING BATCH:	(  540 /   625)	LOSS:	0.096
# TRAINING BATCH:	(  550 /   625)	LOSS:	0.149
# TRAINING BATCH:	(  560 /   625)	LOSS:	0.071
# TRAINING BATCH:	(  570 /   625)	LOSS:	0.021
# TRAINING BATCH:	(  580 /   625)	LOSS:	0.061
# TRAINING BATCH:	(  590 /   625)	LOSS:	0.091
# TRAINING BATCH:	(  600 /   625)	LOSS:	0.031
# TRAINING BATCH:	(  610 /   625)	LOSS:	0.074
# TRAINING BATCH:	(  620 /   625)	LOSS:	0.085
# TEST BATCH:	(    0 /   157)	LOSS:	0.195
# TEST BATCH:	(   50 /   157)	LOSS:	0.278
# TEST BATCH:	(  100 /   157)	LOSS:	0.089
# EPOCH:	   15	TRAIN LOSS:	0.003	TRAIN ACCURACY:	0.937	TEST LOSS:	0.006	TEST ACCURACY:	0.878
# TRAINING BATCH:	(    0 /   625)	LOSS:	0.032
# TRAINING BATCH:	(   10 /   625)	LOSS:	0.020
# TRAINING BATCH:	(   20 /   625)	LOSS:	0.074
# TRAINING BATCH:	(   30 /   625)	LOSS:	0.064
# TRAINING BATCH:	(   40 /   625)	LOSS:	0.127
# TRAINING BATCH:	(   50 /   625)	LOSS:	0.124
# TRAINING BATCH:	(   60 /   625)	LOSS:	0.039
# TRAINING BATCH:	(   70 /   625)	LOSS:	0.140
# TRAINING BATCH:	(   80 /   625)	LOSS:	0.067
# TRAINING BATCH:	(   90 /   625)	LOSS:	0.038
# TRAINING BATCH:	(  100 /   625)	LOSS:	0.102
# TRAINING BATCH:	(  110 /   625)	LOSS:	0.095
# TRAINING BATCH:	(  120 /   625)	LOSS:	0.045
# TRAINING BATCH:	(  130 /   625)	LOSS:	0.153
# TRAINING BATCH:	(  140 /   625)	LOSS:	0.111
# TRAINING BATCH:	(  150 /   625)	LOSS:	0.056
# TRAINING BATCH:	(  160 /   625)	LOSS:	0.098
# TRAINING BATCH:	(  170 /   625)	LOSS:	0.115
# TRAINING BATCH:	(  180 /   625)	LOSS:	0.092
# TRAINING BATCH:	(  190 /   625)	LOSS:	0.089
# TRAINING BATCH:	(  200 /   625)	LOSS:	0.135
# TRAINING BATCH:	(  210 /   625)	LOSS:	0.076
# TRAINING BATCH:	(  220 /   625)	LOSS:	0.064
# TRAINING BATCH:	(  230 /   625)	LOSS:	0.045
# TRAINING BATCH:	(  240 /   625)	LOSS:	0.034
# TRAINING BATCH:	(  250 /   625)	LOSS:	0.098
# TRAINING BATCH:	(  260 /   625)	LOSS:	0.153
# TRAINING BATCH:	(  270 /   625)	LOSS:	0.095
# TRAINING BATCH:	(  280 /   625)	LOSS:	0.031
# TRAINING BATCH:	(  290 /   625)	LOSS:	0.141
# TRAINING BATCH:	(  300 /   625)	LOSS:	0.093
# TRAINING BATCH:	(  310 /   625)	LOSS:	0.031
# TRAINING BATCH:	(  320 /   625)	LOSS:	0.061
# TRAINING BATCH:	(  330 /   625)	LOSS:	0.089
# TRAINING BATCH:	(  340 /   625)	LOSS:	0.093
# TRAINING BATCH:	(  350 /   625)	LOSS:	0.078
# TRAINING BATCH:	(  360 /   625)	LOSS:	0.050
# TRAINING BATCH:	(  370 /   625)	LOSS:	0.068
# TRAINING BATCH:	(  380 /   625)	LOSS:	0.046
# TRAINING BATCH:	(  390 /   625)	LOSS:	0.083
# TRAINING BATCH:	(  400 /   625)	LOSS:	0.080
# TRAINING BATCH:	(  410 /   625)	LOSS:	0.108
# TRAINING BATCH:	(  420 /   625)	LOSS:	0.053
# TRAINING BATCH:	(  430 /   625)	LOSS:	0.060
# TRAINING BATCH:	(  440 /   625)	LOSS:	0.037
# TRAINING BATCH:	(  450 /   625)	LOSS:	0.044
# TRAINING BATCH:	(  460 /   625)	LOSS:	0.115
# TRAINING BATCH:	(  470 /   625)	LOSS:	0.192
# TRAINING BATCH:	(  480 /   625)	LOSS:	0.023
# TRAINING BATCH:	(  490 /   625)	LOSS:	0.190
# TRAINING BATCH:	(  500 /   625)	LOSS:	0.147
# TRAINING BATCH:	(  510 /   625)	LOSS:	0.073
# TRAINING BATCH:	(  520 /   625)	LOSS:	0.071
# TRAINING BATCH:	(  530 /   625)	LOSS:	0.025
# TRAINING BATCH:	(  540 /   625)	LOSS:	0.042
# TRAINING BATCH:	(  550 /   625)	LOSS:	0.101
# TRAINING BATCH:	(  560 /   625)	LOSS:	0.139
# TRAINING BATCH:	(  570 /   625)	LOSS:	0.047
# TRAINING BATCH:	(  580 /   625)	LOSS:	0.077
# TRAINING BATCH:	(  590 /   625)	LOSS:	0.036
# TRAINING BATCH:	(  600 /   625)	LOSS:	0.039
# TRAINING BATCH:	(  610 /   625)	LOSS:	0.050
# TRAINING BATCH:	(  620 /   625)	LOSS:	0.059
# TEST BATCH:	(    0 /   157)	LOSS:	0.152
# TEST BATCH:	(   50 /   157)	LOSS:	0.251
# TEST BATCH:	(  100 /   157)	LOSS:	0.080
# EPOCH:	   16	TRAIN LOSS:	0.002	TRAIN ACCURACY:	0.940	TEST LOSS:	0.006	TEST ACCURACY:	0.878
# TRAINING BATCH:	(    0 /   625)	LOSS:	0.040
# TRAINING BATCH:	(   10 /   625)	LOSS:	0.059
# TRAINING BATCH:	(   20 /   625)	LOSS:	0.018
# TRAINING BATCH:	(   30 /   625)	LOSS:	0.026
# TRAINING BATCH:	(   40 /   625)	LOSS:	0.201
# TRAINING BATCH:	(   50 /   625)	LOSS:	0.044
# TRAINING BATCH:	(   60 /   625)	LOSS:	0.166
# TRAINING BATCH:	(   70 /   625)	LOSS:	0.080
# TRAINING BATCH:	(   80 /   625)	LOSS:	0.146
# TRAINING BATCH:	(   90 /   625)	LOSS:	0.125
# TRAINING BATCH:	(  100 /   625)	LOSS:	0.094
# TRAINING BATCH:	(  110 /   625)	LOSS:	0.045
# TRAINING BATCH:	(  120 /   625)	LOSS:	0.086
# TRAINING BATCH:	(  130 /   625)	LOSS:	0.033
# TRAINING BATCH:	(  140 /   625)	LOSS:	0.136
# TRAINING BATCH:	(  150 /   625)	LOSS:	0.098
# TRAINING BATCH:	(  160 /   625)	LOSS:	0.073
# TRAINING BATCH:	(  170 /   625)	LOSS:	0.022
# TRAINING BATCH:	(  180 /   625)	LOSS:	0.042
# TRAINING BATCH:	(  190 /   625)	LOSS:	0.033
# TRAINING BATCH:	(  200 /   625)	LOSS:	0.072
# TRAINING BATCH:	(  210 /   625)	LOSS:	0.075
# TRAINING BATCH:	(  220 /   625)	LOSS:	0.062
# TRAINING BATCH:	(  230 /   625)	LOSS:	0.136
# TRAINING BATCH:	(  240 /   625)	LOSS:	0.102
# TRAINING BATCH:	(  250 /   625)	LOSS:	0.019
# TRAINING BATCH:	(  260 /   625)	LOSS:	0.068
# TRAINING BATCH:	(  270 /   625)	LOSS:	0.137
# TRAINING BATCH:	(  280 /   625)	LOSS:	0.120
# TRAINING BATCH:	(  290 /   625)	LOSS:	0.031
# TRAINING BATCH:	(  300 /   625)	LOSS:	0.041
# TRAINING BATCH:	(  310 /   625)	LOSS:	0.033
# TRAINING BATCH:	(  320 /   625)	LOSS:	0.082
# TRAINING BATCH:	(  330 /   625)	LOSS:	0.020
# TRAINING BATCH:	(  340 /   625)	LOSS:	0.035
# TRAINING BATCH:	(  350 /   625)	LOSS:	0.049
# TRAINING BATCH:	(  360 /   625)	LOSS:	0.203
# TRAINING BATCH:	(  370 /   625)	LOSS:	0.058
# TRAINING BATCH:	(  380 /   625)	LOSS:	0.104
# TRAINING BATCH:	(  390 /   625)	LOSS:	0.116
# TRAINING BATCH:	(  400 /   625)	LOSS:	0.039
# TRAINING BATCH:	(  410 /   625)	LOSS:	0.106
# TRAINING BATCH:	(  420 /   625)	LOSS:	0.051
# TRAINING BATCH:	(  430 /   625)	LOSS:	0.081
# TRAINING BATCH:	(  440 /   625)	LOSS:	0.176
# TRAINING BATCH:	(  450 /   625)	LOSS:	0.033
# TRAINING BATCH:	(  460 /   625)	LOSS:	0.033
# TRAINING BATCH:	(  470 /   625)	LOSS:	0.084
# TRAINING BATCH:	(  480 /   625)	LOSS:	0.179
# TRAINING BATCH:	(  490 /   625)	LOSS:	0.158
# TRAINING BATCH:	(  500 /   625)	LOSS:	0.033
# TRAINING BATCH:	(  510 /   625)	LOSS:	0.021
# TRAINING BATCH:	(  520 /   625)	LOSS:	0.164
# TRAINING BATCH:	(  530 /   625)	LOSS:	0.077
# TRAINING BATCH:	(  540 /   625)	LOSS:	0.164
# TRAINING BATCH:	(  550 /   625)	LOSS:	0.025
# TRAINING BATCH:	(  560 /   625)	LOSS:	0.074
# TRAINING BATCH:	(  570 /   625)	LOSS:	0.132
# TRAINING BATCH:	(  580 /   625)	LOSS:	0.034
# TRAINING BATCH:	(  590 /   625)	LOSS:	0.032
# TRAINING BATCH:	(  600 /   625)	LOSS:	0.125
# TRAINING BATCH:	(  610 /   625)	LOSS:	0.108
# TRAINING BATCH:	(  620 /   625)	LOSS:	0.115
# TEST BATCH:	(    0 /   157)	LOSS:	0.179
# TEST BATCH:	(   50 /   157)	LOSS:	0.230
# TEST BATCH:	(  100 /   157)	LOSS:	0.118
# EPOCH:	   17	TRAIN LOSS:	0.002	TRAIN ACCURACY:	0.946	TEST LOSS:	0.006	TEST ACCURACY:	0.884
# TRAINING BATCH:	(    0 /   625)	LOSS:	0.074
# TRAINING BATCH:	(   10 /   625)	LOSS:	0.035
# TRAINING BATCH:	(   20 /   625)	LOSS:	0.102
# TRAINING BATCH:	(   30 /   625)	LOSS:	0.040
# TRAINING BATCH:	(   40 /   625)	LOSS:	0.139
# TRAINING BATCH:	(   50 /   625)	LOSS:	0.094
# TRAINING BATCH:	(   60 /   625)	LOSS:	0.023
# TRAINING BATCH:	(   70 /   625)	LOSS:	0.043
# TRAINING BATCH:	(   80 /   625)	LOSS:	0.042
# TRAINING BATCH:	(   90 /   625)	LOSS:	0.017
# TRAINING BATCH:	(  100 /   625)	LOSS:	0.102
# TRAINING BATCH:	(  110 /   625)	LOSS:	0.095
# TRAINING BATCH:	(  120 /   625)	LOSS:	0.028
# TRAINING BATCH:	(  130 /   625)	LOSS:	0.081
# TRAINING BATCH:	(  140 /   625)	LOSS:	0.073
# TRAINING BATCH:	(  150 /   625)	LOSS:	0.064
# TRAINING BATCH:	(  160 /   625)	LOSS:	0.021
# TRAINING BATCH:	(  170 /   625)	LOSS:	0.103
# TRAINING BATCH:	(  180 /   625)	LOSS:	0.063
# TRAINING BATCH:	(  190 /   625)	LOSS:	0.124
# TRAINING BATCH:	(  200 /   625)	LOSS:	0.017
# TRAINING BATCH:	(  210 /   625)	LOSS:	0.086
# TRAINING BATCH:	(  220 /   625)	LOSS:	0.039
# TRAINING BATCH:	(  230 /   625)	LOSS:	0.030
# TRAINING BATCH:	(  240 /   625)	LOSS:	0.018
# TRAINING BATCH:	(  250 /   625)	LOSS:	0.156
# TRAINING BATCH:	(  260 /   625)	LOSS:	0.032
# TRAINING BATCH:	(  270 /   625)	LOSS:	0.038
# TRAINING BATCH:	(  280 /   625)	LOSS:	0.043
# TRAINING BATCH:	(  290 /   625)	LOSS:	0.125
# TRAINING BATCH:	(  300 /   625)	LOSS:	0.072
# TRAINING BATCH:	(  310 /   625)	LOSS:	0.030
# TRAINING BATCH:	(  320 /   625)	LOSS:	0.041
# TRAINING BATCH:	(  330 /   625)	LOSS:	0.041
# TRAINING BATCH:	(  340 /   625)	LOSS:	0.152
# TRAINING BATCH:	(  350 /   625)	LOSS:	0.061
# TRAINING BATCH:	(  360 /   625)	LOSS:	0.037
# TRAINING BATCH:	(  370 /   625)	LOSS:	0.054
# TRAINING BATCH:	(  380 /   625)	LOSS:	0.033
# TRAINING BATCH:	(  390 /   625)	LOSS:	0.051
# TRAINING BATCH:	(  400 /   625)	LOSS:	0.032
# TRAINING BATCH:	(  410 /   625)	LOSS:	0.072
# TRAINING BATCH:	(  420 /   625)	LOSS:	0.036
# TRAINING BATCH:	(  430 /   625)	LOSS:	0.032
# TRAINING BATCH:	(  440 /   625)	LOSS:	0.029
# TRAINING BATCH:	(  450 /   625)	LOSS:	0.079
# TRAINING BATCH:	(  460 /   625)	LOSS:	0.093
# TRAINING BATCH:	(  470 /   625)	LOSS:	0.081
# TRAINING BATCH:	(  480 /   625)	LOSS:	0.083
# TRAINING BATCH:	(  490 /   625)	LOSS:	0.238
# TRAINING BATCH:	(  500 /   625)	LOSS:	0.159
# TRAINING BATCH:	(  510 /   625)	LOSS:	0.044
# TRAINING BATCH:	(  520 /   625)	LOSS:	0.045
# TRAINING BATCH:	(  530 /   625)	LOSS:	0.069
# TRAINING BATCH:	(  540 /   625)	LOSS:	0.092
# TRAINING BATCH:	(  550 /   625)	LOSS:	0.034
# TRAINING BATCH:	(  560 /   625)	LOSS:	0.050
# TRAINING BATCH:	(  570 /   625)	LOSS:	0.068
# TRAINING BATCH:	(  580 /   625)	LOSS:	0.038
# TRAINING BATCH:	(  590 /   625)	LOSS:	0.129
# TRAINING BATCH:	(  600 /   625)	LOSS:	0.112
# TRAINING BATCH:	(  610 /   625)	LOSS:	0.017
# TRAINING BATCH:	(  620 /   625)	LOSS:	0.106
# TEST BATCH:	(    0 /   157)	LOSS:	0.118
# TEST BATCH:	(   50 /   157)	LOSS:	0.332
# TEST BATCH:	(  100 /   157)	LOSS:	0.113
# EPOCH:	   18	TRAIN LOSS:	0.002	TRAIN ACCURACY:	0.948	TEST LOSS:	0.006	TEST ACCURACY:	0.884
# TRAINING BATCH:	(    0 /   625)	LOSS:	0.020
# TRAINING BATCH:	(   10 /   625)	LOSS:	0.023
# TRAINING BATCH:	(   20 /   625)	LOSS:	0.042
# TRAINING BATCH:	(   30 /   625)	LOSS:	0.052
# TRAINING BATCH:	(   40 /   625)	LOSS:	0.050
# TRAINING BATCH:	(   50 /   625)	LOSS:	0.077
# TRAINING BATCH:	(   60 /   625)	LOSS:	0.127
# TRAINING BATCH:	(   70 /   625)	LOSS:	0.060
# TRAINING BATCH:	(   80 /   625)	LOSS:	0.237
# TRAINING BATCH:	(   90 /   625)	LOSS:	0.036
# TRAINING BATCH:	(  100 /   625)	LOSS:	0.089
# TRAINING BATCH:	(  110 /   625)	LOSS:	0.034
# TRAINING BATCH:	(  120 /   625)	LOSS:	0.029
# TRAINING BATCH:	(  130 /   625)	LOSS:	0.102
# TRAINING BATCH:	(  140 /   625)	LOSS:	0.053
# TRAINING BATCH:	(  150 /   625)	LOSS:	0.019
# TRAINING BATCH:	(  160 /   625)	LOSS:	0.025
# TRAINING BATCH:	(  170 /   625)	LOSS:	0.103
# TRAINING BATCH:	(  180 /   625)	LOSS:	0.040
# TRAINING BATCH:	(  190 /   625)	LOSS:	0.053
# TRAINING BATCH:	(  200 /   625)	LOSS:	0.032
# TRAINING BATCH:	(  210 /   625)	LOSS:	0.081
# TRAINING BATCH:	(  220 /   625)	LOSS:	0.043
# TRAINING BATCH:	(  230 /   625)	LOSS:	0.086
# TRAINING BATCH:	(  240 /   625)	LOSS:	0.064
# TRAINING BATCH:	(  250 /   625)	LOSS:	0.066
# TRAINING BATCH:	(  260 /   625)	LOSS:	0.137
# TRAINING BATCH:	(  270 /   625)	LOSS:	0.131
# TRAINING BATCH:	(  280 /   625)	LOSS:	0.072
# TRAINING BATCH:	(  290 /   625)	LOSS:	0.040
# TRAINING BATCH:	(  300 /   625)	LOSS:	0.052
# TRAINING BATCH:	(  310 /   625)	LOSS:	0.106
# TRAINING BATCH:	(  320 /   625)	LOSS:	0.082
# TRAINING BATCH:	(  330 /   625)	LOSS:	0.064
# TRAINING BATCH:	(  340 /   625)	LOSS:	0.043
# TRAINING BATCH:	(  350 /   625)	LOSS:	0.117
# TRAINING BATCH:	(  360 /   625)	LOSS:	0.047
# TRAINING BATCH:	(  370 /   625)	LOSS:	0.036
# TRAINING BATCH:	(  380 /   625)	LOSS:	0.077
# TRAINING BATCH:	(  390 /   625)	LOSS:	0.031
# TRAINING BATCH:	(  400 /   625)	LOSS:	0.036
# TRAINING BATCH:	(  410 /   625)	LOSS:	0.055
# TRAINING BATCH:	(  420 /   625)	LOSS:	0.054
# TRAINING BATCH:	(  430 /   625)	LOSS:	0.069
# TRAINING BATCH:	(  440 /   625)	LOSS:	0.049
# TRAINING BATCH:	(  450 /   625)	LOSS:	0.070
# TRAINING BATCH:	(  460 /   625)	LOSS:	0.135
# TRAINING BATCH:	(  470 /   625)	LOSS:	0.036
# TRAINING BATCH:	(  480 /   625)	LOSS:	0.021
# TRAINING BATCH:	(  490 /   625)	LOSS:	0.108
# TRAINING BATCH:	(  500 /   625)	LOSS:	0.053
# TRAINING BATCH:	(  510 /   625)	LOSS:	0.033
# TRAINING BATCH:	(  520 /   625)	LOSS:	0.077
# TRAINING BATCH:	(  530 /   625)	LOSS:	0.027
# TRAINING BATCH:	(  540 /   625)	LOSS:	0.060
# TRAINING BATCH:	(  550 /   625)	LOSS:	0.027
# TRAINING BATCH:	(  560 /   625)	LOSS:	0.042
# TRAINING BATCH:	(  570 /   625)	LOSS:	0.062
# TRAINING BATCH:	(  580 /   625)	LOSS:	0.018
# TRAINING BATCH:	(  590 /   625)	LOSS:	0.069
# TRAINING BATCH:	(  600 /   625)	LOSS:	0.069
# TRAINING BATCH:	(  610 /   625)	LOSS:	0.052
# TRAINING BATCH:	(  620 /   625)	LOSS:	0.016
# TEST BATCH:	(    0 /   157)	LOSS:	0.282
# TEST BATCH:	(   50 /   157)	LOSS:	0.251
# TEST BATCH:	(  100 /   157)	LOSS:	0.164
# EPOCH:	   19	TRAIN LOSS:	0.002	TRAIN ACCURACY:	0.949	TEST LOSS:	0.006	TEST ACCURACY:	0.881
# TRAINING BATCH:	(    0 /   625)	LOSS:	0.025
# TRAINING BATCH:	(   10 /   625)	LOSS:	0.043
# TRAINING BATCH:	(   20 /   625)	LOSS:	0.047
# TRAINING BATCH:	(   30 /   625)	LOSS:	0.068
# TRAINING BATCH:	(   40 /   625)	LOSS:	0.013
# TRAINING BATCH:	(   50 /   625)	LOSS:	0.103
# TRAINING BATCH:	(   60 /   625)	LOSS:	0.087
# TRAINING BATCH:	(   70 /   625)	LOSS:	0.019
# TRAINING BATCH:	(   80 /   625)	LOSS:	0.020
# TRAINING BATCH:	(   90 /   625)	LOSS:	0.071
# TRAINING BATCH:	(  100 /   625)	LOSS:	0.048
# TRAINING BATCH:	(  110 /   625)	LOSS:	0.157
# TRAINING BATCH:	(  120 /   625)	LOSS:	0.040
# TRAINING BATCH:	(  130 /   625)	LOSS:	0.035
# TRAINING BATCH:	(  140 /   625)	LOSS:	0.082
# TRAINING BATCH:	(  150 /   625)	LOSS:	0.020
# TRAINING BATCH:	(  160 /   625)	LOSS:	0.022
# TRAINING BATCH:	(  170 /   625)	LOSS:	0.037
# TRAINING BATCH:	(  180 /   625)	LOSS:	0.131
# TRAINING BATCH:	(  190 /   625)	LOSS:	0.054
# TRAINING BATCH:	(  200 /   625)	LOSS:	0.035
# TRAINING BATCH:	(  210 /   625)	LOSS:	0.038
# TRAINING BATCH:	(  220 /   625)	LOSS:	0.071
# TRAINING BATCH:	(  230 /   625)	LOSS:	0.083
# TRAINING BATCH:	(  240 /   625)	LOSS:	0.020
# TRAINING BATCH:	(  250 /   625)	LOSS:	0.022
# TRAINING BATCH:	(  260 /   625)	LOSS:	0.028
# TRAINING BATCH:	(  270 /   625)	LOSS:	0.054
# TRAINING BATCH:	(  280 /   625)	LOSS:	0.029
# TRAINING BATCH:	(  290 /   625)	LOSS:	0.074
# TRAINING BATCH:	(  300 /   625)	LOSS:	0.042
# TRAINING BATCH:	(  310 /   625)	LOSS:	0.090
# TRAINING BATCH:	(  320 /   625)	LOSS:	0.050
# TRAINING BATCH:	(  330 /   625)	LOSS:	0.030
# TRAINING BATCH:	(  340 /   625)	LOSS:	0.072
# TRAINING BATCH:	(  350 /   625)	LOSS:	0.035
# TRAINING BATCH:	(  360 /   625)	LOSS:	0.029
# TRAINING BATCH:	(  370 /   625)	LOSS:	0.104
# TRAINING BATCH:	(  380 /   625)	LOSS:	0.038
# TRAINING BATCH:	(  390 /   625)	LOSS:	0.009
# TRAINING BATCH:	(  400 /   625)	LOSS:	0.106
# TRAINING BATCH:	(  410 /   625)	LOSS:	0.065
# TRAINING BATCH:	(  420 /   625)	LOSS:	0.155
# TRAINING BATCH:	(  430 /   625)	LOSS:	0.034
# TRAINING BATCH:	(  440 /   625)	LOSS:	0.234
# TRAINING BATCH:	(  450 /   625)	LOSS:	0.033
# TRAINING BATCH:	(  460 /   625)	LOSS:	0.032
# TRAINING BATCH:	(  470 /   625)	LOSS:	0.043
# TRAINING BATCH:	(  480 /   625)	LOSS:	0.107
# TRAINING BATCH:	(  490 /   625)	LOSS:	0.052
# TRAINING BATCH:	(  500 /   625)	LOSS:	0.086
# TRAINING BATCH:	(  510 /   625)	LOSS:	0.058
# TRAINING BATCH:	(  520 /   625)	LOSS:	0.025
# TRAINING BATCH:	(  530 /   625)	LOSS:	0.086
# TRAINING BATCH:	(  540 /   625)	LOSS:	0.017
# TRAINING BATCH:	(  550 /   625)	LOSS:	0.028
# TRAINING BATCH:	(  560 /   625)	LOSS:	0.090
# TRAINING BATCH:	(  570 /   625)	LOSS:	0.029
# TRAINING BATCH:	(  580 /   625)	LOSS:	0.049
# TRAINING BATCH:	(  590 /   625)	LOSS:	0.031
# TRAINING BATCH:	(  600 /   625)	LOSS:	0.061
# TRAINING BATCH:	(  610 /   625)	LOSS:	0.139
# TRAINING BATCH:	(  620 /   625)	LOSS:	0.045
# TEST BATCH:	(    0 /   157)	LOSS:	0.168
# TEST BATCH:	(   50 /   157)	LOSS:	0.331
# TEST BATCH:	(  100 /   157)	LOSS:	0.228
# EPOCH:	   20	TRAIN LOSS:	0.002	TRAIN ACCURACY:	0.953	TEST LOSS:	0.006	TEST ACCURACY:	0.873

# %%
get_training_progress_plot(
    metrics['train_loss'],
    metrics['train_acc'],
    metrics['test_loss'],
    metrics['test_acc'],
)

# %% [markdown]
# It is amazing what we achieved with such a small (for the standard of deep learning) model and dataset! Lets indulge in some more examples on the test set!

# %%
# look at some predictions
def plot_prediction(model: nn.Module, dataset: Dataset, idx: int) -> None:
    sample = dataset[idx]
    num_1 = sample['num_1'].unsqueeze(0).to(device)
    num_2 = sample['num_2'].unsqueeze(0).to(device)
    y = sample['label'].unsqueeze(0).to(device)

    y_hat = model(num_1, num_2)
    y_hat = torch.argmax(y_hat, dim=1).squeeze(0)

    print('Prediction:', ''.join([str(int(i)) for i in y_hat]))
    print('Label:', ''.join([str(int(i)) for i in y.squeeze(0)]))

    plot_digits(num_1.squeeze(0), num_2.squeeze(0))

plot_prediction(model, test_dataset, int(torch.randint(len(test_dataset), (1, ))))
plot_prediction(model, test_dataset, int(torch.randint(len(test_dataset), (1, ))))
# Out:
# Prediction: 536
# Label: 536
# Prediction: 080
# Label: 130

# %% [markdown]
# ## Exercise 3
#
# In this exercise, we are going to focus on the concept of self-attention. Generally speaking, self-attention allows the model to capture dependencies within a single sequence, weighting the importance of the individual sequence elements/token relative to each other. To do so the classical self-attention mechanism consists of three trainable weight matrices $W_q^{d \times d_q}$, $W_k^{d \times d_k}$, $W_v^{d \times d_v}$ with $d_k = d_q$. In addition, we usually also have an input matrix $X^{N \times d}$ where each row represents one token/element of this input. This can e.g. be an embedding vector per token but also a vector representation obtained from other network components.
#
# To actually understand the mechanism behind self-attention we want to calculate one iteration of the self-attention procedure. Let us assume we have the input sentence: Alice visits Bob. The corresponding embedding vectors per token are $x^{(1)} = (2, 1, 0)$, $x^{(2)} = (0, 0, 1)$, $x^{(3)} = (0, 2, 0)$. The weight matrices are
# \begin{equation}W_q = \left(\begin{matrix} 0 & 2  \\ 1 & 0 \\ 3 & 1 \end{matrix}\right), W_k = \left(\begin{matrix} 1 & 0  \\ 0 & 1 \\ 1 & 3 \end{matrix}\right), W_v = \left(\begin{matrix} 4 & 2  \\ 6 & 5 \\ 3 & 2\end{matrix}\right) \end{equation}

# %% [markdown]
# 1. Compute $Q = XW_q, K= XW_k$ and $V= XW_v$.
# 2. Compute the attention weights $A = \text{softmax}(\frac{QK^T}{\sqrt(d_k)})$
#     1. What is the dimension of $A$?
#     2. What does the multiplication of $Q$ and $K$ actually mean? How can we interpret the values of A?
# 3. Compute the attention outputs $\text{Attention}(K, Q, V) = AV$
#     1. What are the dimensions of $\text{Attention}(K, Q, V)$?
#     2. How can we interpret this operation?

# %% [markdown]
# \textbf{Solution:}
#
# 1.
#     \begin{equation} Q = X W_q = \left(\begin{matrix} 2 & 1 & 0 \\ 0 & 0 & 1 \\ 0 & 2 & 0 \end{matrix}\right)
#     \left(\begin{matrix} 0 & 2 \\ 1 & 0 \\ 3 & 1 \end{matrix}\right)
#     = \left(\begin{matrix} 1.0 & 4.0 \\ 3.0 & 1.0 \\ 2.0 & 0.0 \end{matrix}\right) \end{equation}
#
#
#     \begin{equation} K = X W_k = \left(\begin{matrix} 2 & 1 & 0 \\ 0 & 0 & 1 \\ 0 & 2 & 0 \end{matrix}\right)
#     \left(\begin{matrix} 1 & 0 \\ 0 & 1 \\ 1 & 3 \end{matrix}\right)
#     = \left(\begin{matrix} 2.0 & 1.0 \\ 1.0 & 3.0 \\ 0.0 & 2.0 \end{matrix}\right) \end{equation}
#
#
#     \begin{equation} V = X W_v = \left(\begin{matrix} 2 & 1 & 0 \\ 0 & 0 & 1 \\ 0 & 2 & 0 \end{matrix}\right)
#     \left(\begin{matrix} 4 & 2 \\ 6 & 5 \\ 3 & 2 \end{matrix}\right)
#     = \left(\begin{matrix} 14.0 & 9.0 \\ 3.0 & 2.0 \\ 12.0 & 10.0 \end{matrix}\right) \end{equation}
#
# 2.
#     \begin{equation} A= \text{softmax} \left( \frac{QK^T}{\sqrt{2}} \right) =
#     \left(\begin{matrix}
#     0.007 & 0.965 & 0.028 \\
#     0.657 & 0.324 & 0.019 \\
#     0.768 & 0.187 & 0.045
#     \end{matrix}\right) \end{equation}
#
#     1. $N \times N$
#     2.  - Vector-wise similarity/closeness between the elements in Q and K.
#         - Intuitively: Per word (embedding) q, how much does an respective element from k relate to q for the given context. How much does k help us to understand what q is about?
#         - This is also why we project into the different spaces. If $Q=K$ exactly (i.e., no learned projection), then the dot product $QK^T$ would usually produce mostly high values along the diagonal and smaller values else where. Softmax on this would then result in an almost one-hot attention matrix (where each token attends mostly to itself). Applying this to $V$ would then mean each word is weighted mostly by itself, so the attention mechanism would not change the representation in a meaningful way.
# 3.
#     \begin{equation} \text{Attention}(K, Q, V) = A V =
#     \left(\begin{matrix}
#     3.33 & 2.27 \\
#     10.40 & 6.75 \\
#     11.86 & 7.74
#     \end{matrix}\right) \end{equation}
#
#     1. $N \times d_v$
#     2. The attention mechanism computes a weighted sum of the value vectors, where the attention weights determine the contribution of each token. Thus, each output representation incorporates the most relevant contextual information provided by the other tokens based on their importance in the given context.

# %% [markdown]
# One problem of the traditional self-attention mechansim, is the memory consumption of $\mathcal{O}(n^2)$, due to storing the full $N \times N$ matrix. An approach that mitigates this bottleneck is FlashAttention. The core idea of FlashAttention is to divide the matrices $Q, K, V$ into blocks along the first dimension and perform the softmax operation block by block, s.t. you iterativley update the softmax-values of the previous blocks, with the values obtained for the current block. For example, let’s consider a specific query row $q_i \in \mathbb{R}^{1 \times d_k}$ from $Q$, and a blockwise decomposition of the key matrix $K$ into two blocks, $K^{(1)} \in \mathbb{R}^{b_1 \times d_k}$ and $K^{(2)} \in \mathbb{R}^{b_2 \times d_k}$, corresponding to the first and second chunks of the key matrix along the sequence dimension. The corresponding query-key dot products yield the two row vectors $\mathbf{a}_i^{(1)} = q_i {K^{(1)}}^\top$ and $\mathbf{a}_i^{(2)} = q_i {K^{(2)}}^\top$. In the end, we want to compute the softmax over the fully concatenated vector $\mathbf{a}_i = \left(\mathbf{a}_i^{(1)}, \mathbf{a}_i^{(2)}\right)$.
#
# FlashAttention uses softmax tiling, which for our vector $\mathbf{a_i}$ consists of the following steps:
#
# 1. Construct the softmax-formulation for each $\mathbf{a}_i^{(1)}, \mathbf{a}_i^{(2)}$ independently. In addition, we compute the respective maximum per vector so $m_1 = max(\mathbf{a}_i^{(1)})$ and $m_2 = max(\mathbf{a}_i^{(2)})$ and subtract that from the exponents in the respective softmax formulation:
#
# \begin{equation}
# \text{softmax}(\mathbf{a}_i^{(1)}) = \frac{\mathbf{f(a_i^{(1)})}}{l_1}
# \end{equation}
#
# \begin{equation}
# \text{softmax}(\mathbf{a}_i^{(2)}) = \frac{\mathbf{f(a_i^{(2)})}}{l_2}
# \end{equation}
#
# with $\mathbf{f(a_i^{(t)})} = \left( e^{a_{i,1}^{(t)} - m_t} \quad \dots \quad e^{a_{i,b_t}^{(t)} - m_t}\right)$ and $l_t = \sum_j e^{a_{i,j}^{(t)} - m_t}$
#
# 2. Compute the global maximum across both vectors, so $m = max(m_1, m_2)$ and construct the normalizers $e^{m_1 - m}$, $e^{m_2 - m}$. Apply them to the softmax:
# \begin{equation}
# \text{softmax}(\mathbf{a}_i^{(1)}) = \frac{\mathbf{f(a_i^{(1)})} \cdot e^{m_1 - m}}{l_1 \cdot e^{m_1 - m}}
# \end{equation}
#
# \begin{equation}
# \text{softmax}(\mathbf{a}_i^{(2)}) = \frac{\mathbf{f(a_i^{(2)})} \cdot e^{m_2 - m}}{l_2 \cdot e^{m_2 - m}}
# \end{equation}
#
# 3. Construct the softmax for $\mathbf{a}_i$ via additivley combining the two individual softmax's:
# \begin{equation}
# \text{softmax}(\mathbf{a}_i) = \frac{\mathbf{f(a_i)}}{l}
# \end{equation}
#
#     with $\mathbf{f(a_i)} = \left (\mathbf{f(a_i^{(1)})} \cdot e^{m_1 - m}, \mathbf{f(a_i^{(2)})} \cdot e^{m_2 - m} \right)$ and $l = l_1 \cdot e^{m_1 - m} + l_2 \cdot e^{m_2 - m}$
#
#
# Now, show that the formulation in 3. actually is equal to the vanilla softmax formulation directly computed for the complete $\mathbf{a_i}$
# \begin{equation}
# \text{softmax}(\mathbf{a}_i) = \frac{\left(e^{a_{i,1}} \quad \dots \quad e^{a_{i,b}}\right)}{\sum_j e^{a_{i,j}}}
# \end{equation}
#
#
# \textbf{Solution:}
#
# Since
# \begin{align*}
# \mathbf{f}(\mathbf{a}_i^{(1)})_j \cdot e^{m_1 - m}
# &= \left( e^{a_{i,j}^{(1)} - m_1} \cdot e^{m_1 - m} \right)
# = \left( e^{a_{i,j}^{(1)} - m} \right) \\
# \mathbf{f}(\mathbf{a}_i^{(2)})_j \cdot e^{m_2 - m}
# &= \left( e^{a_{i,j}^{(2)} - m_2} \cdot e^{m_2 - m} \right)
# = \left( e^{a_{i,j}^{(2)} - m} \right)
# \end{align*}
#
# So:
# \begin{align*}
# \mathbf{f}(\mathbf{a}_i) &= \left( e^{a_{i,1} - m}, \dots, e^{a_{i,b_1 + b_2} - m} \right) \\
# l &= \sum_{j=1}^{b_1 + b_2} e^{a_{i,j} - m}
# \end{align*}
#
# Multiplying numerator and denominator by $e^{m}$, we recover:
# \begin{align*}
# \text{softmax}(\mathbf{a}_i) = \frac{ \left( e^{a_{i,1}}, \dots, e^{a_{i,b_1 + b_2}} \right) }{ \sum_{j=1}^{b_1 + b_2} e^{a_{i,j}} }
# \end{align*}
#
# Therefore, the final expression is:
# \begin{align*}
# \text{softmax}(\mathbf{a}_i) = \frac{ \left( e^{a_{i,1}}, \dots, e^{a_{i,b_1 + b_2}} \right) }{ \sum_{j=1}^{b_1 + b_2} e^{a_{i,j}} }
# \end{align*}
#
# which is exactly the vanilla softmax.

# %% [markdown]
# Now, let's recap why this method is great for reducing the memory consumption and for increasing computational efficiency. The block-wise (and thus intermediate) attention scores never need to be fully stored. It is enough to store only the per-block partial results and running statistics (like the max and sum for softmax). In addition, computation within each block is fully parallelizable across queries and across the elements inside the block. Synchronization is only needed when combining the results across blocks, to correctly update the softmax normalization and the final output.
#
# ## Exercise 4
#
# Now, in the last exercise we want to apply the self attention concept to our model from exercise 1. Reusing both the data preprocessing functions and the training loop, we only have to update the model:

# %%
class AttentionModel(nn.Module):
    def __init__(self):
        # A class that inherits from nn.Module needs to call the constructor from the
        # parent class
        super().__init__()

        self.embedding = nn.Embedding(
            num_embeddings=10001,
            embedding_dim=64,
            padding_idx=0
        )
        self.attn = nn.MultiheadAttention(
            # The embed_dim must match the embedding_dim from before!
            embed_dim=64,     
            num_heads=4,
            batch_first=True
        )

        self.fc = nn.Linear(in_features=64, out_features=1)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x: Tensor) -> Tensor:
        # The output needs to be reshaped or otherwise we have a dimension too much.
        x = self.embedding(x).squeeze(2)

        # Self-attention (Q=K=V)
        attn_out, _ = self.attn(x, x, x)  # shape: (batch_size, seq_len, embed_dim)

        # You can either:
        # - take the mean over time steps (standard practice),
        # - or use the first token, or apply another pooling strategy.
        pooled = attn_out.mean(dim=1)  # shape: (batch_size, embed_dim)

        # We need to extract the last hidden state
        y_score = self.fc(pooled)
        y_hat = self.sigmoid(y_score).squeeze(-1)
        return y_hat

# %% [markdown]
# Now let's simply reuse the training loop from exercise 1:

# %%
def train(
        model: nn.Module,
        loss: nn.Module,
        optimizer: Optimizer,
        train_dataset: Dataset,
        test_dataset: Dataset,
        epochs: int,
        batch_size: int
) -> Dict:
    metrics: Dict = {
        'train_loss': [],
        'train_acc': [],
        'test_loss': [],
        'test_acc': [],
    }

    num_train_batches = ceil(len(train_dataset) / batch_size)
    num_test_batches = ceil(len(test_dataset) / batch_size)

    train_loader = DataLoader(train_dataset, batch_size, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size)

    for ep in range(1, epochs + 1):
        total_loss = 0
        num_correct = 0

        ################################################################################
        # TRAINING LOOP
        ################################################################################

        for batch_idx, (x, y) in enumerate(train_loader):

            y_hat = model(x)
            batch_loss = loss(y_hat, y)

            optimizer.zero_grad()
            batch_loss.backward()
            optimizer.step()

            # if batch_idx % 200 == 0:
            #     print('TRAINING BATCH:\t({:5} / {:5})\tLOSS:\t{:.3f}'
            #           .format(batch_idx, num_train_batches, float(batch_loss)),
            #           end='\r')

            total_loss += float(batch_loss)
            num_correct += int(torch.sum(torch.where(y_hat > 0.5, 1, 0) == y))

        ep_train_loss = total_loss / len(train_dataset)
        ep_train_acc = num_correct / len(train_dataset)

        total_loss = 0
        num_correct = 0

        ################################################################################
        # TEST LOOP
        ################################################################################

        for batch_idx, (x, y) in enumerate(test_loader):
            with torch.no_grad(): 
                y_hat = model(x)
                batch_loss = loss(y_hat, y)

            # if batch_idx % 200 == 0:
            #     print('TEST BATCH:\t({:5} / {:5})\tLOSS:\t{:.3f}'
            #           .format(batch_idx, num_test_batches, float(batch_loss)), end='\r')

            total_loss += float(batch_loss)
            num_correct += int(torch.sum(torch.where(y_hat > 0.5, 1, 0) == y))

        ep_test_loss = total_loss / len(test_dataset)
        ep_test_acc = num_correct / len(test_dataset)

        metrics['train_loss'].append(ep_train_loss)
        metrics['train_acc'].append(ep_train_acc)
        metrics['test_loss'].append(ep_test_loss)
        metrics['test_acc'].append(ep_test_acc)

        print('EPOCH:\t{:5}\tTRAIN LOSS:\t{:.3f}\tTRAIN ACCURACY:\t{:.3f}\tTEST LOSS:\t'
              '{:.3f}\tTEST ACCURACY:\t{:.3f}'
              .format(ep, ep_train_loss, ep_train_acc, ep_test_loss, ep_test_acc))
    return metrics

# %%
epochs = 10
batch_size = 32

model = (
    AttentionModel().to(device)
)

optimizer = (
    Adam(model.parameters(), lr=5e-4)
)

loss = (
    nn.BCELoss()
)

train_dataset = (
    IMDBDataset(train_x, train_y)
)

test_dataset = (
    IMDBDataset(test_x, test_y)
)

metrics = train(model, loss, optimizer, train_dataset, test_dataset, epochs, batch_size)
# Out:
# EPOCH:	    1	TRAIN LOSS:	0.017	TRAIN ACCURACY:	0.721	TEST LOSS:	0.014	TEST ACCURACY:	0.806
# EPOCH:	    2	TRAIN LOSS:	0.012	TRAIN ACCURACY:	0.842	TEST LOSS:	0.012	TEST ACCURACY:	0.836
# EPOCH:	    3	TRAIN LOSS:	0.010	TRAIN ACCURACY:	0.874	TEST LOSS:	0.011	TEST ACCURACY:	0.848
# EPOCH:	    4	TRAIN LOSS:	0.008	TRAIN ACCURACY:	0.892	TEST LOSS:	0.011	TEST ACCURACY:	0.854
# EPOCH:	    5	TRAIN LOSS:	0.007	TRAIN ACCURACY:	0.907	TEST LOSS:	0.011	TEST ACCURACY:	0.856
# EPOCH:	    6	TRAIN LOSS:	0.007	TRAIN ACCURACY:	0.919	TEST LOSS:	0.012	TEST ACCURACY:	0.855
# EPOCH:	    7	TRAIN LOSS:	0.006	TRAIN ACCURACY:	0.929	TEST LOSS:	0.013	TEST ACCURACY:	0.854
# EPOCH:	    8	TRAIN LOSS:	0.005	TRAIN ACCURACY:	0.940	TEST LOSS:	0.014	TEST ACCURACY:	0.853
# EPOCH:	    9	TRAIN LOSS:	0.005	TRAIN ACCURACY:	0.947	TEST LOSS:	0.014	TEST ACCURACY:	0.852
# EPOCH:	   10	TRAIN LOSS:	0.004	TRAIN ACCURACY:	0.957	TEST LOSS:	0.016	TEST ACCURACY:	0.846

# %%
def get_training_progress_plot(
        train_losses: List[float],
        train_accs: List[float],
        val_losses: List[float],
        val_accs: List[float],
) -> None:
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(7, 2))

    ax1.set_title('Loss')
    ax1.plot(train_losses, label='Train Loss')
    ax1.plot(val_losses, label='Test Loss')
    ax1.legend()

    ax2.set_title('Accuracy')
    ax2.plot(train_accs, label='Train Accuracy')
    ax2.plot(val_accs, label='Test Accuracy')
    ax2.set_ylim(0, 1)
    ax2.legend()


get_training_progress_plot(
    metrics['train_loss'],
    metrics['train_acc'],
    metrics['test_loss'],
    metrics['test_acc'],
)
